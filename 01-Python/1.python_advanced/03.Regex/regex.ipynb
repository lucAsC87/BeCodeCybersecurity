# %% [markdown]
# # Regular expressions (regex) : love or hate?

# %% [markdown]
# ![commit strip](http://www.commitstrip.com/wp-content/uploads/2014/02/Strips-Le-dernier-des-vrais-codeurs-650-finalenglsih.jpg)

# %% [markdown]
# Regular expressions are used in almost all languages. It is a very powerful tool to check if the content of a variable has the shape you expect.
#
# For example, if you retrieve a phone number, you expect the variable to be composed of numbers and spaces (or dashes) but nothing more.
#
# Regular expressions not only warn you of an unwanted character but also delete/modify all those that are not desirable.

# %% [markdown]
# **There are two ways to use regular expressions:**
# * The first consists in calling the function with the pattern as the first parameter, and the string to be analyzed as the second parameter.
# * The second way is to compile the regex, and then use the methods of the created object to analyze a string passed as an argument. This method speeds up processing when a regex is used several times.

# %%
import re

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Searches the pattern in the previous string and return a `MatchObject` if matches are found,
# otherwise returns `None`.
print(re.search(pattern, string))
# Out:
# <re.Match object; span=(1, 2), match=' '>

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Cuts the string according to the occurrence of the pattern.
print(re.split(pattern, string))
# Out:
# ['I', 'am', 'fine', '!', 'There', 'are', 'still', '6', 'months', 'left', ':()']

# %% [markdown]
# ### A little syntax
#
#     [xy]  A possible segment list. Example[abc] equals: a, b or c
#
#     (x|y) Indicates a multiple choice type (ps|ump) equals "ps" OR "UMP"
#
#     \d    the segment is composed only of numbers, which is equivalent to[0-9].
#
#     \D    the segment is not composed of numbers, which is equivalent to[^0-9].
#
#     \s    A space, which is equivalent to [ \t\n\r\r\f\v].
#
#     \S    No space, which is equivalent to[^ ^ \t\n\r\f\v].
#
#     \w    Alphanumeric presence, which is equivalent to[a-zA-Z0-9_].
#
#     \W    No alphanumeric presence[^a-zA-Z0-9_].
#
#     \     Is an escape character

# %% [markdown]
# Let's try it.
#
# If the answer is not `None`, it means the match matches. GREY is indeed a name beginning with GR followed by a character and ending with Y.

# %%
print(re.match("GR(.)?Y", "GREY"))
# (.)? means that we expect 0 or 1 character.
# 0 or 1 because of the `?` following the character `.`, which means any character
# Out:
# <re.Match object; span=(0, 4), match='GREY'>

# %%
pattern = "GR(.)?Y"
string = "GREY"

result = re.match(pattern, string)
print(result)

# It is equal to
compiled = re.compile(pattern)
result = compiled.match(string)
print(result)
# Out:
# <re.Match object; span=(0, 4), match='GREY'>
# <re.Match object; span=(0, 4), match='GREY'>

# %%
#  So in a loop the second syntax is nicer
pattern = "GR(.)?Y"
compiled = re.compile(pattern)
l = ["GREY 'S", "GRAY", "GREYISH", "A GREY"]

for elem in l:
    result = compiled.match(elem)
    print(elem, result)
# Out:
# GREY 'S <re.Match object; span=(0, 4), match='GREY'>
# GRAY <re.Match object; span=(0, 4), match='GRAY'>
# GREYISH <re.Match object; span=(0, 4), match='GREY'>
# A GREY None

# %% [markdown]
# In the following, we search for specific expressions in a string.

# %%
print(re.findall("GR(.)?Y", "GREY"))
# so here we are looking for a unique element (.)? between GR and Y
# Out:
# ['E']

# %%
# Ditto for two characters to be found
re.findall("G(.)?(.)?Y", "GREY")
# Out:
# [('R', 'E')]

# %% [markdown]
# To keep only numbers.

# %%
# Only numbers
print(re.findall("([0-9]+)", "Hello I live on the 7th floor of 220 street of sims"))
# "+" Means 1 or more characters
# Out:
# ['7', '220']

# %% [markdown]
# And conversely, if you only want to keep the words.

# %%
# Only words
print(re.findall("([A-z]+)", "Hello I live on the 7th floor of 220 street of sims"))
# Out:
# ['Hello', 'I', 'live', 'on', 'the', 'th', 'floor', 'of', 'street', 'of', 'sims']

# %% [markdown]
# ### Stop, we recap !

# %% [markdown]
# Character | Meaning
# :-------------------------:|:-------------------------:
# **.** | **Refers to any character.**
# **^** | **Indicates that the beginning of the string must match <br/> (i.e. a string can only match if it starts in the same way, <br /> if it is preceded by spaces or a line break)**
# **$** | **Indicates that the end of the chain must match <br /> (the same remark as above applies, but at the end level).**
# **{n}**|**Indicates that the previous character must be repeated n times.**
# **{n, m}**|**Indicates that the previous character must be repeated between n and m times.**
#  *| **The previous character can be repeated none or several times. <br />For example, ab* may correspond to: a, ab, or a followed by any number of b.**
# **+**|**The previous character can be repeated once or several times. <br/>For example, to ab+ corresponds an a followed by any number of b.**
# **?**|**The previous character can be repeated zero or once.<br /> For example, to ab? correspond ab and a.**
# **\w** | **it corresponds to any alphabetical character, it is equivalent to [a-zA-Z0-9_].**
# **\W** | **it corresponds to everything that is not an alphabetical character.**
# **\d** | **it corresponds to any numeric character, i.e. it is equivalent to[0-9].**
# **\D** | **it corresponds to everything that is not a numeric character.**

# %% [markdown]
# ![alt text](http://www.codercaste.com/wp-content/uploads/2013/01/regex.gif)

# %% [markdown]
# ### Some useful resources
# http://www.rexegg.com/regex-quickstart.html
# http://www.dreambank.net/regex.html#examples
# https://pythex.org/ *(Pythex is a real-time regular expression editor for Python, a quick way to test your regular expressions.)*
# https://regex101.com/
# *(Regex101 is online regex editor and debugger. Regex101 allows you to create, debug, test and have your expressions explained for PHP, PCRE, Python, Golang and JavaScript. The website also features a community where you can share useful expressions.)*

# %% [markdown]
# #### How to check that the entered string is that of a number ?

# %%
number = input("Your number : ")
if re.match("^[0-9]+$", number):
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number.")
# Out:
# The string entered is a number.

# %% [markdown]
# Another way

# %%
compiled = re.compile("^[0-9]+$")
if compiled.search(number) is not None:
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number")
# Out:
# The string entered is a number.

# %% [markdown]
# ## Drill

# %% [markdown]
# **1. Create a regex that finds integers without size limit.**

# %%
s = "sssgdds8sfsfs"
pattern = r"\d"
print(re.findall(pattern,s))
# Out:
# ['8']

# %% [markdown]
# **2. Create a regex that finds negative integers without size limit.**

# %%
s = "sssgdds-8sfsfs"
pattern = r"-\d"
print(re.findall(pattern,s))
# Out:
# ['-8']

# %% [markdown]
# **3. Create a regex that finds (positive or negative) integers without size limit.**

# %%
s = "sssgdds-8s8fsfs"
pattern = r"-?\d"
print(re.findall(pattern,s))
# Out:
# ['-8', '8']

# %% [markdown]
# **4. Capture all the numbers of the following sentence :**

# %%
text = "21 scouts and 3 tanks fought against 4,003 protestors, so the manager was not 100.00% happy."
pattern = r"\d*[\.\,]?\d+"
print(re.findall(pattern, text))
# Out:
# ['21', '3', '4,003', '100.00']

# %% [markdown]
# **5. Find all words that end with 'ly'.**

# %%
text = "He had prudently disguised himself but was quickly captured by the police."
pattern = r"[a-z]+ly"
print(re.findall(pattern, text))
# Out:
# ['prudently', 'quickly']

# %% [markdown]
# **6. License plate number**
# A license plate consists of 2 capital letters, a dash ('-'), 3 digits, a dash ('-') and finally 2 capital letters. Write a script to check that an input string is a license plate.
# If it's correct, print `"good"`. If it's not correct, print `"Not good"`.

# %%
plate = input("Enter your license plate number: ")
pattern = r"[A-Z]{2}-[0-9]{3}-[A-Z]{2}"
if re.match(pattern, plate):
    print("good")
else:
    print("Not good")
# Out:
# Not good

# %% [markdown]
# **7 . Address IPV4**
# An IPv4 address is composed of 4 numbers between 0 and 255 separated by '.'
# Write a script to verify that a string entered is that of an IPv4 address.

# %%
ip = input("Enter your IP address :")
def verify_ip(ip_address):
    pattern = r"[0-9]{3}\.[0-9]{3}\.[0-9]{3}\.[0-9]{3}"
    if re.match(pattern, ip_address):
        check_ip = ip_address.split(".")
        for part in check_ip:
            if int(part) > 255:
                print("Not a valid IPv4 address.")
                return False
            else:
                print("Good")
                return True
    else:
        print("Not a valid IPv4 address.")
        return False
print(verify_ip(ip))
# Out:
# Good
# True

# %% [markdown]
# **8. Valid Mail**
# An email is composed of alphanumeric characters followed by `@` and a domain name.
# Write a script that checks that the string entered by a user is indeed that of an email, otherwise ask him to re-enter it again (until he gets a valid email).

# %%
def mail_validator():
    pattern = r"\b[A-Za-z0-9._-]+@[a-z]+.[a-z]{2,}\b"
    while True:
        mail = input("Enter your e-mail:")
        if re.match(pattern, mail):
            return True
        else:
            print("Not a valid mail address.")

# %% [markdown]
# "**9. Valid Password**
# Write an additional script that verifies the password (obviously if the email is valid) where the only specificity of the password is that it has to contain at least 6 characters.

# %%
def pass_validator():
    mail_validator()
    pass_pattern = r"[A-Za-z0-9]{6,}"
    while True:
        password = input("Enter your password :")
        if re.match(pass_pattern, password):
            return True
        else:
            print("Not a valid password.")

pass_validator()
# Out:
# Not a valid mail address.
# Not a valid password.
# True

# %% [markdown]
# **10. Valid Password bis**
# The password must now contain at least 6 characters AND
#
# - at least one lowercase letter AND
# - at least one uppercase letter AND
# - at least one number AND
# - at least one special character (among `$#@`).

# %%
def stronger_pass_validator():
    mail_validator()
    pass_pattern = r"^(?=.*[A-Z])(?=.*[a-z])(?=.*[0-9])(?=.*[$#@]).{6,}$"
    while True:
        password = input("Enter your password :")
        if re.match(pass_pattern, password):
            return True
        else:
            print("Not a valid password.")

stronger_pass_validator()
# Out:
# True

# %% [markdown]
# **11. Search by groups**
# It is possible to search by groups, and it is very powerful!
# `?P<x>\w+` means the capture of a "group" named `x`, this group is composed of at least (`+`) one alphanumeric  character `(\w)`.

# %%
m = re.search(
    r"Welcome to (?P<where>\w+) ! You are (?P<age>\d+) years old ?",
    "Welcome to Olivier ! You are 32 years old ?",
)
print(m.group("where"))
print(m.group("age"))
# Out:
# Olivier
# 32

# %%
# Another Example
m = re.search(
    r"^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)",
    "audrey.boulevart@benextcomapgny.com",
)
if m is not None:
    print(m.group("who"))
    print(m.group("who2"))
    print(m.group("operator"))
    print(m.group("zone"))
# Out:
# audrey
# boulevart
# benextcomapgny
# com

# %% [markdown]
# Load the file `./data/mail.txt` and clean it with the regex. The goal is to retrieve the last name, first name, operator and zone, as in the previous example. Store each of those into their own separate list.

# %%
list_mail = open("./data/mail.txt")
for line in list_mail:
    test = re.search(
    r"^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)",
    line
)
    if test is not None:
        print(list(test.group("who", "who2", "operator", "zone")))
# Out:
# ['aikin', 'joe', 'odul', 'xyz']
# ['moore', '', 'imail', 'gov']
# ['halknutson', '', 'email', 'xyz']
# ['alexnorquist', '', 'proton', 'com']
# ['monte', 'hylan', 'belgaximus', 'net']
# ['knutsondan', '', 'belgaximus', 'org']
# ['lepage', '', 'gaagle', 'xyz']
# ['chapman_ben', '', 'napster', 'hu']
# ['upson1544', '', 'youhoo', 'hu']
# ['552966959', '', 'belgaximus', 'hu']
# ['soloman_ziegler', '', 'email', 'tech']
# ['ortiz', 'mark', 'napster', 'me']
# ['ashwoon_hank', '', 'imail', 'io']
# ['pettigrew', '', 'proton', 'hu']
# ['doranedward', '', 'napster', 'net']
# ['mills_joe', '', 'imail', 'xyz']
# ['yang', '', 'email', 'hu']
# ['ike', '', 'ecoin', 'io']
# ['larrytrebil', '', 'email', 'org']
# ['davis_ike', '', 'odul', 'io']
# ['davidsonhal', '', 'hotmoille', 'apple']
# ['john8733', '', 'youhoo', 'com']
# ['johnfletcher', '', 'youhoo', 'me']
# ['cataldi_larry', '', 'napster', 'com']
# ['rogerfietzer', '', 'imail', 'apple']
# ['edward4185', '', 'gaagle', 'gov']
# ['hancock_matthew', '', 'belgaximus', 'gov']
# ['solberg_cast', '', 'gaagle', 'apple']
# ['georgepak', '', 'gaagle', 'me']
# ['ike', '', 'ecoin', 'com']
# ['tapia_quinn', '', 'gaagle', 'io']
# ['795419860', '', 'imail', 'tech']
# ['jack', '', 'gaagle', 'apple']
# ['joe', '', 'ecoin', 'tech']
# ['ben', 'yang', 'ecoin', 'com']
# ['pettigrewgeorge', '', 'odul', 'me']
# ['boyd_carl', '', 'napster', 'me']
# ['yocum_mark', '', 'youhoo', 'com']
# ['george59', '', 'ecoin', 'gov']
# ['johnsen2201', '', 'imail', 'io']
# ['schutzlarry', '', 'email', 'apple']
# ['quizoz', 'joe', 'napster', 'tech']
# ['matthew8227', '', 'hotmoille', 'me']
# ['georgemoody', '', 'hotmoille', 'com']
# ['lawicki589', '', 'hotmoille', 'me']
# ['doran7947', '', 'gaagle', 'tech']
# ['mark', '', 'email', 'io']
# ['waltermartin', '', 'ecoin', 'gov']
# ['george', '', 'hotmoille', 'hu']
# ['ferry', 'victor', 'gaagle', 'com']
# ['fred', 'weiss', 'odul', 'tech']
# ['jurgensonpeter', '', 'proton', 'tech']
# ['stevefietzer', '', 'ecoin', 'tech']
# ['sonderling_caswell', '', 'napster', 'tech']
# ['johnsen', 'walter', 'odul', 'net']
# ['mccormack', '', 'napster', 'xyz']
# ['roberts', 'hank', 'proton', 'net']
# ['valente', '', 'gaagle', 'xyz']
# ['ory_walter', '', 'proton', 'hu']
# ['tyirwin', '', 'proton', 'tech']
# ['paulferry', '', 'hotmoille', 'com']
# ['george', '', 'youhoo', 'gov']
# ['mccormack', 'carl', 'imail', 'xyz']
# ['851886792', '', 'youhoo', 'hu']
# ['zeaser_aaron', '', 'belgaximus', 'apple']
# ['adam', '', 'proton', 'net']
# ['tisler', 'roger', 'hotmoille', 'tech']
# ['severson_george', '', 'proton', 'org']
# ['otto', 'nuttle', 'proton', 'hu']
# ['illingsworth', '', 'belgaximus', 'gov']
# ['alex685', '', 'hotmoille', 'com']
# ['hancock_valente', '', 'hotmoille', 'net']
# ['paul9581', '', 'email', 'tech']
# ['sawyer_chambers', '', 'belgaximus', 'xyz']
# ['johnsen', 'tim', 'email', 'gov']
# ['aaron', 'roberts', 'imail', 'gov']
# ['schiebel2392', '', 'hotmoille', 'xyz']
# ['mccormackedward', '', 'proton', 'com']
# ['tapia1876', '', 'imail', 'tech']
# ['quizoz9628', '', 'belgaximus', 'apple']
# ['rogerstahl', '', 'odul', 'apple']
# ['schutz_johnsen', '', 'ecoin', 'tech']
# ['carlupson', '', 'napster', 'me']
# ['larry349', '', 'odul', 'me']
# ['matthew', 'linde', 'youhoo', 'tech']
# ['mcginnis', '', 'imail', 'xyz']
# ['nugent_jack', '', 'gaagle', 'hu']
# ['wagle_john', '', 'napster', 'gov']
# ['chapmannathan', '', 'youhoo', 'org']
# ['hal536', '', 'napster', 'net']
# ['472510707', '', 'odul', 'io']
# ['thomas', 'casal', 'hotmoille', 'com']
# ['adamillingsworth', '', 'youhoo', 'xyz']
# ['peterstahl', '', 'gaagle', 'me']
# ['victortandy', '', 'youhoo', 'hu']
# ['adam', 'sellon', 'email', 'tech']
# ['ike3831', '', 'proton', 'apple']
# ['timfletcher', '', 'imail', 'xyz']
# ['frank', 'schickowski', 'gaagle', 'io']
# ['566486749', '', 'email', 'net']
# ['675340599', '', 'proton', 'org']
# ['davis_nathan', '', 'ecoin', 'com']
# ['253159777', '', 'gaagle', 'net']
# ['edwardschutz', '', 'hotmoille', 'net']
# ['sagar_carl', '', 'hotmoille', 'org']
# ['331837931', '', 'napster', 'me']
# ['aaronbongard', '', 'odul', 'xyz']
# ['ty9516', '', 'belgaximus', 'net']
# ['schustersteve', '', 'proton', 'tech']
# ['moody_schiebel', '', 'hotmoille', 'me']
# ['soloman_ramachandran', '', 'gaagle', 'org']
# ['victor630', '', 'hotmoille', 'hu']
# ['yang_trebil', '', 'imail', 'me']
# ['hoffman_zeller', '', 'imail', 'me']
# ['ripka_thomas', '', 'email', 'tech']
# ['vader', 'hal', 'belgaximus', 'org']
# ['ottochambers', '', 'imail', 'io']
# ['tylulloff', '', 'email', 'gov']
# ['263935905', '', 'youhoo', 'tech']
# ['carlvail', '', 'napster', 'me']
# ['hanktisler', '', 'ecoin', 'com']
# ['uddin1510', '', 'email', 'org']
# ['mccormack', 'carl', 'proton', 'net']
# ['vader', '', 'proton', 'me']
# ['nelsonmark', '', 'imail', 'xyz']
# ['stahl', '', 'odul', 'apple']
# ['timirwin', '', 'hotmoille', 'me']
# ['davis9134', '', 'imail', 'tech']
# ['davidziegler', '', 'imail', 'tech']
# ['carl1959', '', 'youhoo', 'apple']
# ['alexkeller', '', 'gaagle', 'com']
# ['469322116', '', 'hotmoille', 'tech']
# ['monte7207', '', 'gaagle', 'hu']
# ['fredtiernan', '', 'email', 'net']
# ['fietzer', '', 'gaagle', 'org']
# ['benquinn', '', 'proton', 'com']
# ['hal', 'weiss', 'email', 'xyz']
# ['sweeney', 'otto', 'gaagle', 'apple']
# ['fletcher_monte', '', 'email', 'com']
# ['woothomas', '', 'napster', 'tech']
# ['walter', '', 'napster', 'io']
# ['dinkins', '', 'proton', 'gov']
# ['950099319', '', 'imail', 'net']
# ['roger', 'myers', 'gaagle', 'io']
# ['tim', 'trusela', 'hotmoille', 'gov']
# ['sawyer', 'adam', 'belgaximus', 'org']
# ['ben', 'jagtap', 'napster', 'tech']
# ['carlmills', '', 'ecoin', 'me']
# ['markboyd', '', 'belgaximus', 'apple']
# ['887934540', '', 'email', 'net']
# ['ortizjack', '', 'gaagle', 'gov']
# ['roberts_myers', '', 'email', 'tech']
# ['soloman8370', '', 'odul', 'gov']
# ['alex3716', '', 'ecoin', 'me']
# ['tim', '', 'proton', 'me']
# ['thompson85', '', 'proton', 'hu']
# ['reyes', 'jack', 'email', 'hu']
# ['dinkinsroger', '', 'youhoo', 'apple']
# ['mills9634', '', 'odul', 'xyz']
# ['821464747', '', 'odul', 'gov']
# ['valente_hydinger', '', 'hotmoille', 'tech']
# ['schiebel1467', '', 'proton', 'io']
# ['larryschiebel', '', 'ecoin', 'net']
# ['jagtap', 'fred', 'proton', 'gov']
# ['edward', 'haworth', 'imail', 'com']
# ['matthewcataldi', '', 'youhoo', 'net']
# ['zeller', '', 'email', 'org']
# ['duffman', '', 'email', 'net']
# ['ottoortiz', '', 'youhoo', 'xyz']
# ['delorenzo', '', 'ecoin', 'me']
# ['miller_keller', '', 'email', 'org']
# ['illingsworth', '', 'youhoo', 'gov']
# ['nelson', '', 'odul', 'tech']
# ['rogers_john', '', 'gaagle', 'tech']
# ['tyresnick', '', 'imail', 'io']
# ['hal', 'yang', 'napster', 'xyz']
# ['tiernan6950', '', 'belgaximus', 'tech']
# ['mills', '', 'belgaximus', 'xyz']
# ['casal', 'hank', 'proton', 'xyz']
# ['hankupson', '', 'odul', 'xyz']
# ['irwin_yang', '', 'gaagle', 'gov']
# ['napier', 'aaron', 'email', 'org']
# ['edward', 'schickowski', 'youhoo', 'xyz']
# ['rogers_lawicki', '', 'gaagle', 'apple']
# ['tapia_upson', '', 'ecoin', 'me']
# ['uddin_yocum', '', 'gaagle', 'hu']
# ['bongardroger', '', 'napster', 'net']
# ['victor', '', 'youhoo', 'gov']
# ['ty', 'schwager', 'napster', 'io']
# ['paultiernan', '', 'youhoo', 'xyz']
# ['roger836', '', 'gaagle', 'tech']
# ['pettigrew', 'victor', 'email', 'io']
# ['johnsen4863', '', 'gaagle', 'apple']
# ['890280316', '', 'ecoin', 'me']
# ['weinstein', 'roger', 'imail', 'io']
# ['alexschmitt', '', 'odul', 'org']
# ['dan', 'uddin', 'ecoin', 'apple']
# ['steve', 'stahl', 'hotmoille', 'me']
# ['matthewfrick', '', 'hotmoille', 'com']
# ['237336989', '', 'email', 'io']
# ['larry6016', '', 'youhoo', 'org']
# ['otto5489', '', 'gaagle', 'tech']
# ['bongard_ty', '', 'ecoin', 'xyz']
# ['169102677', '', 'gaagle', 'me']
# ['upson', 'hal', 'gaagle', 'io']
# ['hal', '', 'hotmoille', 'gov']
# ['sonderling_mark', '', 'belgaximus', 'me']
# ['430581778', '', 'hotmoille', 'com']
# ['walterkassing', '', 'napster', 'tech']
# ['victorceledon', '', 'ecoin', 'xyz']
# ['kassing', '', 'hotmoille', 'apple']
# ['duffman6005', '', 'youhoo', 'hu']
# ['frank', 'ventotla', 'belgaximus', 'io']
# ['uddinotto', '', 'youhoo', 'org']
# ['703979481', '', 'ecoin', 'apple']
# ['paul', 'nugent', 'ecoin', 'apple']
# ['nugent', '', 'proton', 'org']
# ['alex', '', 'odul', 'tech']
# ['aaronsweeney', '', 'ecoin', 'apple']
# ['knutson_celedon', '', 'hotmoille', 'xyz']
# ['tydoran', '', 'belgaximus', 'org']
# ['millerhal', '', 'hotmoille', 'org']
# ['adamnuttle', '', 'youhoo', 'hu']
# ['ashwoon8609', '', 'youhoo', 'tech']
# ['mcginnis_reardon', '', 'youhoo', 'org']
# ['ramachandran', 'mark', 'proton', 'com']
# ['monteshaffer', '', 'proton', 'tech']
# ['monte', '', 'proton', 'gov']
# ['pettigrew9750', '', 'proton', 'com']
# ['yocum_dan', '', 'napster', 'xyz']
# ['darnell8483', '', 'email', 'xyz']
# ['pettigrewlarry', '', 'imail', 'tech']
# ['ben5039', '', 'hotmoille', 'tech']
# ['mcginnis', 'dan', 'gaagle', 'tech']
# ['roger', 'vogal', 'email', 'xyz']
# ['adamtisler', '', 'gaagle', 'xyz']
# ['matthew3420', '', 'hotmoille', 'tech']
# ['john8770', '', 'napster', 'hu']
# ['hesch_zeller', '', 'email', 'apple']
# ['christensen_ben', '', 'proton', 'com']
# ['walter', 'soulis', 'email', 'com']
# ['ben8671', '', 'proton', 'tech']
# ['frankjagtap', '', 'napster', 'com']
# ['peternuttle', '', 'napster', 'gov']
# ['victor8847', '', 'ecoin', 'io']
# ['ferry', 'paul', 'imail', 'org']
# ['690377034', '', 'gaagle', 'apple']
# ['lepageroger', '', 'proton', 'gov']
# ['john', 'zeaser', 'imail', 'gov']
# ['4709006', '', 'napster', 'tech']
# ['kaskel5284', '', 'belgaximus', 'org']
# ['hanktiernan', '', 'youhoo', 'io']
# ['ripka2474', '', 'hotmoille', 'tech']
# ['cataldi_matthew', '', 'odul', 'me']
# ['steve6967', '', 'odul', 'hu']
# ['irwincarl', '', 'belgaximus', 'gov']
# ['wakefieldjoe', '', 'ecoin', 'org']
# ['nathansagar', '', 'email', 'apple']
# ['hydinger_larry', '', 'odul', 'xyz']
# ['frank', 'yates', 'proton', 'gov']
# ['schuster5868', '', 'youhoo', 'tech']
# ['rogerschwager', '', 'imail', 'tech']
# ['163622426', '', 'imail', 'com']
# ['baxstercarl', '', 'proton', 'net']
# ['aikin', '', 'napster', 'gov']
# ['tisler_reyes', '', 'imail', 'io']
# ['monte1021', '', 'hotmoille', 'gov']
# ['quizoz', '', 'proton', 'apple']
# ['vail_soukup', '', 'proton', 'apple']
# ['thomassonderling', '', 'napster', 'com']
# ['frankaikin', '', 'odul', 'io']
# ['aaronillingsworth', '', 'hotmoille', 'com']
# ['859491337', '', 'youhoo', 'hu']
# ['paul', 'eastman', 'napster', 'io']
# ['waltertisler', '', 'belgaximus', 'apple']
# ['ferro_caswell', '', 'hotmoille', 'com']
# ['george', '', 'gaagle', 'hu']
# ['timorwig', '', 'email', 'io']
# ['jones', '', 'napster', 'net']
# ['hoffman', 'roger', 'youhoo', 'xyz']
# ['matthew', 'trusela', 'imail', 'io']
# ['larry2207', '', 'imail', 'apple']
# ['rice_sonderling', '', 'gaagle', 'hu']
# ['nuttleben', '', 'proton', 'net']
# ['dewalt_martin', '', 'belgaximus', 'io']
# ['ikekassing', '', 'gaagle', 'com']
# ['240044289', '', 'odul', 'tech']
# ['otto', '', 'napster', 'hu']
# ['ferro', 'edward', 'imail', 'xyz']
# ['hankanderson', '', 'imail', 'net']
# ['dan', 'deitz', 'belgaximus', 'gov']
# ['orwig_sweeney', '', 'proton', 'me']
# ['bencaswell', '', 'youhoo', 'apple']
# ['chambers', 'victor', 'email', 'net']
# ['579081959', '', 'ecoin', 'hu']
# ['moore', 'fred', 'imail', 'com']
# ['thomas', '', 'gaagle', 'me']
# ['orwig', '', 'imail', 'tech']
# ['hal', '', 'imail', 'me']
# ['alex9835', '', 'email', 'org']
# ['nathanripka', '', 'belgaximus', 'com']
# ['sonderling', '', 'napster', 'xyz']
# ['matthew', 'duffman', 'gaagle', 'net']
# ['monte2098', '', 'odul', 'io']
# ['victor', 'tiernan', 'email', 'hu']
# ['822140569', '', 'proton', 'net']
# ['joe', '', 'hotmoille', 'com']
# ['matthew', '', 'gaagle', 'tech']
# ['walter', '', 'napster', 'net']
# ['yocum_ventotla', '', 'email', 'tech']
# ['vader_sweeney', '', 'ecoin', 'hu']
# ['orwig_mills', '', 'youhoo', 'me']
# ['roger7781', '', 'odul', 'io']
# ['dugan_thomas', '', 'odul', 'tech']
# ['vader', '', 'gaagle', 'apple']
# ['otto', '', 'gaagle', 'xyz']
# ['sawyer_johnson', '', 'hotmoille', 'apple']
# ['george', '', 'hotmoille', 'net']
# ['anderson', 'john', 'hotmoille', 'gov']
# ['hydinger_aaron', '', 'ecoin', 'com']
# ['monte', '', 'hotmoille', 'com']
# ['severson_aaron', '', 'proton', 'io']
# ['jack', 'fletcher', 'napster', 'com']
# ['jurgensonpaul', '', 'ecoin', 'io']
# ['438861443', '', 'ecoin', 'gov']
# ['aaron', '', 'proton', 'com']
# ['doran', '', 'email', 'org']
# ['sweeney_nathan', '', 'proton', 'xyz']
# ['celedon_bauer', '', 'gaagle', 'net']
# ['ben', 'bongard', 'hotmoille', 'com']
# ['421931320', '', 'belgaximus', 'gov']
# ['cataldi_haworth', '', 'gaagle', 'com']
# ['290273746', '', 'hotmoille', 'me']
# ['tybauer', '', 'imail', 'apple']
# ['larrymyers', '', 'hotmoille', 'tech']
# ['orymonte', '', 'youhoo', 'me']
# ['lawless', 'fred', 'imail', 'tech']
# ['fredroot', '', 'odul', 'com']
# ['napier3011', '', 'email', 'com']
# ['tynapier', '', 'napster', 'org']
# ['ty3947', '', 'ecoin', 'io']
# ['ben', '', 'odul', 'com']
# ['sawyer', '', 'imail', 'com']
# ['schwager9365', '', 'hotmoille', 'io']
# ['aaronlewis', '', 'proton', 'gov']
# ['nelson_jack', '', 'gaagle', 'apple']
# ['upson1390', '', 'proton', 'apple']
# ['871781143', '', 'odul', 'org']
# ['269062053', '', 'youhoo', 'me']
# ['victorreardon', '', 'proton', 'com']
# ['soloman', '', 'gaagle', 'tech']
# ['aaronsagar', '', 'ecoin', 'org']
# ['alex', '', 'odul', 'hu']
# ['ike5340', '', 'email', 'apple']
# ['120987413', '', 'email', 'tech']
# ['ziegler', '', 'hotmoille', 'hu']
# ['tisler', 'monte', 'odul', 'gov']
# ['victorquinn', '', 'gaagle', 'io']
# ['aaronebner', '', 'youhoo', 'apple']
# ['fred', 'moore', 'gaagle', 'net']
# ['adam3605', '', 'gaagle', 'io']
# ['stevewagle', '', 'napster', 'com']
# ['montedeitz', '', 'napster', 'hu']
# ['orwig_john', '', 'email', 'org']
# ['roger', '', 'napster', 'apple']
# ['edwarddeitz', '', 'gaagle', 'tech']
# ['273554425', '', 'proton', 'gov']
# ['edward', 'darnell', 'proton', 'org']
# ['marknapier', '', 'youhoo', 'com']
# ['upson', 'peter', 'gaagle', 'me']
# ['john', 'stahl', 'email', 'xyz']
# ['duffman', 'aaron', 'proton', 'hu']
# ['jenson', '', 'hotmoille', 'hu']
# ['rogermcginnis', '', 'napster', 'tech']
# ['soukup', '', 'belgaximus', 'gov']
# ['soloman', '', 'odul', 'apple']
# ['877692701', '', 'napster', 'hu']
# ['tandyaaron', '', 'ecoin', 'tech']
# ['ingramthomas', '', 'youhoo', 'xyz']
# ['aaron8129', '', 'belgaximus', 'apple']
# ['fredmills', '', 'imail', 'net']
# ['haljagtap', '', 'hotmoille', 'org']
# ['soloman_eastman', '', 'email', 'com']
# ['montelewis', '', 'gaagle', 'org']
# ['peter', 'mccord', 'gaagle', 'com']
# ['roger', '', 'proton', 'io']
# ['paiser', '', 'youhoo', 'gov']
# ['ty', '', 'imail', 'gov']
# ['roberts', '', 'youhoo', 'gov']
# ['958642438', '', 'email', 'net']
# ['boyd3853', '', 'belgaximus', 'net']
# ['soloman_nathan', '', 'youhoo', 'gov']
# ['92101346', '', 'proton', 'tech']
# ['chambers', 'mark', 'napster', 'com']
# ['nuttleedward', '', 'gaagle', 'apple']
# ['adamrice', '', 'ecoin', 'net']
# ['fred937', '', 'odul', 'com']
# ['ben', '', 'belgaximus', 'hu']
# ['dan', '', 'gaagle', 'gov']
# ['walterturco', '', 'imail', 'tech']
# ['roger', 'fletcher', 'belgaximus', 'xyz']
# ['adamziegler', '', 'youhoo', 'org']
# ['275056493', '', 'youhoo', 'xyz']
# ['peterlewis', '', 'belgaximus', 'gov']
# ['jack', '', 'imail', 'net']
# ['george3788', '', 'gaagle', 'com']
# ['zeller', 'roger', 'youhoo', 'me']
# ['ottoschmitt', '', 'odul', 'org']
# ['tiernan', 'jack', 'ecoin', 'apple']
# ['schutz_knutson', '', 'gaagle', 'gov']
# ['hal', 'severson', 'youhoo', 'hu']
# ['mccord_ferry', '', 'odul', 'gov']
# ['uddin2208', '', 'youhoo', 'me']
# ['roger6727', '', 'imail', 'me']
# ['schlicht670', '', 'hotmoille', 'net']
# ['steve', '', 'odul', 'xyz']
# ['sawyer', '', 'napster', 'apple']
# ['soulis2863', '', 'belgaximus', 'hu']
# ['sonderling4257', '', 'email', 'org']
# ['upson_paul', '', 'gaagle', 'org']
# ['timtrebil', '', 'belgaximus', 'tech']
# ['104036307', '', 'ecoin', 'me']
# ['frankupson', '', 'imail', 'apple']
# ['fietzeralex', '', 'youhoo', 'hu']
# ['solomanjohn', '', 'youhoo', 'apple']
# ['peter6564', '', 'email', 'hu']
# ['johnsen2199', '', 'gaagle', 'tech']
# ['lepage_edward', '', 'ecoin', 'net']
# ['dugelman8872', '', 'odul', 'me']
# ['vanderpoel_hydinger', '', 'odul', 'xyz']
# ['ripka2789', '', 'email', 'io']
# ['larry1596', '', 'imail', 'tech']
# ['moorety', '', 'napster', 'io']
# ['roger', 'fietzer', 'belgaximus', 'apple']
# ['soulispeter', '', 'imail', 'io']
# ['ty3503', '', 'imail', 'apple']
# ['lepage_ostrander', '', 'hotmoille', 'io']
# ['vanderpoel_dan', '', 'gaagle', 'net']
# ['darnellty', '', 'gaagle', 'org']
# ['kalleg_david', '', 'belgaximus', 'gov']
# ['steve', '', 'odul', 'apple']
# ['lulloff', 'matthew', 'proton', 'hu']
# ['chamberspaul', '', 'odul', 'com']
# ['bencasal', '', 'odul', 'io']
# ['vader_john', '', 'napster', 'org']
# ['lepage6698', '', 'email', 'hu']
# ['zeller_ziegler', '', 'ecoin', 'tech']
# ['walterschwager', '', 'email', 'io']
# ['christensenty', '', 'napster', 'xyz']
# ['severson_woo', '', 'proton', 'org']
# ['vailjoe', '', 'imail', 'io']
# ['dewalt_adam', '', 'proton', 'net']
# ['ziegler8928', '', 'imail', 'net']
# ['wakefield_edward', '', 'youhoo', 'tech']
# ['nugent1331', '', 'proton', 'xyz']
# ['celedon_severson', '', 'odul', 'me']
# ['ty', 'tiernan', 'odul', 'gov']
# ['schmitt', '', 'imail', 'org']
# ['aaronwagle', '', 'email', 'tech']
# ['woo', '', 'hotmoille', 'io']
# ['tim9542', '', 'hotmoille', 'tech']
# ['john5694', '', 'email', 'me']
# ['sagar_nathan', '', 'belgaximus', 'xyz']
# ['larry', 'dinkins', 'proton', 'com']
# ['severson', 'steve', 'imail', 'hu']
# ['fredturco', '', 'odul', 'net']
# ['edward', '', 'youhoo', 'com']
# ['reyes', 'roger', 'ecoin', 'tech']
# ['reamer_tim', '', 'hotmoille', 'org']
# ['steve3131', '', 'email', 'tech']
# ['wagner9136', '', 'gaagle', 'apple']
# ['davis_bowers', '', 'belgaximus', 'me']
# ['edward9079', '', 'napster', 'net']
# ['283141330', '', 'gaagle', 'hu']
# ['tyduffman', '', 'hotmoille', 'hu']
# ['walterhydinger', '', 'ecoin', 'io']
# ['ben9635', '', 'odul', 'apple']
# ['vanderpoel', 'mark', 'odul', 'tech']
# ['delorenzo', 'jack', 'napster', 'xyz']
# ['nathan', 'woo', 'proton', 'org']
# ['victorvader', '', 'belgaximus', 'tech']
# ['ben', 'irwin', 'email', 'net']
# ['eastman_larry', '', 'napster', 'apple']
# ['sweeney_alex', '', 'hotmoille', 'hu']
# ['hydinger_otto', '', 'email', 'apple']
# ['peter2600', '', 'belgaximus', 'apple']
# ['eastman_adam', '', 'imail', 'xyz']
# ['thomas', '', 'gaagle', 'com']
# ['hal', '', 'napster', 'gov']
# ['paulresnick', '', 'gaagle', 'me']
# ['682804922', '', 'ecoin', 'hu']
# ['myerspeter', '', 'youhoo', 'me']
# ['fred67', '', 'youhoo', 'net']
# ['edwardhoffman', '', 'napster', 'apple']
# ['thompson_orwig', '', 'napster', 'com']
# ['ike', 'stahl', 'hotmoille', 'apple']
# ['markhoffman', '', 'imail', 'org']
# ['669214282', '', 'imail', 'com']
# ['hank', '', 'proton', 'com']
# ['pettigrew_bauer', '', 'youhoo', 'hu']
# ['nuttle_upson', '', 'ecoin', 'com']
# ['danziegler', '', 'hotmoille', 'tech']
# ['nugent_uddin', '', 'belgaximus', 'com']
# ['alex', 'mccormack', 'hotmoille', 'com']
# ['larry', '', 'youhoo', 'hu']
# ['deitzdan', '', 'imail', 'apple']
# ['alexhesch', '', 'odul', 'gov']
# ['dinkinscarl', '', 'napster', 'io']
# ['edward', '', 'imail', 'tech']
# ['43720854', '', 'ecoin', 'net']
# ['tiernanotto', '', 'hotmoille', 'xyz']
# ['220923632', '', 'proton', 'xyz']
# ['vader_larry', '', 'belgaximus', 'io']
# ['lepage', '', 'odul', 'io']
# ['woofrank', '', 'youhoo', 'hu']
# ['413352781', '', 'imail', 'xyz']
# ['walterschutz', '', 'imail', 'apple']
# ['ike', '', 'proton', 'xyz']
# ['tislerjohn', '', 'napster', 'org']
# ['ebner_chapman', '', 'email', 'me']
# ['jurgenson', 'mark', 'odul', 'net']
# ['40053022', '', 'belgaximus', 'apple']
# ['nathanhylan', '', 'gaagle', 'io']
# ['carl1266', '', 'proton', 'me']
# ['ortiz', '', 'gaagle', 'hu']
# ['irwin_otto', '', 'proton', 'hu']
# ['ikechapman', '', 'youhoo', 'io']
# ['nathan', 'zeller', 'odul', 'me']
# ['joeuddin', '', 'ecoin', 'me']
# ['lawicki', '', 'gaagle', 'org']
# ['casal9156', '', 'belgaximus', 'com']
# ['resnick2754', '', 'youhoo', 'xyz']
# ['ashwoon_hank', '', 'odul', 'io']
# ['jack3740', '', 'proton', 'xyz']
# ['hal', 'casal', 'hotmoille', 'com']
# ['jurgenson_dan', '', 'napster', 'hu']
# ['393543398', '', 'proton', 'hu']
# ['steve5769', '', 'proton', 'apple']
# ['duffman_vanderpoel', '', 'odul', 'com']
# ['735354722', '', 'hotmoille', 'gov']
# ['monteschiebel', '', 'odul', 'tech']
# ['larry', 'miller', 'youhoo', 'tech']
# ['duffmanedward', '', 'email', 'me']
# ['tim', 'roberts', 'ecoin', 'xyz']
# ['schickowski', 'matthew', 'napster', 'com']
# ['steve', '', 'youhoo', 'gov']
# ['duffman_weiss', '', 'proton', 'gov']
# ['rogersty', '', 'hotmoille', 'hu']
# ['paulchapman', '', 'imail', 'xyz']
# ['bongardben', '', 'napster', 'tech']
# ['ory_joe', '', 'belgaximus', 'com']
# ['cannon_ferro', '', 'ecoin', 'apple']
# ['rice_soulis', '', 'ecoin', 'apple']
# ['579097737', '', 'belgaximus', 'hu']
# ['pettigrewfred', '', 'odul', 'net']
# ['victorillingsworth', '', 'ecoin', 'org']
# ['wagnercarl', '', 'proton', 'net']
# ['fred', '', 'imail', 'io']
# ['christensen', '', 'belgaximus', 'hu']
# ['vail', '', 'gaagle', 'com']
# ['nathan', '', 'imail', 'hu']
# ['victorjones', '', 'napster', 'tech']
# ['resnick', 'david', 'odul', 'apple']
# ['roger', '', 'proton', 'net']
# ['resnick', 'thomas', 'imail', 'apple']
# ['soukup_tim', '', 'odul', 'apple']
# ['hank', '', 'hotmoille', 'org']
# ['victorfletcher', '', 'imail', 'tech']
# ['schwager_pak', '', 'odul', 'tech']
# ['weinsteintim', '', 'proton', 'org']
# ['fred2414', '', 'hotmoille', 'apple']
# ['hesch1648', '', 'imail', 'tech']
# ['weiss_walter', '', 'gaagle', 'com']
# ['ottoreamer', '', 'email', 'apple']
# ['timbauer', '', 'ecoin', 'apple']
# ['ike', 'reyes', 'belgaximus', 'gov']
# ['matthew', '', 'hotmoille', 'com']
# ['reardon', '', 'gaagle', 'hu']
# ['mccormack7946', '', 'youhoo', 'me']
# ['matthew6993', '', 'hotmoille', 'org']
# ['mcginnis', 'walter', 'email', 'io']
# ['mark2192', '', 'youhoo', 'xyz']
# ['dan', '', 'hotmoille', 'tech']
# ['nuttlety', '', 'gaagle', 'gov']
# ['victortisler', '', 'youhoo', 'com']
# ['tisler_cannon', '', 'youhoo', 'apple']
# ['jacksolberg', '', 'gaagle', 'me']
# ['nathan', 'vanderpoel', 'belgaximus', 'tech']
# ['fletcher_duffman', '', 'ecoin', 'com']
# ['dugan_ortiz', '', 'hotmoille', 'io']
# ['anderson_dewalt', '', 'odul', 'me']
# ['adampak', '', 'hotmoille', 'net']
# ['peter', 'norquist', 'napster', 'net']
# ['yang', '', 'imail', 'net']
# ['alex7627', '', 'youhoo', 'gov']
# ['ben', '', 'napster', 'xyz']
# ['weiss9401', '', 'youhoo', 'xyz']
# ['haworth_steve', '', 'youhoo', 'gov']
# ['ulrich9331', '', 'email', 'org']
# ['baxster', 'mark', 'email', 'net']
# ['dugelman2727', '', 'odul', 'xyz']
# ['yates_hal', '', 'odul', 'net']
# ['otto1543', '', 'youhoo', 'gov']
# ['bateman_joe', '', 'odul', 'apple']
# ['larryhoffman', '', 'belgaximus', 'tech']
# ['celedonmatthew', '', 'napster', 'net']
# ['victorrogers', '', 'gaagle', 'net']
# ['ashwoon_ben', '', 'napster', 'net']
# ['711978855', '', 'email', 'org']
# ['delorenzo', '', 'belgaximus', 'xyz']
# ['zeller_john', '', 'napster', 'hu']
# ['olson', '', 'odul', 'gov']
# ['bensoukup', '', 'proton', 'me']
# ['sweeneytim', '', 'ecoin', 'gov']
# ['joe', '', 'proton', 'hu']
# ['doran', '', 'proton', 'tech']
# ['otto', '', 'hotmoille', 'gov']
# ['frankchristensen', '', 'odul', 'me']
# ['524504262', '', 'odul', 'me']
# ['tim3793', '', 'gaagle', 'io']
# ['otto815', '', 'email', 'me']
# ['sweeney', 'carl', 'gaagle', 'net']
# ['knutson_trebil', '', 'email', 'me']
# ['jack', 'weinstein', 'email', 'apple']
# ['victor', '', 'proton', 'hu']
# ['hancockcarl', '', 'napster', 'com']
# ['schlicht', 'dan', 'email', 'tech']
# ['tisler3297', '', 'belgaximus', 'tech']
# ['steve6502', '', 'email', 'net']
# ['frank5506', '', 'imail', 'apple']
# ['schwager_joe', '', 'napster', 'org']
# ['weiss5261', '', 'email', 'tech']
# ['dantrusela', '', 'odul', 'org']
# ['leisinger_walter', '', 'hotmoille', 'org']
# ['roger4965', '', 'odul', 'net']
# ['mccormack_ike', '', 'youhoo', 'hu']
# ['jackortiz', '', 'imail', 'com']
# ['ferro_peter', '', 'ecoin', 'apple']
# ['schmitt', '', 'imail', 'apple']
# ['yates', 'thomas', 'belgaximus', 'org']
# ['schutzike', '', 'ecoin', 'tech']
# ['upson', '', 'hotmoille', 'hu']
# ['schlicht', 'monte', 'hotmoille', 'com']
# ['upson', '', 'youhoo', 'com']
# ['525072400', '', 'proton', 'tech']
# ['jurgenson_trusela', '', 'odul', 'me']
# ['georgeturco', '', 'imail', 'hu']
# ['jenson9642', '', 'proton', 'io']
# ['thomascaswell', '', 'napster', 'io']
# ['thomaskalleg', '', 'ecoin', 'xyz']
# ['bowers', 'steve', 'napster', 'io']
# ['victorresnick', '', 'proton', 'org']
# ['sellon_roger', '', 'proton', 'hu']
# ['peter', '', 'hotmoille', 'com']
# ['victor2700', '', 'napster', 'xyz']
# ['hesch_mills', '', 'ecoin', 'org']
# ['frankwoo', '', 'napster', 'gov']
# ['ulrich_carl', '', 'belgaximus', 'hu']
# ['hoffman', '', 'hotmoille', 'hu']
# ['zellersteve', '', 'napster', 'io']
# ['jonesthomas', '', 'email', 'tech']
# ['jagtap_victor', '', 'email', 'gov']
# ['reyes3325', '', 'youhoo', 'gov']
# ['schickowski7190', '', 'odul', 'tech']
# ['irwin', '', 'odul', 'hu']
# ['moore_edward', '', 'youhoo', 'org']
# ['tisler_fred', '', 'imail', 'apple']
# ['thomas', '', 'email', 'xyz']
# ['alexcataldi', '', 'napster', 'org']
# ['hankulrich', '', 'belgaximus', 'hu']
# ['peter', 'moody', 'proton', 'io']
# ['ben', 'weinstein', 'odul', 'apple']
# ['davidson_jack', '', 'youhoo', 'xyz']
# ['jacksellon', '', 'napster', 'io']
# ['cataldiedward', '', 'hotmoille', 'io']
# ['sellon', 'jack', 'ecoin', 'net']
# ['748522766', '', 'gaagle', 'xyz']
# ['victorsweeney', '', 'odul', 'tech']
# ['johnmoody', '', 'imail', 'xyz']
# ['peter', 'sandstrom', 'napster', 'xyz']
# ['montelulloff', '', 'email', 'io']
# ['andersonhal', '', 'odul', 'apple']
# ['napier_hank', '', 'belgaximus', 'hu']
# ['moodygeorge', '', 'proton', 'net']
# ['peter4809', '', 'email', 'net']
# ['marknapier', '', 'proton', 'io']
# ['darnell_roger', '', 'hotmoille', 'net']
# ['george', '', 'belgaximus', 'gov']
# ['tim', 'weinstein', 'odul', 'io']
# ['pak_roger', '', 'proton', 'com']
# ['georgecasal', '', 'hotmoille', 'tech']
# ['fred', 'martin', 'youhoo', 'apple']
# ['alex', '', 'proton', 'apple']
# ['dan', 'ventotla', 'proton', 'gov']
# ['dewalt_joe', '', 'email', 'com']
# ['celedon_hesch', '', 'youhoo', 'net']
# ['ty8684', '', 'odul', 'apple']
# ['nuttle_yang', '', 'youhoo', 'hu']
# ['hal', 'rice', 'napster', 'com']
# ['821663824', '', 'odul', 'apple']
# ['mccord', 'fred', 'proton', 'apple']
# ['orwig', '', 'ecoin', 'xyz']
# ['turcolarry', '', 'gaagle', 'hu']
# ['mcginnis_aaron', '', 'email', 'com']
# ['johnpettigrew', '', 'proton', 'hu']
# ['hal', 'yocum', 'email', 'apple']
# ['monteschuster', '', 'belgaximus', 'gov']
# ['fietzer_mark', '', 'gaagle', 'tech']
# ['271794997', '', 'imail', 'gov']
# ['hancock', '', 'imail', 'tech']
# ['wagle_doran', '', 'hotmoille', 'hu']
# ['558791202', '', 'napster', 'io']
# ['quinn1097', '', 'imail', 'org']
# ['sawyer', '', 'proton', 'hu']
# ['ory7664', '', 'belgaximus', 'net']
# ['olsonjohn', '', 'belgaximus', 'tech']
# ['knutson_matthew', '', 'odul', 'tech']
# ['aikin7996', '', 'belgaximus', 'tech']
# ['dewalt674', '', 'napster', 'io']
# ['ventotla_haworth', '', 'imail', 'tech']
# ['ike', '', 'ecoin', 'apple']
# ['yates', 'hal', 'odul', 'io']
# ['resnick_john', '', 'napster', 'xyz']
# ['roger', 'deitz', 'gaagle', 'org']
# ['pak', 'matthew', 'gaagle', 'gov']
# ['edward', '', 'odul', 'io']
# ['markmoore', '', 'email', 'tech']
# ['schickowski', 'roger', 'hotmoille', 'net']
# ['larrysandstrom', '', 'odul', 'org']
# ['nathan', '', 'napster', 'gov']
# ['nathan', 'rogers', 'odul', 'gov']
# ['adameastman', '', 'email', 'me']
# ['carl', 'mcginnis', 'email', 'apple']
# ['davidashwoon', '', 'belgaximus', 'tech']
# ['sawyer', 'steve', 'imail', 'me']
# ['rogercannon', '', 'youhoo', 'io']
# ['aaron', '', 'hotmoille', 'gov']
# ['celedon_ostrander', '', 'email', 'gov']
# ['rogerhoffman', '', 'email', 'apple']
# ['victor2949', '', 'hotmoille', 'org']
# ['matthew', 'schwager', 'imail', 'com']
# ['dan9862', '', 'ecoin', 'com']
# ['victor3334', '', 'belgaximus', 'apple']
# ['trebil', '', 'ecoin', 'gov']
# ['786331264', '', 'napster', 'me']
# ['tyjohnson', '', 'gaagle', 'xyz']
# ['valente5120', '', 'imail', 'net']
# ['187630443', '', 'imail', 'net']
# ['926609635', '', 'odul', 'com']
# ['john', '', 'hotmoille', 'tech']
# ['myers6475', '', 'email', 'org']
# ['ortiz8400', '', 'napster', 'apple']
# ['sandstromgeorge', '', 'hotmoille', 'net']
# ['hylan_tandy', '', 'odul', 'tech']
# ['adammccord', '', 'napster', 'org']
# ['matthew3862', '', 'odul', 'apple']
# ['david8084', '', 'proton', 'tech']
# ['johnmills', '', 'ecoin', 'tech']
# ['haljones', '', 'gaagle', 'tech']
# ['lawless', 'ty', 'gaagle', 'net']
# ['walter', '', 'ecoin', 'xyz']
# ['trebil', 'alex', 'email', 'net']
# ['edward6567', '', 'odul', 'me']
# ['carl3803', '', 'ecoin', 'hu']
# ['ashwoon_vail', '', 'email', 'io']
# ['uddin2141', '', 'youhoo', 'io']
# ['schwager', 'edward', 'imail', 'hu']
# ['652768911', '', 'napster', 'xyz']
# ['rogerupson', '', 'proton', 'tech']
# ['vail_peter', '', 'youhoo', 'apple']
# ['johnson9398', '', 'odul', 'io']
# ['alex7385', '', 'email', 'me']
# ['larrykassing', '', 'gaagle', 'com']
# ['mccormack', 'thomas', 'hotmoille', 'xyz']
# ['610601900', '', 'ecoin', 'hu']
# ['halroberts', '', 'hotmoille', 'org']
# ['timweinstein', '', 'email', 'com']
# ['wagner_frank', '', 'ecoin', 'tech']
# ['benlinde', '', 'napster', 'hu']
# ['baxsteraaron', '', 'ecoin', 'tech']
# ['rogers', '', 'email', 'gov']
# ['mills', 'carl', 'email', 'xyz']
# ['root9744', '', 'ecoin', 'io']
# ['jack', '', 'napster', 'hu']
# ['yangaaron', '', 'youhoo', 'xyz']
# ['jones_thomas', '', 'proton', 'net']
# ['vogal_jack', '', 'hotmoille', 'me']
# ['dinkins', 'victor', 'imail', 'gov']
# ['carlwakefield', '', 'ecoin', 'hu']
# ['darnell_severson', '', 'hotmoille', 'net']
# ['522177655', '', 'youhoo', 'com']
# ['marklewis', '', 'gaagle', 'gov']
# ['georgetandy', '', 'hotmoille', 'xyz']
# ['myersadam', '', 'proton', 'gov']
# ['lawicki5448', '', 'proton', 'com']
# ['bateman', '', 'odul', 'apple']
# ['nathan9473', '', 'belgaximus', 'apple']
# ['rootcarl', '', 'email', 'me']
# ['dugelman_ventotla', '', 'youhoo', 'net']
# ['aaronbauer', '', 'ecoin', 'tech']
# ['ikemaki', '', 'imail', 'io']
# ['matthew', '', 'imail', 'tech']
# ['schutz', 'hal', 'odul', 'net']
# ['roger', 'illingsworth', 'hotmoille', 'org']
# ['john5380', '', 'napster', 'hu']
# ['johnseverson', '', 'belgaximus', 'org']
# ['frank', 'ulrich', 'imail', 'hu']
# ['frank', 'wagner', 'odul', 'xyz']
# ['919971786', '', 'ecoin', 'tech']
# ['nathandugan', '', 'email', 'net']
# ['wagner', 'carl', 'napster', 'org']
# ['george5651', '', 'napster', 'gov']
# ['mark7071', '', 'proton', 'me']
# ['carlulrich', '', 'napster', 'apple']
# ['illingsworthnathan', '', 'gaagle', 'net']
# ['maki_alex', '', 'napster', 'net']
# ['carltrussel', '', 'youhoo', 'tech']
# ['vail2954', '', 'belgaximus', 'tech']
# ['337341248', '', 'proton', 'me']
# ['cast', '', 'imail', 'io']
# ['jackmccormack', '', 'gaagle', 'me']
# ['frank', '', 'napster', 'me']
# ['severson3859', '', 'belgaximus', 'tech']
# ['myers_aaron', '', 'hotmoille', 'com']
# ['markrogers', '', 'odul', 'tech']
# ['jackduffman', '', 'proton', 'xyz']
# ['ty2530', '', 'ecoin', 'net']
# ['rice525', '', 'napster', 'io']
# ['matthewpaiser', '', 'imail', 'org']
# ['sweeney', '', 'gaagle', 'xyz']
# ['nuttle5146', '', 'proton', 'gov']
# ['hank9650', '', 'odul', 'com']
# ['thomas', '', 'gaagle', 'xyz']
# ['stevesoukup', '', 'imail', 'tech']
# ['236893373', '', 'youhoo', 'tech']
# ['schusterhank', '', 'ecoin', 'io']
# ['pak', '', 'odul', 'org']
# ['timaikin', '', 'imail', 'apple']
# ['frankkaskel', '', 'imail', 'gov']
# ['baxster_ferry', '', 'napster', 'tech']
# ['vogal', 'larry', 'napster', 'io']
# ['davidroot', '', 'belgaximus', 'io']
# ['steve', '', 'imail', 'io']
# ['89291924', '', 'ecoin', 'xyz']
# ['sellon9643', '', 'youhoo', 'net']
# ['norquist5151', '', 'odul', 'com']
# ['fredtapia', '', 'proton', 'net']
# ['ferry', 'roger', 'email', 'xyz']
# ['chapman6405', '', 'email', 'apple']
# ['carl172', '', 'gaagle', 'com']
# ['david2563', '', 'youhoo', 'me']
# ['knutson_monte', '', 'gaagle', 'xyz']
# ['tywakefield', '', 'proton', 'me']
# ['zellerdan', '', 'ecoin', 'org']
# ['tapiamonte', '', 'odul', 'net']
# ['yang', 'hal', 'ecoin', 'apple']
# ['makiedward', '', 'napster', 'io']
# ['ventotlaedward', '', 'hotmoille', 'hu']
# ['stahl', '', 'odul', 'tech']
# ['joe', 'pettigrew', 'proton', 'io']
# ['johnson', '', 'gaagle', 'gov']
# ['roger4494', '', 'email', 'gov']
# ['miller_dan', '', 'hotmoille', 'tech']
# ['turcovictor', '', 'proton', 'me']
# ['vanderpoel_george', '', 'proton', 'org']
# ['george', 'ziegler', 'odul', 'apple']
# ['sweeney', 'roger', 'proton', 'io']
# ['montevanderpoel', '', 'email', 'gov']
# ['reyes_hank', '', 'email', 'apple']
# ['larry', '', 'gaagle', 'gov']
# ['zeller_moody', '', 'hotmoille', 'hu']
# ['doran', '', 'hotmoille', 'tech']
# ['adamashwoon', '', 'hotmoille', 'tech']
# ['reardon5977', '', 'gaagle', 'apple']
# ['dewalt_hoffman', '', 'gaagle', 'xyz']
# ['roberts_sweeney', '', 'email', 'net']
# ['alex', 'sellon', 'napster', 'me']
# ['paulnorquist', '', 'gaagle', 'tech']
# ['dan', '', 'belgaximus', 'hu']
# ['fred3131', '', 'ecoin', 'me']
# ['steve3229', '', 'odul', 'tech']
# ['899782577', '', 'email', 'me']
# ['linde_tim', '', 'gaagle', 'gov']
# ['765367121', '', 'email', 'me']
# ['haworthjohn', '', 'ecoin', 'hu']
# ['uflan_joe', '', 'proton', 'apple']
# ['upson', '', 'imail', 'xyz']
# ['713432851', '', 'youhoo', 'me']
# ['anderson_yates', '', 'odul', 'me']
# ['kassingpeter', '', 'imail', 'me']
# ['745585104', '', 'ecoin', 'net']
# ['rogerolson', '', 'proton', 'xyz']
# ['adam', 'moore', 'imail', 'hu']
# ['montelulloff', '', 'proton', 'io']
# ['ortiz_steve', '', 'gaagle', 'com']
# ['victorweiss', '', 'email', 'me']
# ['nuttlejoe', '', 'youhoo', 'gov']
# ['thomassoulis', '', 'belgaximus', 'hu']
# ['turco', 'john', 'belgaximus', 'org']
# ['tyboyd', '', 'youhoo', 'me']
# ['johnrice', '', 'hotmoille', 'net']
# ['valente_ulrich', '', 'gaagle', 'xyz']
# ['fietzer', '', 'proton', 'com']
# ['haworth', '', 'odul', 'net']
# ['carl7338', '', 'imail', 'tech']
# ['moody7198', '', 'youhoo', 'net']
# ['fietzer', 'george', 'email', 'org']
# ['resnick_tisler', '', 'ecoin', 'com']
# ['ben', 'ebner', 'youhoo', 'com']
# ['victor', '', 'napster', 'hu']
# ['91207142', '', 'imail', 'tech']
# ['sweeneyedward', '', 'belgaximus', 'xyz']
# ['mccord_paiser', '', 'gaagle', 'net']
# ['ziegler5406', '', 'hotmoille', 'me']
# ['frankpaiser', '', 'napster', 'org']
# ['hylan', 'joe', 'odul', 'com']
# ['trusela3854', '', 'gaagle', 'net']
# ['jagtap_keller', '', 'hotmoille', 'xyz']
# ['turcodan', '', 'belgaximus', 'me']
# ['ike', 'kalleg', 'odul', 'xyz']
# ['393592788', '', 'napster', 'io']
# ['quinn_roger', '', 'belgaximus', 'com']
# ['severson_delorenzo', '', 'proton', 'io']
# ['reyes_paul', '', 'odul', 'io']
# ['woo_quizoz', '', 'ecoin', 'xyz']
# ['timillingsworth', '', 'odul', 'io']
# ['otto147', '', 'belgaximus', 'org']
# ['sagar_weinstein', '', 'belgaximus', 'me']
# ['frankmartin', '', 'email', 'apple']
# ['schuster_joe', '', 'napster', 'apple']
# ['davis', '', 'youhoo', 'org']
# ['carljones', '', 'belgaximus', 'gov']
# ['boyd_carl', '', 'napster', 'apple']
# ['kaskel', '', 'hotmoille', 'net']
# ['roberts_baxster', '', 'napster', 'com']
# ['irwin_ike', '', 'youhoo', 'apple']
# ['rogerduffman', '', 'proton', 'io']
# ['zeaser_casal', '', 'imail', 'net']
# ['carl', 'celedon', 'proton', 'gov']
# ['frank', 'ulrich', 'napster', 'io']
# ['622575176', '', 'proton', 'io']
# ['tisler', '', 'gaagle', 'apple']
# ['559573601', '', 'imail', 'org']
# ['davis', 'peter', 'ecoin', 'com']
# ['zeaser', 'mark', 'odul', 'xyz']
# ['matthew', '', 'odul', 'tech']
# ['ikecasal', '', 'ecoin', 'me']
# ['quinn_thomas', '', 'odul', 'net']
# ['hal', 'leisinger', 'napster', 'tech']
# ['pak', '', 'proton', 'tech']
# ['david', '', 'youhoo', 'org']
# ['edward', '', 'belgaximus', 'xyz']
# ['lawless5456', '', 'email', 'io']
# ['yates9610', '', 'hotmoille', 'tech']
# ['586433493', '', 'proton', 'apple']
# ['dansonderling', '', 'napster', 'me']
# ['carlstahl', '', 'odul', 'net']
# ['bauer_reamer', '', 'imail', 'net']
# ['thomas', 'wagle', 'ecoin', 'net']
# ['steveshaffer', '', 'belgaximus', 'gov']
# ['562075782', '', 'napster', 'net']
# ['norquisthank', '', 'email', 'io']
# ['sandstromgeorge', '', 'napster', 'tech']
# ['edwardmaki', '', 'belgaximus', 'gov']
# ['marklewis', '', 'proton', 'io']
# ['473755189', '', 'belgaximus', 'com']
# ['542237317', '', 'youhoo', 'tech']
# ['peterduffman', '', 'imail', 'gov']
# ['uddinty', '', 'odul', 'me']
# ['david', '', 'napster', 'io']
# ['rogerostrander', '', 'gaagle', 'com']
# ['ikereardon', '', 'belgaximus', 'hu']
# ['fletcher2637', '', 'youhoo', 'org']
# ['vadermark', '', 'belgaximus', 'me']
# ['danmcginnis', '', 'imail', 'net']
# ['root', 'aaron', 'imail', 'io']
# ['johnsen5090', '', 'imail', 'io']
# ['bateman', '', 'napster', 'gov']
# ['394758759', '', 'gaagle', 'org']
# ['upson_lawless', '', 'imail', 'xyz']
# ['frankillingsworth', '', 'email', 'apple']
# ['jagtap_sawyer', '', 'odul', 'net']
# ['larry', 'upson', 'youhoo', 'tech']
# ['fletcher', 'nathan', 'imail', 'org']
# ['solberg', 'victor', 'odul', 'io']
# ['root_kaskel', '', 'hotmoille', 'tech']
# ['celedonsteve', '', 'imail', 'me']
# ['david', '', 'odul', 'hu']
# ['matthew', 'fletcher', 'imail', 'gov']
# ['jacksandstrom', '', 'youhoo', 'io']
# ['bowers_steve', '', 'hotmoille', 'xyz']
# ['dewalt7124', '', 'gaagle', 'com']
# ['larry6516', '', 'ecoin', 'com']
# ['hank', '', 'hotmoille', 'tech']
# ['chapman_fred', '', 'youhoo', 'hu']
# ['jackquinn', '', 'napster', 'gov']
# ['darnell', 'peter', 'odul', 'apple']
# ['schickowski1112', '', 'hotmoille', 'net']
# ['sweeney', '', 'belgaximus', 'net']
# ['uddin', 'john', 'imail', 'net']
# ['rogertrussel', '', 'email', 'net']
# ['soloman', '', 'belgaximus', 'xyz']
# ['adam', 'nugent', 'belgaximus', 'me']
# ['thompson', '', 'gaagle', 'tech']
# ['ulrich8195', '', 'napster', 'org']
# ['tiernan_johnson', '', 'youhoo', 'tech']
# ['860812952', '', 'odul', 'gov']
# ['nelson_severson', '', 'imail', 'tech']
# ['mccormack_caswell', '', 'imail', 'com']
# ['solberg', 'roger', 'odul', 'net']
# ['nathanfletcher', '', 'youhoo', 'org']
# ['hank', '', 'ecoin', 'com']
# ['celedon_ory', '', 'napster', 'xyz']
# ['trusela', '', 'email', 'gov']
# ['peter', 'cataldi', 'ecoin', 'tech']
# ['tim9711', '', 'belgaximus', 'com']
# ['frank8688', '', 'ecoin', 'com']
# ['schusterfrank', '', 'ecoin', 'io']
# ['otto', 'valente', 'gaagle', 'xyz']
# ['johnson_victor', '', 'napster', 'hu']
# ['knutson', '', 'proton', 'apple']
# ['delorenzomark', '', 'ecoin', 'io']
# ['chambers6155', '', 'napster', 'io']
# ['hydinger6967', '', 'gaagle', 'net']
# ['thomas9547', '', 'napster', 'xyz']
# ['upsonpaul', '', 'hotmoille', 'apple']
# ['david', '', 'email', 'gov']
# ['darnell_jack', '', 'hotmoille', 'gov']
# ['monte', '', 'napster', 'xyz']
# ['roger', 'sagar', 'gaagle', 'io']
# ['frankwagle', '', 'gaagle', 'net']
# ['myers', 'hank', 'belgaximus', 'com']
# ['612577631', '', 'proton', 'apple']
# ['deitzmark', '', 'email', 'me']
# ['sellon_thomas', '', 'email', 'io']
# ['matthewdavis', '', 'napster', 'gov']
# ['orwig_alex', '', 'ecoin', 'com']
# ['978609355', '', 'napster', 'tech']
# ['yocumty', '', 'proton', 'me']
# ['george', 'bateman', 'ecoin', 'me']
# ['sawyer_larry', '', 'proton', 'xyz']
# ['ulrich', 'roger', 'gaagle', 'gov']
# ['15077598', '', 'belgaximus', 'com']
# ['timdugelman', '', 'ecoin', 'apple']
# ['franknuttle', '', 'ecoin', 'hu']
# ['adamnelson', '', 'gaagle', 'apple']
# ['nuttle_walter', '', 'hotmoille', 'me']
# ['keller_monte', '', 'belgaximus', 'me']
# ['nathan', 'lulloff', 'hotmoille', 'me']
# ['aaroncast', '', 'odul', 'hu']
# ['illingsworth4885', '', 'email', 'me']
# ['markshaffer', '', 'imail', 'io']
# ['victor', '', 'gaagle', 'xyz']
# ['quinn8871', '', 'odul', 'xyz']
# ['thomasbongard', '', 'gaagle', 'xyz']
# ['alexvalente', '', 'hotmoille', 'xyz']
# ['adam', 'kalleg', 'napster', 'xyz']
# ['hanknelson', '', 'belgaximus', 'io']
# ['roger', '', 'hotmoille', 'gov']
# ['joelepage', '', 'napster', 'org']
# ['dandewalt', '', 'odul', 'com']
# ['thomas', '', 'odul', 'io']
# ['ben', 'boyd', 'email', 'me']
# ['hancocksteve', '', 'proton', 'tech']
# ['boyd', '', 'ecoin', 'me']
# ['delorenzo8683', '', 'odul', 'com']
# ['reyes', '', 'proton', 'io']
# ['tapia', '', 'hotmoille', 'org']
# ['rogerramachandran', '', 'youhoo', 'hu']
# ['hesch', 'roger', 'napster', 'hu']
# ['valente', '', 'napster', 'hu']
# ['dewalt_schlicht', '', 'email', 'apple']
# ['jurgenson496', '', 'belgaximus', 'io']
# ['john', '', 'odul', 'net']
# ['soukup', '', 'proton', 'gov']
# ['jack', 'deitz', 'youhoo', 'org']
# ['victor', '', 'belgaximus', 'tech']
# ['leisinger9124', '', 'gaagle', 'com']
# ['thomasbateman', '', 'youhoo', 'gov']
# ['bongard_moore', '', 'imail', 'xyz']
# ['fletcherpeter', '', 'imail', 'xyz']
# ['irwin6425', '', 'email', 'hu']
# ['irwinhal', '', 'youhoo', 'tech']
# ['753760757', '', 'odul', 'gov']
# ['olson', '', 'youhoo', 'me']
# ['nathan424', '', 'proton', 'hu']
# ['casal', '', 'imail', 'com']
# ['jackhoffman', '', 'imail', 'gov']
# ['adam4353', '', 'odul', 'gov']
# ['ben', 'lewis', 'proton', 'gov']
# ['tiernan9526', '', 'youhoo', 'io']
# ['sweeney3123', '', 'youhoo', 'gov']
# ['delorenzo', 'thomas', 'email', 'org']
# ['wagle', '', 'napster', 'io']
# ['527881805', '', 'ecoin', 'apple']
# ['linde443', '', 'gaagle', 'xyz']
# ['hydinger2431', '', 'email', 'me']
# ['ferro', '', 'imail', 'xyz']
# ['leisinger7925', '', 'gaagle', 'hu']
# ['otto', '', 'email', 'org']
# ['sawyerdan', '', 'youhoo', 'tech']
# ['ulrich', '', 'belgaximus', 'apple']
# ['dewaltjohn', '', 'ecoin', 'xyz']
# ['daviduddin', '', 'odul', 'hu']
# ['schuster4665', '', 'hotmoille', 'apple']
# ['walter', '', 'hotmoille', 'io']
# ['aikin', '', 'proton', 'tech']
# ['haltisler', '', 'gaagle', 'io']
# ['roger', 'nuttle', 'hotmoille', 'hu']
# ['frankmccord', '', 'odul', 'gov']
# ['790068404', '', 'imail', 'net']
# ['fletcher', 'peter', 'proton', 'apple']
# ['paul', '', 'proton', 'gov']
# ['johndugelman', '', 'napster', 'xyz']
# ['markwagle', '', 'napster', 'tech']
# ['joe', '', 'hotmoille', 'org']
# ['sonderling_dinkins', '', 'email', 'io']
# ['rogerchapman', '', 'proton', 'net']
# ['vanderpoel', 'roger', 'imail', 'com']
# ['joe2475', '', 'imail', 'tech']
# ['paiser_moody', '', 'proton', 'io']
# ['paiser', '', 'ecoin', 'me']
# ['peter', 'ventotla', 'napster', 'me']
# ['524167342', '', 'odul', 'com']
# ['hal', 'nugent', 'gaagle', 'me']
# ['petersawyer', '', 'gaagle', 'net']
# ['edward1595', '', 'hotmoille', 'gov']
# ['thomasroot', '', 'ecoin', 'net']
# ['720054838', '', 'hotmoille', 'net']
# ['835555730', '', 'belgaximus', 'io']
# ['edwardjenson', '', 'hotmoille', 'io']
# ['darnell_ty', '', 'belgaximus', 'me']
# ['hank2676', '', 'imail', 'gov']
# ['victorturco', '', 'email', 'apple']
# ['dugan', '', 'email', 'hu']
# ['fred6946', '', 'hotmoille', 'me']
# ['ferro', '', 'ecoin', 'hu']
# ['hal7714', '', 'youhoo', 'me']
# ['921295508', '', 'youhoo', 'org']
# ['hank944', '', 'ecoin', 'io']
# ['turco_david', '', 'proton', 'org']
# ['baxster', '', 'odul', 'io']
# ['schutz_tiernan', '', 'imail', 'org']
# ['boyd_eastman', '', 'imail', 'net']
# ['tislermonte', '', 'hotmoille', 'gov']
# ['ferrynathan', '', 'odul', 'tech']
# ['aikin_johnsen', '', 'hotmoille', 'hu']
# ['carlschuster', '', 'hotmoille', 'com']
# ['adamferro', '', 'email', 'xyz']
# ['haworth_ostrander', '', 'proton', 'me']
# ['peterostrander', '', 'odul', 'apple']
# ['matthew', 'schlicht', 'odul', 'apple']
# ['zeller_ty', '', 'odul', 'xyz']
# ['fred542', '', 'proton', 'com']
# ['chapman_roger', '', 'hotmoille', 'io']
# ['shaffer', '', 'gaagle', 'xyz']
# ['napier_tim', '', 'email', 'org']
# ['resnick_soloman', '', 'youhoo', 'io']
# ['hydinger', 'victor', 'ecoin', 'io']
# ['reardonnathan', '', 'imail', 'com']
# ['irwinfrank', '', 'email', 'org']
# ['778805808', '', 'gaagle', 'net']
# ['benduffman', '', 'hotmoille', 'com']
# ['stahl_peter', '', 'hotmoille', 'apple']
# ['zeaser_lawicki', '', 'napster', 'xyz']
# ['tisler', '', 'proton', 'io']
# ['john', '', 'youhoo', 'tech']
# ['daviddavidson', '', 'ecoin', 'org']
# ['joeschmitt', '', 'imail', 'com']
# ['jones3480', '', 'odul', 'gov']
# ['hal', 'davidson', 'belgaximus', 'apple']
# ['dan', 'soloman', 'email', 'xyz']
# ['pak_aaron', '', 'imail', 'io']
# ['pettigrew_walter', '', 'youhoo', 'io']
# ['solberg_peter', '', 'email', 'com']
# ['ottoreamer', '', 'belgaximus', 'xyz']
# ['ebner2247', '', 'odul', 'org']
# ['rogerlawicki', '', 'odul', 'com']
# ['adam3493', '', 'youhoo', 'io']
# ['edwardtiernan', '', 'proton', 'com']
# ['hal', '', 'imail', 'hu']
# ['tyquinn', '', 'hotmoille', 'net']
# ['thomashancock', '', 'gaagle', 'hu']
# ['quinn_david', '', 'odul', 'org']
# ['ebner', 'thomas', 'ecoin', 'com']
# ['cast3500', '', 'proton', 'io']
# ['edward', '', 'ecoin', 'hu']
# ['hal', 'vogal', 'ecoin', 'io']
# ['fred6097', '', 'email', 'xyz']
# ['uddin_celedon', '', 'youhoo', 'xyz']
# ['328027994', '', 'odul', 'apple']
# ['doran', 'victor', 'belgaximus', 'xyz']
# ['petersonderling', '', 'ecoin', 'gov']
# ['alexlawless', '', 'hotmoille', 'com']
# ['fletcher6080', '', 'proton', 'org']
# ['david9675', '', 'belgaximus', 'tech']
# ['hal', '', 'youhoo', 'org']
# ['shaffer_adam', '', 'imail', 'me']
# ['orysteve', '', 'gaagle', 'apple']
# ['zellerty', '', 'email', 'org']
# ['resnick_ty', '', 'hotmoille', 'gov']
# ['turcolarry', '', 'napster', 'gov']
# ['roger7870', '', 'imail', 'xyz']
# ['solberg', 'monte', 'gaagle', 'tech']
# ['ikeolson', '', 'imail', 'xyz']
# ['tim', 'vogal', 'napster', 'me']
# ['davidson_joe', '', 'imail', 'apple']
# ['113992553', '', 'proton', 'gov']
# ['weiss_keller', '', 'hotmoille', 'io']
# ['roberts5261', '', 'email', 'hu']
# ['thompsonhank', '', 'email', 'tech']
# ['trussel', 'adam', 'youhoo', 'gov']
# ['schwager', '', 'odul', 'tech']
# ['paul', '', 'odul', 'net']
# ['jackferro', '', 'youhoo', 'xyz']
# ['ingram_schutz', '', 'hotmoille', 'apple']
# ['wagner', 'larry', 'hotmoille', 'xyz']
# ['tyshaffer', '', 'napster', 'com']
# ['tapia287', '', 'ecoin', 'net']
# ['fred4639', '', 'email', 'xyz']
# ['steveingram', '', 'gaagle', 'tech']
# ['alex', '', 'gaagle', 'me']
# ['moody_alex', '', 'belgaximus', 'me']
# ['davidyates', '', 'odul', 'gov']
# ['sellon_mark', '', 'ecoin', 'org']
# ['duganjack', '', 'napster', 'tech']
# ['george7677', '', 'hotmoille', 'io']
# ['947932051', '', 'gaagle', 'me']
# ['kassingmonte', '', 'imail', 'com']
# ['edward', 'orwig', 'gaagle', 'org']
# ['lawless_steve', '', 'imail', 'me']
# ['soulis_matthew', '', 'proton', 'tech']
# ['vail7262', '', 'hotmoille', 'hu']
# ['christensen_adam', '', 'imail', 'org']
# ['chamberspaul', '', 'gaagle', 'com']
# ['carlripka', '', 'proton', 'org']
# ['thompson', '', 'imail', 'gov']
# ['shaffernathan', '', 'hotmoille', 'io']
# ['haworth1948', '', 'gaagle', 'gov']
# ['nathan', '', 'napster', 'com']
# ['george', 'davidson', 'hotmoille', 'net']
# ['john6870', '', 'napster', 'com']
# ['baxster_hal', '', 'napster', 'io']
# ['monte', 'ebner', 'gaagle', 'io']
# ['paiser_paiser', '', 'imail', 'org']
# ['danyocum', '', 'youhoo', 'io']
# ['heschedward', '', 'ecoin', 'org']
# ['george', 'schutz', 'gaagle', 'tech']
# ['hancock_walter', '', 'youhoo', 'xyz']
# ['doran', '', 'email', 'io']
# ['leisinger_joe', '', 'imail', 'hu']
# ['thomas4571', '', 'gaagle', 'org']
# ['ramachandran2353', '', 'napster', 'hu']
# ['davidson_schuster', '', 'hotmoille', 'net']
# ['nathan6101', '', 'email', 'gov']
# ['matthew', '', 'imail', 'tech']
# ['sellon_cast', '', 'ecoin', 'hu']
# ['matthew', '', 'youhoo', 'net']
# ['wagle_ferry', '', 'napster', 'hu']
# ['walterpaiser', '', 'youhoo', 'net']
# ['darnell', '', 'napster', 'gov']
# ['hank2051', '', 'ecoin', 'xyz']
# ['thomas', 'cataldi', 'ecoin', 'com']
# ['thompson_roger', '', 'odul', 'io']
# ['roger4607', '', 'napster', 'com']
# ['keller_walter', '', 'odul', 'io']
# ['matthew', 'uflan', 'imail', 'gov']
# ['joe', 'kaskel', 'napster', 'tech']
# ['cataldidavid', '', 'belgaximus', 'gov']
# ['roger', 'upson', 'odul', 'me']
# ['thomaspaiser', '', 'odul', 'org']
# ['victor', '', 'napster', 'net']
# ['orwig', 'larry', 'napster', 'apple']
# ['ferro7108', '', 'gaagle', 'apple']
# ['johnsen', 'matthew', 'napster', 'hu']
# ['ebner', 'fred', 'hotmoille', 'hu']
# ['victor9493', '', 'hotmoille', 'hu']
# ['peter6703', '', 'ecoin', 'gov']
# ['delorenzothomas', '', 'youhoo', 'net']
# ['miller6509', '', 'proton', 'xyz']
# ['hancock5965', '', 'imail', 'hu']
# ['illingsworthaaron', '', 'napster', 'apple']
# ['ostrander', '', 'belgaximus', 'xyz']
# ['monte6005', '', 'email', 'net']
# ['56345021', '', 'gaagle', 'io']
# ['fietzer', '', 'ecoin', 'tech']
# ['tyreardon', '', 'odul', 'xyz']
# ['zeaserpeter', '', 'youhoo', 'hu']
# ['montehydinger', '', 'hotmoille', 'com']
# ['hank5419', '', 'proton', 'hu']
# ['cannon965', '', 'youhoo', 'gov']
# ['joe', '', 'youhoo', 'hu']
# ['shaffer', 'paul', 'gaagle', 'xyz']
# ['lawless_thomas', '', 'napster', 'me']
# ['chambers', '', 'gaagle', 'io']
# ['nathanferro', '', 'proton', 'io']
# ['mark9494', '', 'belgaximus', 'org']
# ['dinkins_carl', '', 'email', 'xyz']
# ['379512415', '', 'napster', 'org']
# ['paulmyers', '', 'ecoin', 'io']
# ['sawyer', '', 'imail', 'me']
# ['georgevalente', '', 'odul', 'apple']
# ['dan', '', 'youhoo', 'apple']
# ['vail', 'monte', 'odul', 'com']
# ['upson_deitz', '', 'imail', 'tech']
# ['fred', 'soulis', 'gaagle', 'gov']
# ['vail_david', '', 'youhoo', 'me']
# ['delorenzo', 'frank', 'odul', 'org']
# ['victor', '', 'youhoo', 'io']
# ['9505661', '', 'gaagle', 'hu']
# ['jackbateman', '', 'odul', 'com']
# ['984521262', '', 'belgaximus', 'tech']
# ['chapman_moore', '', 'hotmoille', 'io']
# ['nathan', 'ortiz', 'youhoo', 'net']
# ['997040446', '', 'youhoo', 'net']
# ['adam', '', 'odul', 'tech']
# ['vader_kalleg', '', 'napster', 'apple']
# ['nathan', '', 'youhoo', 'hu']
# ['timdugelman', '', 'email', 'gov']
# ['john3292', '', 'odul', 'gov']
# ['ripka', '', 'ecoin', 'io']
# ['ostrander6580', '', 'youhoo', 'hu']
# ['benmartin', '', 'hotmoille', 'me']
# ['hankmills', '', 'napster', 'gov']
# ['ricemark', '', 'ecoin', 'apple']
# ...
# ['nuttle_adam', '', 'belgaximus', 'me']
# ['ferro3891', '', 'belgaximus', 'apple']
# ['ziegler_david', '', 'belgaximus', 'net']
# ['634710274', '', 'email', 'xyz']
# ['tim', '', 'youhoo', 'net']
# ['wagle2353', '', 'ecoin', 'apple']
# ['danramachandran', '', 'napster', 'net']
# ['schmitt9731', '', 'hotmoille', 'com']
# ['wagle', '', 'odul', 'apple']
# ['olson', 'frank', 'napster', 'io']
# ['kalleg_monte', '', 'belgaximus', 'hu']
# ['batemanvictor', '', 'email', 'com']
# ['moodyben', '', 'imail', 'net']
# ['carl', 'cataldi', 'youhoo', 'tech']
# ['stahl_monte', '', 'proton', 'tech']
# ['alexvail', '', 'imail', 'gov']
# ['soloman', 'joe', 'imail', 'net']
# ['405543669', '', 'odul', 'xyz']
# ['vail', '', 'proton', 'me']
# ['ike', '', 'proton', 'net']
# ['hal', '', 'email', 'io']
# ['reamer_hylan', '', 'youhoo', 'io']
# ['george', 'upson', 'ecoin', 'io']
# ['larryschlicht', '', 'ecoin', 'hu']
# ['nathan', '', 'ecoin', 'tech']
# ['walter', 'schmitt', 'email', 'net']
# ['205198734', '', 'proton', 'xyz']
# ['sagar_mcginnis', '', 'email', 'tech']
# ['lulloff3777', '', 'belgaximus', 'org']
# ['celedonsteve', '', 'odul', 'com']
# ['solomanotto', '', 'gaagle', 'apple']
# ['george', 'ziegler', 'napster', 'apple']
# ['orwigdavid', '', 'youhoo', 'net']
# ['steve132', '', 'odul', 'apple']
# ['fietzer', 'thomas', 'youhoo', 'xyz']
# ['298834407', '', 'hotmoille', 'tech']
# ['bowerscarl', '', 'gaagle', 'xyz']
# ['ty', 'roberts', 'gaagle', 'com']
# ['soukup3953', '', 'ecoin', 'xyz']
# ['hankduffman', '', 'proton', 'gov']
# ['zeaserjoe', '', 'imail', 'gov']
# ['paul', '', 'odul', 'tech']
# ['628123697', '', 'imail', 'net']
# ['sonderlingroger', '', 'napster', 'io']
# ['fred', 'cataldi', 'proton', 'gov']
# ['norquist7475', '', 'belgaximus', 'com']
# ['steve8944', '', 'napster', 'apple']
# ['illingsworth_baxster', '', 'belgaximus', 'org']
# ['chapman_wakefield', '', 'odul', 'me']
# ['fred', '', 'youhoo', 'apple']
# ['mccormack', 'mark', 'email', 'org']
# ['ferro_moore', '', 'napster', 'me']
# ['967162871', '', 'gaagle', 'org']
# ['thomasbongard', '', 'ecoin', 'net']
# ['schuster_paul', '', 'youhoo', 'net']
# ['ulrich', 'frank', 'email', 'io']
# ['larry6980', '', 'hotmoille', 'apple']
# ['tybauer', '', 'odul', 'xyz']
# ['reyes', '', 'ecoin', 'org']
# ['reardon_schickowski', '', 'gaagle', 'io']
# ['truselamatthew', '', 'ecoin', 'xyz']
# ['vail', 'john', 'email', 'net']
# ['aaron8268', '', 'napster', 'org']
# ['waglety', '', 'belgaximus', 'xyz']
# ['494478911', '', 'napster', 'me']
# ['soukup_jones', '', 'napster', 'hu']
# ['schutz112', '', 'hotmoille', 'xyz']
# ['147193373', '', 'hotmoille', 'gov']
# ['45863462', '', 'hotmoille', 'net']
# ['jensonroger', '', 'belgaximus', 'xyz']
# ['lawicki', '', 'ecoin', 'me']
# ['ingram', 'roger', 'odul', 'org']
# ['joe', '', 'belgaximus', 'tech']
# ['ebnerfrank', '', 'email', 'tech']
# ['frick', '', 'hotmoille', 'apple']
# ['ike', 'lulloff', 'youhoo', 'io']
# ['nugent2010', '', 'youhoo', 'com']
# ['solberg_ike', '', 'napster', 'gov']
# ['sellon', 'peter', 'gaagle', 'hu']
# ['345679740', '', 'imail', 'tech']
# ['resnick_soulis', '', 'napster', 'net']
# ['david1223', '', 'proton', 'io']
# ['vail_mccormack', '', 'odul', 'net']
# ['doran2251', '', 'hotmoille', 'gov']
# ['duffman_otto', '', 'odul', 'com']
# ['ripkadavid', '', 'napster', 'org']
# ['thompson_larry', '', 'imail', 'com']
# ['myers_nugent', '', 'odul', 'com']
# ['nelson_uflan', '', 'odul', 'net']
# ['rogersandstrom', '', 'napster', 'org']
# ['bongard9752', '', 'napster', 'me']
# ['ike', '', 'ecoin', 'tech']
# ['edward', '', 'imail', 'gov']
# ['peter', '', 'ecoin', 'tech']
# ['sonderling1544', '', 'hotmoille', 'net']
# ['delorenzo8378', '', 'imail', 'net']
# ['hoffman_hal', '', 'ecoin', 'io']
# ['solberg9104', '', 'gaagle', 'tech']
# ['valente7241', '', 'proton', 'hu']
# ['otto1835', '', 'napster', 'xyz']
# ['schwager', '', 'gaagle', 'io']
# ['bateman', 'walter', 'odul', 'me']
# ['larrymcginnis', '', 'napster', 'com']
# ['thomas', 'rice', 'proton', 'me']
# ['ben', 'bauer', 'youhoo', 'xyz']
# ['ty', '', 'proton', 'apple']
# ['larrysagar', '', 'napster', 'org']
# ['trussel4767', '', 'imail', 'io']
# ['uflan', '', 'imail', 'tech']
# ['jackmartin', '', 'youhoo', 'net']
# ['david', '', 'hotmoille', 'net']
# ['carlwagner', '', 'gaagle', 'me']
# ['aaron', '', 'email', 'gov']
# ['62416842', '', 'odul', 'com']
# ['uddin', 'peter', 'belgaximus', 'hu']
# ['illingsworthtim', '', 'proton', 'net']
# ['moody_john', '', 'napster', 'apple']
# ['andersonvictor', '', 'odul', 'me']
# ['jack', '', 'ecoin', 'xyz']
# ['baxster_schutz', '', 'odul', 'org']
# ['ikeschmitt', '', 'gaagle', 'me']
# ['jackzeaser', '', 'imail', 'apple']
# ['thomas', 'moore', 'gaagle', 'xyz']
# ['walter', 'kassing', 'imail', 'hu']
# ['fred2919', '', 'napster', 'gov']
# ['tiernan', 'matthew', 'email', 'net']
# ['cast', '', 'belgaximus', 'org']
# ['carl', '', 'napster', 'io']
# ['paul7394', '', 'imail', 'org']
# ['nugentlarry', '', 'email', 'xyz']
# ['ripka8728', '', 'hotmoille', 'org']
# ['aaron', '', 'ecoin', 'org']
# ['lawicki1357', '', 'imail', 'me']
# ['nugent4493', '', 'gaagle', 'gov']
# ['matthewquizoz', '', 'email', 'net']
# ['victor', 'hoffman', 'proton', 'io']
# ['kaskel_joe', '', 'napster', 'xyz']
# ['schlicht', '', 'belgaximus', 'apple']
# ['lawless', 'alex', 'odul', 'tech']
# ['baxster_hank', '', 'ecoin', 'xyz']
# ['thomaspaiser', '', 'belgaximus', 'tech']
# ['victorseverson', '', 'gaagle', 'net']
# ['seversonmark', '', 'email', 'gov']
# ['hancock_stahl', '', 'ecoin', 'gov']
# ['ostrander', 'alex', 'youhoo', 'net']
# ['carlsweeney', '', 'youhoo', 'io']
# ['562090828', '', 'ecoin', 'org']
# ['ben', 'wakefield', 'proton', 'io']
# ['schickowski3120', '', 'napster', 'gov']
# ['wakefield', 'edward', 'hotmoille', 'io']
# ['roger7345', '', 'ecoin', 'com']
# ['ortiz', '', 'hotmoille', 'tech']
# ['soulismark', '', 'youhoo', 'gov']
# ['johnvail', '', 'proton', 'xyz']
# ['peternapier', '', 'gaagle', 'hu']
# ['bateman', '', 'odul', 'tech']
# ['doran', 'walter', 'youhoo', 'gov']
# ['ebner', '', 'ecoin', 'org']
# ['jenson_solberg', '', 'youhoo', 'io']
# ['ramachandran_orwig', '', 'gaagle', 'net']
# ['victor', 'chapman', 'proton', 'xyz']
# ['soloman_quizoz', '', 'youhoo', 'gov']
# ['paulupson', '', 'email', 'hu']
# ['peter', '', 'ecoin', 'gov']
# ['walter', '', 'hotmoille', 'gov']
# ['aaronmccord', '', 'email', 'me']
# ['sellon', 'jack', 'odul', 'gov']
# ['paul', 'turco', 'email', 'apple']
# ['adam', '', 'youhoo', 'hu']
# ['hal', '', 'gaagle', 'hu']
# ['fredrice', '', 'email', 'xyz']
# ['bowersedward', '', 'ecoin', 'com']
# ['darnell', '', 'youhoo', 'hu']
# ['frick69', '', 'belgaximus', 'com']
# ['timortiz', '', 'belgaximus', 'org']
# ['mark287', '', 'ecoin', 'net']
# ['leisingeraaron', '', 'ecoin', 'com']
# ['aaron', '', 'youhoo', 'tech']
# ['linde', '', 'imail', 'net']
# ['mccormack', '', 'napster', 'org']
# ['cataldi_vogal', '', 'email', 'com']
# ['walter', 'schuster', 'odul', 'apple']
# ['629679708', '', 'youhoo', 'me']
# ['victor', 'nuttle', 'napster', 'me']
# ['root', 'dan', 'odul', 'org']
# ['ashwoon', '', 'napster', 'xyz']
# ['kassing_joe', '', 'odul', 'com']
# ['schuster_root', '', 'napster', 'net']
# ['681617279', '', 'gaagle', 'me']
# ['orwig', '', 'imail', 'me']
# ['turco_eastman', '', 'gaagle', 'apple']
# ['ziegler8032', '', 'gaagle', 'tech']
# ['stevemiller', '', 'proton', 'apple']
# ['97234842', '', 'imail', 'net']
# ['reardon9212', '', 'proton', 'gov']
# ['paul', 'myers', 'email', 'gov']
# ['jack7787', '', 'belgaximus', 'net']
# ['jagtap_larry', '', 'belgaximus', 'org']
# ['otto', 'leisinger', 'proton', 'io']
# ['yates_thomas', '', 'ecoin', 'xyz']
# ['knutson_thomas', '', 'email', 'com']
# ['davis', 'monte', 'hotmoille', 'net']
# ['vader_alex', '', 'odul', 'xyz']
# ['nuttle1626', '', 'imail', 'hu']
# ['738731613', '', 'email', 'io']
# ['hesch', 'hank', 'email', 'me']
# ['monte6198', '', 'imail', 'me']
# ['alexhydinger', '', 'gaagle', 'gov']
# ['schuster_tiernan', '', 'email', 'xyz']
# ['victorkeller', '', 'proton', 'net']
# ['illingsworth', 'monte', 'belgaximus', 'apple']
# ['peter', '', 'belgaximus', 'net']
# ['hoffman9254', '', 'odul', 'tech']
# ['sandstrom6021', '', 'belgaximus', 'gov']
# ['moody_lawless', '', 'youhoo', 'tech']
# ['622921665', '', 'belgaximus', 'org']
# ['wagner', '', 'ecoin', 'me']
# ['498202212', '', 'odul', 'tech']
# ['thompson2886', '', 'belgaximus', 'org']
# ['alexfrick', '', 'email', 'xyz']
# ['zeller', 'matthew', 'imail', 'com']
# ['thomasjagtap', '', 'proton', 'hu']
# ['stahl_solberg', '', 'proton', 'hu']
# ['resnick', '', 'youhoo', 'me']
# ['881606408', '', 'imail', 'io']
# ['hank4616', '', 'proton', 'gov']
# ['thomas', 'reamer', 'odul', 'hu']
# ['turco', '', 'hotmoille', 'tech']
# ['matthew', 'doran', 'odul', 'hu']
# ['frick_steve', '', 'napster', 'gov']
# ['edwarddinkins', '', 'imail', 'com']
# ['35834059', '', 'proton', 'com']
# ['paul7873', '', 'ecoin', 'com']
# ['upson_quinn', '', 'youhoo', 'tech']
# ['peteryocum', '', 'proton', 'io']
# ['200912703', '', 'youhoo', 'org']
# ['hank2763', '', 'imail', 'io']
# ['roger4911', '', 'hotmoille', 'apple']
# ['thompsonlarry', '', 'email', 'net']
# ['ebner_casal', '', 'hotmoille', 'com']
# ['moodyroger', '', 'ecoin', 'com']
# ['delorenzo_adam', '', 'hotmoille', 'org']
# ['dan', 'delorenzo', 'proton', 'xyz']
# ['knutsondavid', '', 'napster', 'me']
# ['hal2231', '', 'hotmoille', 'me']
# ['quinn_aikin', '', 'hotmoille', 'net']
# ['trebilroger', '', 'belgaximus', 'com']
# ['tiernanmark', '', 'odul', 'apple']
# ['olson', 'george', 'odul', 'tech']
# ['reamer', '', 'imail', 'hu']
# ['haworth9991', '', 'email', 'gov']
# ['robertsmark', '', 'imail', 'gov']
# ['jack', '', 'belgaximus', 'com']
# ['trussel', '', 'youhoo', 'hu']
# ['jackupson', '', 'proton', 'xyz']
# ['nugent6976', '', 'napster', 'com']
# ['martin_kaskel', '', 'hotmoille', 'gov']
# ['halquinn', '', 'belgaximus', 'com']
# ['vail', 'frank', 'hotmoille', 'apple']
# ['nuttlesteve', '', 'odul', 'me']
# ['nathan', 'yocum', 'ecoin', 'apple']
# ['victorknutson', '', 'proton', 'io']
# ['kaskel', '', 'ecoin', 'me']
# ['72032888', '', 'email', 'me']
# ['joe', 'nuttle', 'youhoo', 'io']
# ['nathan3403', '', 'napster', 'apple']
# ['aaron', '', 'imail', 'me']
# ['aaron1573', '', 'odul', 'net']
# ['benmoody', '', 'proton', 'io']
# ['916085653', '', 'napster', 'hu']
# ['knutson', 'tim', 'napster', 'io']
# ['schickowski_tapia', '', 'hotmoille', 'tech']
# ['john5147', '', 'napster', 'gov']
# ['fredlawicki', '', 'hotmoille', 'me']
# ['nathan', '', 'ecoin', 'net']
# ['reardon', 'ben', 'ecoin', 'net']
# ['kellerhal', '', 'proton', 'tech']
# ['kalleg_nathan', '', 'ecoin', 'hu']
# ['roger', 'dinkins', 'proton', 'io']
# ['johnsen_cataldi', '', 'napster', 'io']
# ['hal', 'wagner', 'imail', 'com']
# ['bongard', '', 'hotmoille', 'tech']
# ['bowers_ulrich', '', 'email', 'me']
# ['nelsonroger', '', 'gaagle', 'xyz']
# ['lewis_ortiz', '', 'proton', 'me']
# ['reyes_steve', '', 'gaagle', 'apple']
# ['martin', 'edward', 'odul', 'org']
# ['ike1526', '', 'ecoin', 'net']
# ['76134991', '', 'imail', 'hu']
# ['aaron', 'pak', 'imail', 'tech']
# ['819378036', '', 'proton', 'com']
# ['ty9361', '', 'gaagle', 'xyz']
# ['frankwoo', '', 'belgaximus', 'hu']
# ['solberg', '', 'belgaximus', 'hu']
# ['turco', '', 'odul', 'apple']
# ['ashwoonthomas', '', 'odul', 'gov']
# ['kaskel', 'tim', 'youhoo', 'org']
# ['larry8418', '', 'belgaximus', 'me']
# ['tandyty', '', 'email', 'xyz']
# ['bauer_ripka', '', 'odul', 'xyz']
# ['866926931', '', 'ecoin', 'org']
# ['hylan_john', '', 'ecoin', 'hu']
# ['hoffman_darnell', '', 'napster', 'org']
# ['sonderling7306', '', 'belgaximus', 'gov']
# ['hank', '', 'email', 'gov']
# ['johnson_joe', '', 'email', 'hu']
# ['lawicki', '', 'gaagle', 'tech']
# ['johnson_yates', '', 'gaagle', 'gov']
# ['zeller_ty', '', 'gaagle', 'me']
# ['thomascasal', '', 'imail', 'net']
# ['wagle', 'dan', 'hotmoille', 'net']
# ['carl3060', '', 'proton', 'tech']
# ['roger6892', '', 'imail', 'hu']
# ['petervader', '', 'ecoin', 'io']
# ['waglehal', '', 'belgaximus', 'io']
# ['paulhydinger', '', 'proton', 'com']
# ['tapia_john', '', 'gaagle', 'xyz']
# ['andersonedward', '', 'ecoin', 'xyz']
# ['timsellon', '', 'hotmoille', 'com']
# ['tim', 'fietzer', 'gaagle', 'net']
# ['pakalex', '', 'gaagle', 'com']
# ['markpak', '', 'proton', 'io']
# ['victordinkins', '', 'ecoin', 'org']
# ['kaskel_duffman', '', 'imail', 'me']
# ['paul9959', '', 'email', 'gov']
# ['ike', 'maki', 'imail', 'me']
# ['406392428', '', 'belgaximus', 'hu']
# ['ory_nugent', '', 'email', 'xyz']
# ['solomangeorge', '', 'hotmoille', 'apple']
# ['bateman_weinstein', '', 'belgaximus', 'gov']
# ['zeaser', '', 'ecoin', 'gov']
# ['ulrichty', '', 'odul', 'hu']
# ['alexmcginnis', '', 'belgaximus', 'org']
# ['halrice', '', 'hotmoille', 'hu']
# ['nelson', 'steve', 'imail', 'hu']
# ['vail_chapman', '', 'youhoo', 'net']
# ['schiebelthomas', '', 'ecoin', 'hu']
# ['ike', 'hancock', 'imail', 'apple']
# ['roger', '', 'belgaximus', 'hu']
# ['nugent_fletcher', '', 'ecoin', 'hu']
# ['maki8692', '', 'imail', 'gov']
# ['adam', '', 'email', 'tech']
# ['adam', '', 'hotmoille', 'io']
# ['thomasyates', '', 'odul', 'com']
# ['celedon_walter', '', 'napster', 'hu']
# ['kassing4495', '', 'proton', 'io']
# ['boyd_george', '', 'odul', 'io']
# ['bowers_ebner', '', 'email', 'xyz']
# ['jack9352', '', 'odul', 'tech']
# ['lewisdan', '', 'youhoo', 'net']
# ['mccormackmark', '', 'hotmoille', 'net']
# ['timbauer', '', 'odul', 'org']
# ['reamer_rogers', '', 'proton', 'hu']
# ['soulisfred', '', 'belgaximus', 'gov']
# ['vader', 'tim', 'hotmoille', 'xyz']
# ['wagnerthomas', '', 'youhoo', 'tech']
# ['adamjagtap', '', 'hotmoille', 'apple']
# ['paul', 'reamer', 'napster', 'com']
# ['adam', '', 'belgaximus', 'io']
# ['ty', '', 'email', 'tech']
# ['edward', '', 'email', 'net']
# ['doran2286', '', 'imail', 'org']
# ['irwinhal', '', 'belgaximus', 'tech']
# ['tyschwager', '', 'odul', 'tech']
# ['georgemills', '', 'imail', 'apple']
# ['wagle389', '', 'odul', 'com']
# ['edwardferro', '', 'hotmoille', 'net']
# ['adamostrander', '', 'hotmoille', 'gov']
# ['258546748', '', 'imail', 'org']
# ['bencaswell', '', 'imail', 'gov']
# ['steve1862', '', 'hotmoille', 'com']
# ['halturco', '', 'email', 'hu']
# ['tiernan_casal', '', 'email', 'com']
# ['alexdoran', '', 'napster', 'org']
# ['frick_cannon', '', 'gaagle', 'tech']
# ['otto', '', 'email', 'apple']
# ['hal', '', 'email', 'tech']
# ['ulrich', 'thomas', 'odul', 'io']
# ['anderson_aaron', '', 'odul', 'me']
# ['hoffman_victor', '', 'imail', 'tech']
# ['larrythompson', '', 'imail', 'apple']
# ['ebnerjohn', '', 'gaagle', 'apple']
# ['frank', 'nelson', 'proton', 'net']
# ['ebner_reamer', '', 'email', 'me']
# ['trusela_paul', '', 'imail', 'me']
# ['dinkinsalex', '', 'email', 'io']
# ['jack3083', '', 'belgaximus', 'gov']
# ['casal', '', 'youhoo', 'gov']
# ['fred', '', 'imail', 'me']
# ['davisgeorge', '', 'napster', 'tech']
# ['jagtap', '', 'odul', 'com']
# ['fredvalente', '', 'gaagle', 'me']
# ['hylan', 'carl', 'hotmoille', 'gov']
# ['270804951', '', 'napster', 'org']
# ['uddin1875', '', 'napster', 'apple']
# ['turco', 'carl', 'belgaximus', 'tech']
# ['hoffman', '', 'gaagle', 'apple']
# ['joe', 'rogers', 'gaagle', 'xyz']
# ['schmitt_larry', '', 'odul', 'gov']
# ['carlsoloman', '', 'ecoin', 'com']
# ['nathan6115', '', 'imail', 'me']
# ['frank', '', 'imail', 'io']
# ['norquist_steve', '', 'belgaximus', 'com']
# ['paul', '', 'hotmoille', 'gov']
# ['orwig', '', 'odul', 'me']
# ['tislerdan', '', 'hotmoille', 'tech']
# ['edward6174', '', 'imail', 'me']
# ['montepettigrew', '', 'hotmoille', 'hu']
# ['schutzlarry', '', 'odul', 'net']
# ['zeasertim', '', 'proton', 'tech']
# ['walter', 'kassing', 'odul', 'tech']
# ['ferro', 'david', 'gaagle', 'tech']
# ['schmitt_schiebel', '', 'belgaximus', 'gov']
# ['martin', 'ben', 'imail', 'me']
# ['benventotla', '', 'youhoo', 'org']
# ['ziegler_soloman', '', 'imail', 'io']
# ['davidson_rogers', '', 'belgaximus', 'xyz']
# ['george', '', 'proton', 'org']
# ['ramachandran431', '', 'napster', 'hu']
# ['paulostrander', '', 'youhoo', 'xyz']
# ['tyseverson', '', 'hotmoille', 'hu']
# ['edwardortiz', '', 'hotmoille', 'tech']
# ['hal5999', '', 'email', 'org']
# ['moody3417', '', 'ecoin', 'gov']
# ['trebil_bowers', '', 'proton', 'org']
# ['pak9267', '', 'ecoin', 'hu']
# ['883886499', '', 'youhoo', 'io']
# ['peterknutson', '', 'gaagle', 'hu']
# ['mark', '', 'belgaximus', 'gov']
# ['660694516', '', 'napster', 'apple']
# ['larry', '', 'belgaximus', 'gov']
# ['ripka1096', '', 'email', 'apple']
# ['bowers', 'otto', 'proton', 'gov']
# ['ulrich_fred', '', 'imail', 'tech']
# ['dugelman_carl', '', 'youhoo', 'io']
# ['801140752', '', 'email', 'net']
# ['jurgenson', 'aaron', 'napster', 'io']
# ['stahl_ty', '', 'gaagle', 'tech']
# ['lawickimatthew', '', 'gaagle', 'tech']
# ['halbongard', '', 'hotmoille', 'tech']
# ['soukup', 'roger', 'youhoo', 'com']
# ['jack', 'sweeney', 'hotmoille', 'org']

# %% [markdown]
# **12. Another way of doing things.**

# %%
mail = "audrey.boulevart@benextcomapgny.com"
splitMail = mail.replace(".", " ").split("@").copy()

firstName = []
name = []
ope = []
zone = []

firstName.append(splitMail[0].split()[0])
name.append(splitMail[0].split()[-1])
ope.append(splitMail[1].split()[0])
zone.append(splitMail[1].split()[-1])

firstName, name, ope, zone

list_mail = open("./data/mail.txt")
for line in list_mail:
    split_line = line.replace(".", " ").split("@").copy()
    who = []
    who2 = []
    operator = []
    zone = []
    who.append(split_line[0].split()[0])
    who2.append(split_line[0].split()[-1])
    operator.append(split_line[1].split()[0])
    zone.append(split_line[1].split()[-1])

    print(who, who2, operator, zone)
# Out:
# ['vogal-roger'] ['vogal-roger'] ['mail'] ['tech']
# ['aikin'] ['joe'] ['odul'] ['xyz']
# ['moore'] ['moore'] ['imail'] ['gov']
# ['halknutson'] ['halknutson'] ['email'] ['xyz']
# ['alexnorquist'] ['alexnorquist'] ['proton'] ['com']
# ['matthewlulloff'] ['matthewlulloff'] ['mail'] ['me']
# ['jenson-thomas'] ['jenson-thomas'] ['belgaximus'] ['org']
# ['mark4451'] ['mark4451'] ['mail'] ['gov']
# ['monte'] ['hylan'] ['belgaximus'] ['net']
# ['dan80'] ['dan80'] ['mail'] ['com']
# ['schmitt-steve'] ['schmitt-steve'] ['napster'] ['org']
# ['knutsondan'] ['knutsondan'] ['belgaximus'] ['org']
# ['lepage'] ['lepage'] ['gaagle'] ['xyz']
# ['chapman_ben'] ['chapman_ben'] ['napster'] ['hu']
# ['upson1544'] ['upson1544'] ['youhoo'] ['hu']
# ['552966959'] ['552966959'] ['belgaximus'] ['hu']
# ['soloman_ziegler'] ['soloman_ziegler'] ['email'] ['tech']
# ['ortiz'] ['mark'] ['napster'] ['me']
# ['ashwoon_hank'] ['ashwoon_hank'] ['imail'] ['io']
# ['pettigrew'] ['pettigrew'] ['proton'] ['hu']
# ['doranedward'] ['doranedward'] ['napster'] ['net']
# ['mills_joe'] ['mills_joe'] ['imail'] ['xyz']
# ['valente_alex'] ['valente_alex'] ['mail'] ['net']
# ['yang'] ['yang'] ['email'] ['hu']
# ['ike'] ['ike'] ['ecoin'] ['io']
# ['hankshaffer'] ['hankshaffer'] ['mail'] ['io']
# ['larrytrebil'] ['larrytrebil'] ['email'] ['org']
# ['davis_ike'] ['davis_ike'] ['odul'] ['io']
# ['davidsonhal'] ['davidsonhal'] ['hotmoille'] ['apple']
# ['john8733'] ['john8733'] ['youhoo'] ['com']
# ['johnfletcher'] ['johnfletcher'] ['youhoo'] ['me']
# ['cataldi_larry'] ['cataldi_larry'] ['napster'] ['com']
# ['rogerfietzer'] ['rogerfietzer'] ['imail'] ['apple']
# ['edward4185'] ['edward4185'] ['gaagle'] ['gov']
# ['hancock_matthew'] ['hancock_matthew'] ['belgaximus'] ['gov']
# ['solberg_cast'] ['solberg_cast'] ['gaagle'] ['apple']
# ['vader-jack'] ['vader-jack'] ['youhoo'] ['hu']
# ['georgepak'] ['georgepak'] ['gaagle'] ['me']
# ['caswell-hal'] ['caswell-hal'] ['ecoin'] ['io']
# ['ike'] ['ike'] ['ecoin'] ['com']
# ['tapia_quinn'] ['tapia_quinn'] ['gaagle'] ['io']
# ['795419860'] ['795419860'] ['imail'] ['tech']
# ['chambers_johnsen'] ['chambers_johnsen'] ['mail'] ['me']
# ['jack'] ['jack'] ['gaagle'] ['apple']
# ['joe'] ['joe'] ['ecoin'] ['tech']
# ['reyesaaron'] ['reyesaaron'] ['mail'] ['hu']
# ['ben'] ['yang'] ['ecoin'] ['com']
# ['pettigrewgeorge'] ['pettigrewgeorge'] ['odul'] ['me']
# ['miller'] ['peter'] ['mail'] ['xyz']
# ['linde-carl'] ['linde-carl'] ['belgaximus'] ['org']
# ['boyd_carl'] ['boyd_carl'] ['napster'] ['me']
# ['yocum_mark'] ['yocum_mark'] ['youhoo'] ['com']
# ['davidferro'] ['davidferro'] ['mail'] ['com']
# ['george59'] ['george59'] ['ecoin'] ['gov']
# ['johnsen2201'] ['johnsen2201'] ['imail'] ['io']
# ['thompson_adam'] ['thompson_adam'] ['mail'] ['me']
# ['schutzlarry'] ['schutzlarry'] ['email'] ['apple']
# ['quizoz'] ['joe'] ['napster'] ['tech']
# ['matthew8227'] ['matthew8227'] ['hotmoille'] ['me']
# ['alex'] ['alex'] ['mail'] ['net']
# ['georgemoody'] ['georgemoody'] ['hotmoille'] ['com']
# ['lawicki589'] ['lawicki589'] ['hotmoille'] ['me']
# ['doran7947'] ['doran7947'] ['gaagle'] ['tech']
# ['baueraaron'] ['baueraaron'] ['mail'] ['gov']
# ['mark'] ['mark'] ['email'] ['io']
# ['waltermartin'] ['waltermartin'] ['ecoin'] ['gov']
# ['kaskel'] ['kaskel'] ['mail'] ['tech']
# ['roberts_matthew'] ['roberts_matthew'] ['mail'] ['hu']
# ['george'] ['george'] ['hotmoille'] ['hu']
# ['ferry'] ['victor'] ['gaagle'] ['com']
# ['fred'] ['weiss'] ['odul'] ['tech']
# ['jurgensonpeter'] ['jurgensonpeter'] ['proton'] ['tech']
# ['stevefietzer'] ['stevefietzer'] ['ecoin'] ['tech']
# ['sonderling_caswell'] ['sonderling_caswell'] ['napster'] ['tech']
# ['johnsen'] ['walter'] ['odul'] ['net']
# ['mccormack'] ['mccormack'] ['napster'] ['xyz']
# ['roberts'] ['hank'] ['proton'] ['net']
# ['valente'] ['valente'] ['gaagle'] ['xyz']
# ['ory_walter'] ['ory_walter'] ['proton'] ['hu']
# ['tyirwin'] ['tyirwin'] ['proton'] ['tech']
# ['paulferry'] ['paulferry'] ['hotmoille'] ['com']
# ['george'] ['george'] ['youhoo'] ['gov']
# ['frank'] ['lulloff'] ['mail'] ['apple']
# ['ripka6596'] ['ripka6596'] ['mail'] ['net']
# ['wagner_schuster'] ['wagner_schuster'] ['mail'] ['me']
# ['mccormack'] ['carl'] ['imail'] ['xyz']
# ['851886792'] ['851886792'] ['youhoo'] ['hu']
# ['zeaser_aaron'] ['zeaser_aaron'] ['belgaximus'] ['apple']
# ['adam'] ['adam'] ['proton'] ['net']
# ['tisler'] ['roger'] ['hotmoille'] ['tech']
# ['ferro-dan'] ['ferro-dan'] ['proton'] ['io']
# ['reardon-alex'] ['reardon-alex'] ['gaagle'] ['tech']
# ['severson_george'] ['severson_george'] ['proton'] ['org']
# ['otto'] ['nuttle'] ['proton'] ['hu']
# ['illingsworth'] ['illingsworth'] ['belgaximus'] ['gov']
# ['danfletcher'] ['danfletcher'] ['mail'] ['net']
# ['alex685'] ['alex685'] ['hotmoille'] ['com']
# ['hancock_valente'] ['hancock_valente'] ['hotmoille'] ['net']
# ['carl7884'] ['carl7884'] ['mail'] ['apple']
# ['paul9581'] ['paul9581'] ['email'] ['tech']
# ['sawyer_chambers'] ['sawyer_chambers'] ['belgaximus'] ['xyz']
# ['johnsen'] ['tim'] ['email'] ['gov']
# ['aaron'] ['roberts'] ['imail'] ['gov']
# ['schiebel2392'] ['schiebel2392'] ['hotmoille'] ['xyz']
# ['mccormackedward'] ['mccormackedward'] ['proton'] ['com']
# ['tapia1876'] ['tapia1876'] ['imail'] ['tech']
# ['quizoz9628'] ['quizoz9628'] ['belgaximus'] ['apple']
# ['rogerstahl'] ['rogerstahl'] ['odul'] ['apple']
# ['schutz_johnsen'] ['schutz_johnsen'] ['ecoin'] ['tech']
# ['schutz-monte'] ['schutz-monte'] ['hotmoille'] ['net']
# ['carlupson'] ['carlupson'] ['napster'] ['me']
# ['larry349'] ['larry349'] ['odul'] ['me']
# ['matthew'] ['linde'] ['youhoo'] ['tech']
# ['mcginnis'] ['mcginnis'] ['imail'] ['xyz']
# ['kalleg'] ['monte'] ['mail'] ['com']
# ['nugent_jack'] ['nugent_jack'] ['gaagle'] ['hu']
# ['wagle_john'] ['wagle_john'] ['napster'] ['gov']
# ['chapmannathan'] ['chapmannathan'] ['youhoo'] ['org']
# ['christensen-larry'] ['christensen-larry'] ['hotmoille'] ['net']
# ['hal536'] ['hal536'] ['napster'] ['net']
# ['472510707'] ['472510707'] ['odul'] ['io']
# ['thomas'] ['casal'] ['hotmoille'] ['com']
# ['adamillingsworth'] ['adamillingsworth'] ['youhoo'] ['xyz']
# ['weiss-adam'] ['weiss-adam'] ['mail'] ['tech']
# ['peterstahl'] ['peterstahl'] ['gaagle'] ['me']
# ['victortandy'] ['victortandy'] ['youhoo'] ['hu']
# ['fredturco'] ['fredturco'] ['mail'] ['hu']
# ['adam'] ['sellon'] ['email'] ['tech']
# ['vader-matthew'] ['vader-matthew'] ['belgaximus'] ['gov']
# ['ike3831'] ['ike3831'] ['proton'] ['apple']
# ['timfletcher'] ['timfletcher'] ['imail'] ['xyz']
# ['frank'] ['schickowski'] ['gaagle'] ['io']
# ['566486749'] ['566486749'] ['email'] ['net']
# ['675340599'] ['675340599'] ['proton'] ['org']
# ['davis_nathan'] ['davis_nathan'] ['ecoin'] ['com']
# ['253159777'] ['253159777'] ['gaagle'] ['net']
# ['edwardschutz'] ['edwardschutz'] ['hotmoille'] ['net']
# ['sagar_carl'] ['sagar_carl'] ['hotmoille'] ['org']
# ['331837931'] ['331837931'] ['napster'] ['me']
# ['aaronbongard'] ['aaronbongard'] ['odul'] ['xyz']
# ['ty9516'] ['ty9516'] ['belgaximus'] ['net']
# ['fred'] ['fred'] ['mail'] ['apple']
# ['schustersteve'] ['schustersteve'] ['proton'] ['tech']
# ['moody_schiebel'] ['moody_schiebel'] ['hotmoille'] ['me']
# ['soloman_ramachandran'] ['soloman_ramachandran'] ['gaagle'] ['org']
# ['victor630'] ['victor630'] ['hotmoille'] ['hu']
# ['yang_trebil'] ['yang_trebil'] ['imail'] ['me']
# ['hoffman_zeller'] ['hoffman_zeller'] ['imail'] ['me']
# ['ripka_thomas'] ['ripka_thomas'] ['email'] ['tech']
# ['vader'] ['hal'] ['belgaximus'] ['org']
# ['ottochambers'] ['ottochambers'] ['imail'] ['io']
# ['tylulloff'] ['tylulloff'] ['email'] ['gov']
# ['263935905'] ['263935905'] ['youhoo'] ['tech']
# ['carlvail'] ['carlvail'] ['napster'] ['me']
# ['hanktisler'] ['hanktisler'] ['ecoin'] ['com']
# ['uddin1510'] ['uddin1510'] ['email'] ['org']
# ['mccormack'] ['carl'] ['proton'] ['net']
# ['vader'] ['vader'] ['proton'] ['me']
# ['nelsonmark'] ['nelsonmark'] ['imail'] ['xyz']
# ['adamvan'] ['zandt'] ['belgaximus'] ['hu']
# ['ziegler-dan'] ['ziegler-dan'] ['proton'] ['me']
# ['uflan'] ['uflan'] ['mail'] ['gov']
# ['sawyer-frank'] ['sawyer-frank'] ['ecoin'] ['net']
# ['dan6858'] ['dan6858'] ['mail'] ['io']
# ['stahl'] ['stahl'] ['odul'] ['apple']
# ['timirwin'] ['timirwin'] ['hotmoille'] ['me']
# ['davis9134'] ['davis9134'] ['imail'] ['tech']
# ['benuflan'] ['benuflan'] ['mail'] ['org']
# ['davidziegler'] ['davidziegler'] ['imail'] ['tech']
# ['carl1959'] ['carl1959'] ['youhoo'] ['apple']
# ['alexkeller'] ['alexkeller'] ['gaagle'] ['com']
# ['ostranderjoe'] ['ostranderjoe'] ['mail'] ['tech']
# ['469322116'] ['469322116'] ['hotmoille'] ['tech']
# ['monte7207'] ['monte7207'] ['gaagle'] ['hu']
# ['lawicki'] ['lawicki'] ['mail'] ['io']
# ['fredtiernan'] ['fredtiernan'] ['email'] ['net']
# ['fietzer'] ['fietzer'] ['gaagle'] ['org']
# ['benquinn'] ['benquinn'] ['proton'] ['com']
# ['matthew8594'] ['matthew8594'] ['mail'] ['xyz']
# ['hal'] ['weiss'] ['email'] ['xyz']
# ['sweeney'] ['otto'] ['gaagle'] ['apple']
# ['fletcher_monte'] ['fletcher_monte'] ['email'] ['com']
# ['adamkalleg'] ['adamkalleg'] ['mail'] ['hu']
# ['woothomas'] ['woothomas'] ['napster'] ['tech']
# ['thomasdavidson'] ['thomasdavidson'] ['mail'] ['io']
# ['moore3490'] ['moore3490'] ['mail'] ['me']
# ['walter'] ['walter'] ['napster'] ['io']
# ['ventotla'] ['alex'] ['mail'] ['tech']
# ['dinkins'] ['dinkins'] ['proton'] ['gov']
# ['950099319'] ['950099319'] ['imail'] ['net']
# ['roger'] ['myers'] ['gaagle'] ['io']
# ['tim'] ['trusela'] ['hotmoille'] ['gov']
# ['sawyer'] ['adam'] ['belgaximus'] ['org']
# ['ben'] ['jagtap'] ['napster'] ['tech']
# ['carlmills'] ['carlmills'] ['ecoin'] ['me']
# ['markboyd'] ['markboyd'] ['belgaximus'] ['apple']
# ['johnyocum'] ['johnyocum'] ['mail'] ['apple']
# ['887934540'] ['887934540'] ['email'] ['net']
# ['ortizjack'] ['ortizjack'] ['gaagle'] ['gov']
# ['tiernan4456'] ['tiernan4456'] ['mail'] ['xyz']
# ['roberts_myers'] ['roberts_myers'] ['email'] ['tech']
# ['soloman8370'] ['soloman8370'] ['odul'] ['gov']
# ['alex3716'] ['alex3716'] ['ecoin'] ['me']
# ['tim'] ['tim'] ['proton'] ['me']
# ['thompson85'] ['thompson85'] ['proton'] ['hu']
# ['reyes'] ['jack'] ['email'] ['hu']
# ['resnick'] ['resnick'] ['mail'] ['hu']
# ['dinkinsroger'] ['dinkinsroger'] ['youhoo'] ['apple']
# ['mills9634'] ['mills9634'] ['odul'] ['xyz']
# ['821464747'] ['821464747'] ['odul'] ['gov']
# ['valente_hydinger'] ['valente_hydinger'] ['hotmoille'] ['tech']
# ['schiebel1467'] ['schiebel1467'] ['proton'] ['io']
# ['larryschiebel'] ['larryschiebel'] ['ecoin'] ['net']
# ['adamostrander'] ['adamostrander'] ['mail'] ['gov']
# ['jagtap'] ['fred'] ['proton'] ['gov']
# ['edward'] ['haworth'] ['imail'] ['com']
# ['matthewcataldi'] ['matthewcataldi'] ['youhoo'] ['net']
# ['resnick_moore'] ['resnick_moore'] ['mail'] ['tech']
# ['zeller'] ['zeller'] ['email'] ['org']
# ['trebil-george'] ['trebil-george'] ['youhoo'] ['apple']
# ['duffman'] ['duffman'] ['email'] ['net']
# ['ottoortiz'] ['ottoortiz'] ['youhoo'] ['xyz']
# ['david'] ['rice'] ['mail'] ['org']
# ['delorenzo'] ['delorenzo'] ['ecoin'] ['me']
# ['miller_keller'] ['miller_keller'] ['email'] ['org']
# ['illingsworth'] ['illingsworth'] ['youhoo'] ['gov']
# ['nelson'] ['nelson'] ['odul'] ['tech']
# ['rogers_john'] ['rogers_john'] ['gaagle'] ['tech']
# ['fredwagner'] ['fredwagner'] ['mail'] ['org']
# ['tyresnick'] ['tyresnick'] ['imail'] ['io']
# ['hal'] ['yang'] ['napster'] ['xyz']
# ['tiernan6950'] ['tiernan6950'] ['belgaximus'] ['tech']
# ['schuster-john'] ['schuster-john'] ['email'] ['tech']
# ['mills'] ['mills'] ['belgaximus'] ['xyz']
# ['casal'] ['hank'] ['proton'] ['xyz']
# ['roger'] ['zandt'] ['gaagle'] ['org']
# ['stevevader'] ['stevevader'] ['mail'] ['me']
# ['hankupson'] ['hankupson'] ['odul'] ['xyz']
# ['184536366'] ['184536366'] ['mail'] ['me']
# ['irwin_yang'] ['irwin_yang'] ['gaagle'] ['gov']
# ['napier'] ['aaron'] ['email'] ['org']
# ['edward'] ['schickowski'] ['youhoo'] ['xyz']
# ['fletcher-alex'] ['fletcher-alex'] ['imail'] ['com']
# ['chambers-monte'] ['chambers-monte'] ['mail'] ['gov']
# ['rogers_lawicki'] ['rogers_lawicki'] ['gaagle'] ['apple']
# ['tapia_upson'] ['tapia_upson'] ['ecoin'] ['me']
# ['uddin_yocum'] ['uddin_yocum'] ['gaagle'] ['hu']
# ['bongardroger'] ['bongardroger'] ['napster'] ['net']
# ['victor'] ['victor'] ['youhoo'] ['gov']
# ['ty'] ['schwager'] ['napster'] ['io']
# ['paultiernan'] ['paultiernan'] ['youhoo'] ['xyz']
# ['roger836'] ['roger836'] ['gaagle'] ['tech']
# ['pettigrew'] ['victor'] ['email'] ['io']
# ['steve'] ['ingram'] ['mail'] ['me']
# ['johnsen4863'] ['johnsen4863'] ['gaagle'] ['apple']
# ['soloman-roger'] ['soloman-roger'] ['ecoin'] ['apple']
# ['34658710'] ['34658710'] ['mail'] ['xyz']
# ['cannon-joe'] ['cannon-joe'] ['mail'] ['io']
# ['284857146'] ['284857146'] ['mail'] ['net']
# ['890280316'] ['890280316'] ['ecoin'] ['me']
# ['kalleg-joe'] ['kalleg-joe'] ['belgaximus'] ['com']
# ['weinstein'] ['roger'] ['imail'] ['io']
# ['alexschmitt'] ['alexschmitt'] ['odul'] ['org']
# ['dan'] ['uddin'] ['ecoin'] ['apple']
# ['steve'] ['stahl'] ['hotmoille'] ['me']
# ['matthewfrick'] ['matthewfrick'] ['hotmoille'] ['com']
# ['237336989'] ['237336989'] ['email'] ['io']
# ['larry6016'] ['larry6016'] ['youhoo'] ['org']
# ['otto5489'] ['otto5489'] ['gaagle'] ['tech']
# ['bongard_ty'] ['bongard_ty'] ['ecoin'] ['xyz']
# ['169102677'] ['169102677'] ['gaagle'] ['me']
# ['upson'] ['hal'] ['gaagle'] ['io']
# ['hal'] ['hal'] ['hotmoille'] ['gov']
# ['lepage-aaron'] ['lepage-aaron'] ['hotmoille'] ['apple']
# ['sonderling_mark'] ['sonderling_mark'] ['belgaximus'] ['me']
# ['430581778'] ['430581778'] ['hotmoille'] ['com']
# ['walterkassing'] ['walterkassing'] ['napster'] ['tech']
# ['victorceledon'] ['victorceledon'] ['ecoin'] ['xyz']
# ['hesch-john'] ['hesch-john'] ['odul'] ['io']
# ['kassing'] ['kassing'] ['hotmoille'] ['apple']
# ['duffman6005'] ['duffman6005'] ['youhoo'] ['hu']
# ['frank'] ['ventotla'] ['belgaximus'] ['io']
# ['uddinotto'] ['uddinotto'] ['youhoo'] ['org']
# ['703979481'] ['703979481'] ['ecoin'] ['apple']
# ['paul'] ['nugent'] ['ecoin'] ['apple']
# ['nugent'] ['nugent'] ['proton'] ['org']
# ['alex'] ['alex'] ['odul'] ['tech']
# ['aaronsweeney'] ['aaronsweeney'] ['ecoin'] ['apple']
# ['knutson_celedon'] ['knutson_celedon'] ['hotmoille'] ['xyz']
# ['tydoran'] ['tydoran'] ['belgaximus'] ['org']
# ['millerhal'] ['millerhal'] ['hotmoille'] ['org']
# ['adamnuttle'] ['adamnuttle'] ['youhoo'] ['hu']
# ['ashwoon8609'] ['ashwoon8609'] ['youhoo'] ['tech']
# ['victormiller'] ['victormiller'] ['mail'] ['org']
# ['mcginnis_reardon'] ['mcginnis_reardon'] ['youhoo'] ['org']
# ['ramachandran'] ['mark'] ['proton'] ['com']
# ['monteshaffer'] ['monteshaffer'] ['proton'] ['tech']
# ['monte'] ['monte'] ['proton'] ['gov']
# ['pettigrew9750'] ['pettigrew9750'] ['proton'] ['com']
# ['yocum_dan'] ['yocum_dan'] ['napster'] ['xyz']
# ['yocum-victor'] ['yocum-victor'] ['imail'] ['xyz']
# ['darnell8483'] ['darnell8483'] ['email'] ['xyz']
# ['zeller-matthew'] ['zeller-matthew'] ['ecoin'] ['apple']
# ['pettigrewlarry'] ['pettigrewlarry'] ['imail'] ['tech']
# ['yocum8146'] ['yocum8146'] ['mail'] ['me']
# ['ben5039'] ['ben5039'] ['hotmoille'] ['tech']
# ['mcginnis'] ['dan'] ['gaagle'] ['tech']
# ['roger'] ['vogal'] ['email'] ['xyz']
# ['adamtisler'] ['adamtisler'] ['gaagle'] ['xyz']
# ['matthew3420'] ['matthew3420'] ['hotmoille'] ['tech']
# ['john8770'] ['john8770'] ['napster'] ['hu']
# ['hesch_zeller'] ['hesch_zeller'] ['email'] ['apple']
# ['christensen_ben'] ['christensen_ben'] ['proton'] ['com']
# ['walter'] ['soulis'] ['email'] ['com']
# ['ben8671'] ['ben8671'] ['proton'] ['tech']
# ['frankjagtap'] ['frankjagtap'] ['napster'] ['com']
# ['peternuttle'] ['peternuttle'] ['napster'] ['gov']
# ['victor8847'] ['victor8847'] ['ecoin'] ['io']
# ['ferry'] ['paul'] ['imail'] ['org']
# ['690377034'] ['690377034'] ['gaagle'] ['apple']
# ['lepageroger'] ['lepageroger'] ['proton'] ['gov']
# ['john'] ['zeaser'] ['imail'] ['gov']
# ['valente-jack'] ['valente-jack'] ['gaagle'] ['me']
# ['4709006'] ['4709006'] ['napster'] ['tech']
# ['deitz-monte'] ['deitz-monte'] ['odul'] ['gov']
# ['fietzer-frank'] ['fietzer-frank'] ['hotmoille'] ['tech']
# ['kaskel5284'] ['kaskel5284'] ['belgaximus'] ['org']
# ['davidson-monte'] ['davidson-monte'] ['mail'] ['xyz']
# ['cataldi_ingram'] ['cataldi_ingram'] ['mail'] ['tech']
# ['hanktiernan'] ['hanktiernan'] ['youhoo'] ['io']
# ['ripka2474'] ['ripka2474'] ['hotmoille'] ['tech']
# ['cataldi_matthew'] ['cataldi_matthew'] ['odul'] ['me']
# ['lewis_lulloff'] ['lewis_lulloff'] ['mail'] ['org']
# ['matthewmccord'] ['matthewmccord'] ['mail'] ['me']
# ['turco8476'] ['turco8476'] ['mail'] ['apple']
# ['steve6967'] ['steve6967'] ['odul'] ['hu']
# ['ortiz-larry'] ['ortiz-larry'] ['napster'] ['org']
# ['irwincarl'] ['irwincarl'] ['belgaximus'] ['gov']
# ['wakefieldjoe'] ['wakefieldjoe'] ['ecoin'] ['org']
# ['nathansagar'] ['nathansagar'] ['email'] ['apple']
# ['hydinger_larry'] ['hydinger_larry'] ['odul'] ['xyz']
# ['frank'] ['yates'] ['proton'] ['gov']
# ['fred'] ['fred'] ['mail'] ['apple']
# ['schuster5868'] ['schuster5868'] ['youhoo'] ['tech']
# ['rogerschwager'] ['rogerschwager'] ['imail'] ['tech']
# ['163622426'] ['163622426'] ['imail'] ['com']
# ['baxstercarl'] ['baxstercarl'] ['proton'] ['net']
# ['yang-hal'] ['yang-hal'] ['mail'] ['net']
# ['aikin'] ['aikin'] ['napster'] ['gov']
# ['ortiz-david'] ['ortiz-david'] ['mail'] ['io']
# ['tisler_reyes'] ['tisler_reyes'] ['imail'] ['io']
# ['stahl-thomas'] ['stahl-thomas'] ['mail'] ['org']
# ['aaron'] ['trusela'] ['mail'] ['gov']
# ['573168868'] ['573168868'] ['mail'] ['tech']
# ['monte1021'] ['monte1021'] ['hotmoille'] ['gov']
# ['petermccord'] ['petermccord'] ['mail'] ['xyz']
# ['quizoz'] ['quizoz'] ['proton'] ['apple']
# ['vail_soukup'] ['vail_soukup'] ['proton'] ['apple']
# ['thomassonderling'] ['thomassonderling'] ['napster'] ['com']
# ['frankaikin'] ['frankaikin'] ['odul'] ['io']
# ['aaronillingsworth'] ['aaronillingsworth'] ['hotmoille'] ['com']
# ['859491337'] ['859491337'] ['youhoo'] ['hu']
# ['paul'] ['eastman'] ['napster'] ['io']
# ['waltertisler'] ['waltertisler'] ['belgaximus'] ['apple']
# ['ferro_caswell'] ['ferro_caswell'] ['hotmoille'] ['com']
# ['george'] ['george'] ['gaagle'] ['hu']
# ['timorwig'] ['timorwig'] ['email'] ['io']
# ['jones'] ['jones'] ['napster'] ['net']
# ['hoffman'] ['roger'] ['youhoo'] ['xyz']
# ['ashwoon'] ['ashwoon'] ['mail'] ['tech']
# ['matthew'] ['trusela'] ['imail'] ['io']
# ['larry2207'] ['larry2207'] ['imail'] ['apple']
# ['rice_sonderling'] ['rice_sonderling'] ['gaagle'] ['hu']
# ['nuttleben'] ['nuttleben'] ['proton'] ['net']
# ['dewalt_martin'] ['dewalt_martin'] ['belgaximus'] ['io']
# ['ikekassing'] ['ikekassing'] ['gaagle'] ['com']
# ['240044289'] ['240044289'] ['odul'] ['tech']
# ['otto'] ['otto'] ['napster'] ['hu']
# ['ferro'] ['edward'] ['imail'] ['xyz']
# ['hankanderson'] ['hankanderson'] ['imail'] ['net']
# ['deitz-roger'] ['deitz-roger'] ['odul'] ['net']
# ['turco_ike'] ['turco_ike'] ['mail'] ['xyz']
# ['dan'] ['deitz'] ['belgaximus'] ['gov']
# ['orwig_sweeney'] ['orwig_sweeney'] ['proton'] ['me']
# ['bencaswell'] ['bencaswell'] ['youhoo'] ['apple']
# ['chambers'] ['victor'] ['email'] ['net']
# ['sweeney_david'] ['sweeney_david'] ['mail'] ['hu']
# ['579081959'] ['579081959'] ['ecoin'] ['hu']
# ['moore'] ['fred'] ['imail'] ['com']
# ['thomas'] ['thomas'] ['gaagle'] ['me']
# ['darnell-otto'] ['darnell-otto'] ['imail'] ['com']
# ['orwig'] ['orwig'] ['imail'] ['tech']
# ['haworth-john'] ['haworth-john'] ['imail'] ['org']
# ['nathankalleg'] ['nathankalleg'] ['mail'] ['xyz']
# ['hal'] ['hal'] ['imail'] ['me']
# ['yocum'] ['yocum'] ['mail'] ['me']
# ['robertsalex'] ['robertsalex'] ['mail'] ['gov']
# ['alex9835'] ['alex9835'] ['email'] ['org']
# ['roberts-hank'] ['roberts-hank'] ['hotmoille'] ['hu']
# ['nathanripka'] ['nathanripka'] ['belgaximus'] ['com']
# ['sonderling'] ['sonderling'] ['napster'] ['xyz']
# ['matthew'] ['duffman'] ['gaagle'] ['net']
# ['monte2098'] ['monte2098'] ['odul'] ['io']
# ['victor'] ['tiernan'] ['email'] ['hu']
# ['cataldi_john'] ['cataldi_john'] ['mail'] ['org']
# ['822140569'] ['822140569'] ['proton'] ['net']
# ['joe'] ['joe'] ['hotmoille'] ['com']
# ['matthew'] ['matthew'] ['gaagle'] ['tech']
# ['walter'] ['walter'] ['napster'] ['net']
# ['baxster_zeaser'] ['baxster_zeaser'] ['mail'] ['hu']
# ['schickowski-hal'] ['schickowski-hal'] ['proton'] ['apple']
# ['moody-alex'] ['moody-alex'] ['odul'] ['org']
# ['yocum_ventotla'] ['yocum_ventotla'] ['email'] ['tech']
# ['vader_sweeney'] ['vader_sweeney'] ['ecoin'] ['hu']
# ['schutz'] ['schutz'] ['mail'] ['hu']
# ['orwig_mills'] ['orwig_mills'] ['youhoo'] ['me']
# ['roger7781'] ['roger7781'] ['odul'] ['io']
# ['dugan_thomas'] ['dugan_thomas'] ['odul'] ['tech']
# ['lulloff'] ['lulloff'] ['mail'] ['net']
# ['vader'] ['vader'] ['gaagle'] ['apple']
# ['otto'] ['otto'] ['gaagle'] ['xyz']
# ['sawyer_johnson'] ['sawyer_johnson'] ['hotmoille'] ['apple']
# ['george'] ['george'] ['hotmoille'] ['net']
# ['anderson'] ['john'] ['hotmoille'] ['gov']
# ['hydinger_aaron'] ['hydinger_aaron'] ['ecoin'] ['com']
# ['monte'] ['monte'] ['hotmoille'] ['com']
# ['severson_aaron'] ['severson_aaron'] ['proton'] ['io']
# ['jack'] ['fletcher'] ['napster'] ['com']
# ['jurgensonpaul'] ['jurgensonpaul'] ['ecoin'] ['io']
# ['438861443'] ['438861443'] ['ecoin'] ['gov']
# ['aaron'] ['aaron'] ['proton'] ['com']
# ['fletcher_thompson'] ['fletcher_thompson'] ['mail'] ['com']
# ['weiss2334'] ['weiss2334'] ['mail'] ['net']
# ['eastman-ty'] ['eastman-ty'] ['belgaximus'] ['me']
# ['doran'] ['doran'] ['email'] ['org']
# ['sweeney_nathan'] ['sweeney_nathan'] ['proton'] ['xyz']
# ['vogal9413'] ['vogal9413'] ['mail'] ['tech']
# ['celedon_bauer'] ['celedon_bauer'] ['gaagle'] ['net']
# ['vader-victor'] ['vader-victor'] ['mail'] ['tech']
# ['873166067'] ['873166067'] ['mail'] ['net']
# ['ben'] ['bongard'] ['hotmoille'] ['com']
# ['carl'] ['weiss'] ['mail'] ['me']
# ['421931320'] ['421931320'] ['belgaximus'] ['gov']
# ['cataldi_haworth'] ['cataldi_haworth'] ['gaagle'] ['com']
# ['vogal-carl'] ['vogal-carl'] ['mail'] ['xyz']
# ['290273746'] ['290273746'] ['hotmoille'] ['me']
# ['tybauer'] ['tybauer'] ['imail'] ['apple']
# ['larrymyers'] ['larrymyers'] ['hotmoille'] ['tech']
# ['soloman-jack'] ['soloman-jack'] ['imail'] ['gov']
# ['rice_mark'] ['rice_mark'] ['mail'] ['me']
# ['orymonte'] ['orymonte'] ['youhoo'] ['me']
# ['mcginnis-tim'] ['mcginnis-tim'] ['mail'] ['xyz']
# ['nathanhancock'] ['nathanhancock'] ['mail'] ['net']
# ['lawless'] ['fred'] ['imail'] ['tech']
# ['paulkassing'] ['paulkassing'] ['mail'] ['gov']
# ['fredroot'] ['fredroot'] ['odul'] ['com']
# ['hesch-ty'] ['hesch-ty'] ['napster'] ['tech']
# ['napier3011'] ['napier3011'] ['email'] ['com']
# ['napier_ortiz'] ['napier_ortiz'] ['mail'] ['org']
# ['tynapier'] ['tynapier'] ['napster'] ['org']
# ['ty3947'] ['ty3947'] ['ecoin'] ['io']
# ['ben'] ['ben'] ['odul'] ['com']
# ['resnickmonte'] ['resnickmonte'] ['mail'] ['hu']
# ['sawyer'] ['sawyer'] ['imail'] ['com']
# ['kaskel-peter'] ['kaskel-peter'] ['youhoo'] ['tech']
# ['schwager9365'] ['schwager9365'] ['hotmoille'] ['io']
# ['aaronlewis'] ['aaronlewis'] ['proton'] ['gov']
# ['nelson_jack'] ['nelson_jack'] ['gaagle'] ['apple']
# ['upson1390'] ['upson1390'] ['proton'] ['apple']
# ['871781143'] ['871781143'] ['odul'] ['org']
# ['269062053'] ['269062053'] ['youhoo'] ['me']
# ['victorreardon'] ['victorreardon'] ['proton'] ['com']
# ['soloman'] ['soloman'] ['gaagle'] ['tech']
# ['aaronsagar'] ['aaronsagar'] ['ecoin'] ['org']
# ['alex'] ['alex'] ['odul'] ['hu']
# ['van'] ['zandt2300'] ['gaagle'] ['xyz']
# ['ike5340'] ['ike5340'] ['email'] ['apple']
# ['120987413'] ['120987413'] ['email'] ['tech']
# ['ziegler'] ['ziegler'] ['hotmoille'] ['hu']
# ['van'] ['zandt'] ['email'] ['me']
# ['tisler'] ['monte'] ['odul'] ['gov']
# ['van'] ['zandt8519'] ['odul'] ['me']
# ['victorquinn'] ['victorquinn'] ['gaagle'] ['io']
# ['lulloffhal'] ['lulloffhal'] ['mail'] ['net']
# ['aaronebner'] ['aaronebner'] ['youhoo'] ['apple']
# ['fred'] ['moore'] ['gaagle'] ['net']
# ['adam3605'] ['adam3605'] ['gaagle'] ['io']
# ['thompson'] ['thompson'] ['mail'] ['hu']
# ['stevewagle'] ['stevewagle'] ['napster'] ['com']
# ['montedeitz'] ['montedeitz'] ['napster'] ['hu']
# ['vanderpoel-adam'] ['vanderpoel-adam'] ['proton'] ['gov']
# ['orwig_john'] ['orwig_john'] ['email'] ['org']
# ['roger'] ['roger'] ['napster'] ['apple']
# ['edwarddeitz'] ['edwarddeitz'] ['gaagle'] ['tech']
# ['273554425'] ['273554425'] ['proton'] ['gov']
# ['edward'] ['darnell'] ['proton'] ['org']
# ['marknapier'] ['marknapier'] ['youhoo'] ['com']
# ['paul635'] ['paul635'] ['mail'] ['xyz']
# ['upson'] ['peter'] ['gaagle'] ['me']
# ['john'] ['stahl'] ['email'] ['xyz']
# ['duffman'] ['aaron'] ['proton'] ['hu']
# ['jenson'] ['jenson'] ['hotmoille'] ['hu']
# ['rogermcginnis'] ['rogermcginnis'] ['napster'] ['tech']
# ['soukup'] ['soukup'] ['belgaximus'] ['gov']
# ['soloman'] ['soloman'] ['odul'] ['apple']
# ['877692701'] ['877692701'] ['napster'] ['hu']
# ['tandyaaron'] ['tandyaaron'] ['ecoin'] ['tech']
# ['ingramthomas'] ['ingramthomas'] ['youhoo'] ['xyz']
# ['aaron8129'] ['aaron8129'] ['belgaximus'] ['apple']
# ['vanderpoeljoe'] ['vanderpoeljoe'] ['mail'] ['io']
# ['fredmills'] ['fredmills'] ['imail'] ['net']
# ['haljagtap'] ['haljagtap'] ['hotmoille'] ['org']
# ['larry'] ['hancock'] ['mail'] ['xyz']
# ['soloman_eastman'] ['soloman_eastman'] ['email'] ['com']
# ['montelewis'] ['montelewis'] ['gaagle'] ['org']
# ['631338425'] ['631338425'] ['mail'] ['gov']
# ['peter'] ['mccord'] ['gaagle'] ['com']
# ['hylan'] ['hylan'] ['mail'] ['apple']
# ['roger'] ['roger'] ['proton'] ['io']
# ['paiser'] ['paiser'] ['youhoo'] ['gov']
# ['schickowski-steve'] ['schickowski-steve'] ['belgaximus'] ['gov']
# ['ty'] ['ty'] ['imail'] ['gov']
# ['roberts'] ['roberts'] ['youhoo'] ['gov']
# ['958642438'] ['958642438'] ['email'] ['net']
# ['boyd3853'] ['boyd3853'] ['belgaximus'] ['net']
# ['soloman_nathan'] ['soloman_nathan'] ['youhoo'] ['gov']
# ['92101346'] ['92101346'] ['proton'] ['tech']
# ['chambers'] ['mark'] ['napster'] ['com']
# ['nuttleedward'] ['nuttleedward'] ['gaagle'] ['apple']
# ['adamrice'] ['adamrice'] ['ecoin'] ['net']
# ['fred937'] ['fred937'] ['odul'] ['com']
# ['ben'] ['ben'] ['belgaximus'] ['hu']
# ['lepagemark'] ['lepagemark'] ['mail'] ['xyz']
# ['dan'] ['dan'] ['gaagle'] ['gov']
# ['walterturco'] ['walterturco'] ['imail'] ['tech']
# ['ebner_fred'] ['ebner_fred'] ['mail'] ['net']
# ['danwagner'] ['danwagner'] ['mail'] ['gov']
# ['jones206'] ['jones206'] ['mail'] ['com']
# ['steve'] ['root'] ['mail'] ['net']
# ['roger'] ['fletcher'] ['belgaximus'] ['xyz']
# ['casal'] ['david'] ['mail'] ['tech']
# ['adamziegler'] ['adamziegler'] ['youhoo'] ['org']
# ['275056493'] ['275056493'] ['youhoo'] ['xyz']
# ['peterlewis'] ['peterlewis'] ['belgaximus'] ['gov']
# ['jack'] ['jack'] ['imail'] ['net']
# ['george3788'] ['george3788'] ['gaagle'] ['com']
# ['seversonpaul'] ['seversonpaul'] ['mail'] ['xyz']
# ['zeller'] ['roger'] ['youhoo'] ['me']
# ['ottoschmitt'] ['ottoschmitt'] ['odul'] ['org']
# ['fietzer_cast'] ['fietzer_cast'] ['mail'] ['tech']
# ['tiernan'] ['jack'] ['ecoin'] ['apple']
# ['schutz_knutson'] ['schutz_knutson'] ['gaagle'] ['gov']
# ['matthew2395'] ['matthew2395'] ['mail'] ['net']
# ['hal'] ['severson'] ['youhoo'] ['hu']
# ['reyes-paul'] ['reyes-paul'] ['imail'] ['gov']
# ['mccord_ferry'] ['mccord_ferry'] ['odul'] ['gov']
# ['uddin2208'] ['uddin2208'] ['youhoo'] ['me']
# ['moody1342'] ['moody1342'] ['mail'] ['com']
# ['roger6727'] ['roger6727'] ['imail'] ['me']
# ['schlicht670'] ['schlicht670'] ['hotmoille'] ['net']
# ['steve'] ['steve'] ['odul'] ['xyz']
# ['sawyer'] ['sawyer'] ['napster'] ['apple']
# ['soulis2863'] ['soulis2863'] ['belgaximus'] ['hu']
# ['yates'] ['steve'] ['mail'] ['io']
# ['sonderling4257'] ['sonderling4257'] ['email'] ['org']
# ['upson_paul'] ['upson_paul'] ['gaagle'] ['org']
# ['timtrebil'] ['timtrebil'] ['belgaximus'] ['tech']
# ['104036307'] ['104036307'] ['ecoin'] ['me']
# ['frankupson'] ['frankupson'] ['imail'] ['apple']
# ['fietzeralex'] ['fietzeralex'] ['youhoo'] ['hu']
# ['solomanjohn'] ['solomanjohn'] ['youhoo'] ['apple']
# ['peter6564'] ['peter6564'] ['email'] ['hu']
# ['johnsen2199'] ['johnsen2199'] ['gaagle'] ['tech']
# ['uflan-frank'] ['uflan-frank'] ['belgaximus'] ['apple']
# ['lepage_edward'] ['lepage_edward'] ['ecoin'] ['net']
# ['dugelman8872'] ['dugelman8872'] ['odul'] ['me']
# ['carlvanderpoel'] ['carlvanderpoel'] ['mail'] ['apple']
# ['vanderpoel_hydinger'] ['vanderpoel_hydinger'] ['odul'] ['xyz']
# ['ripka2789'] ['ripka2789'] ['email'] ['io']
# ['chambers'] ['aaron'] ['mail'] ['com']
# ['nathan2454'] ['nathan2454'] ['mail'] ['xyz']
# ['larry1596'] ['larry1596'] ['imail'] ['tech']
# ['moorety'] ['moorety'] ['napster'] ['io']
# ['roger'] ['fietzer'] ['belgaximus'] ['apple']
# ['soulispeter'] ['soulispeter'] ['imail'] ['io']
# ['victorschmitt'] ['victorschmitt'] ['mail'] ['org']
# ['ty3503'] ['ty3503'] ['imail'] ['apple']
# ['lepage_ostrander'] ['lepage_ostrander'] ['hotmoille'] ['io']
# ['vanderpoel_dan'] ['vanderpoel_dan'] ['gaagle'] ['net']
# ['darnellty'] ['darnellty'] ['gaagle'] ['org']
# ['kalleg_david'] ['kalleg_david'] ['belgaximus'] ['gov']
# ['steve'] ['steve'] ['odul'] ['apple']
# ['lulloff'] ['matthew'] ['proton'] ['hu']
# ['chamberspaul'] ['chamberspaul'] ['odul'] ['com']
# ['anderson845'] ['anderson845'] ['mail'] ['com']
# ['quizoz_upson'] ['quizoz_upson'] ['mail'] ['tech']
# ['bencasal'] ['bencasal'] ['odul'] ['io']
# ['vader_john'] ['vader_john'] ['napster'] ['org']
# ['mark'] ['lepage'] ['mail'] ['apple']
# ['lepage6698'] ['lepage6698'] ['email'] ['hu']
# ['zeller_ziegler'] ['zeller_ziegler'] ['ecoin'] ['tech']
# ['walterschwager'] ['walterschwager'] ['email'] ['io']
# ['christensenty'] ['christensenty'] ['napster'] ['xyz']
# ['severson_woo'] ['severson_woo'] ['proton'] ['org']
# ['vailjoe'] ['vailjoe'] ['imail'] ['io']
# ['tiernan-frank'] ['tiernan-frank'] ['napster'] ['org']
# ['dewalt_adam'] ['dewalt_adam'] ['proton'] ['net']
# ['rogertrebil'] ['rogertrebil'] ['mail'] ['gov']
# ['ziegler8928'] ['ziegler8928'] ['imail'] ['net']
# ['duffman-ben'] ['duffman-ben'] ['hotmoille'] ['hu']
# ['wakefield_edward'] ['wakefield_edward'] ['youhoo'] ['tech']
# ['dugelman_van'] ['zandt'] ['gaagle'] ['net']
# ['nugent1331'] ['nugent1331'] ['proton'] ['xyz']
# ['frick-otto'] ['frick-otto'] ['hotmoille'] ['hu']
# ['celedon_severson'] ['celedon_severson'] ['odul'] ['me']
# ['ty'] ['tiernan'] ['odul'] ['gov']
# ['schmitt'] ['schmitt'] ['imail'] ['org']
# ['aaronwagle'] ['aaronwagle'] ['email'] ['tech']
# ['woo'] ['woo'] ['hotmoille'] ['io']
# ['tim9542'] ['tim9542'] ['hotmoille'] ['tech']
# ['john5694'] ['john5694'] ['email'] ['me']
# ['sagar_nathan'] ['sagar_nathan'] ['belgaximus'] ['xyz']
# ['larry'] ['dinkins'] ['proton'] ['com']
# ['severson'] ['steve'] ['imail'] ['hu']
# ['fredturco'] ['fredturco'] ['odul'] ['net']
# ['victoringram'] ['victoringram'] ['mail'] ['apple']
# ['edward'] ['edward'] ['youhoo'] ['com']
# ['tisler-matthew'] ['tisler-matthew'] ['imail'] ['me']
# ['reyes'] ['roger'] ['ecoin'] ['tech']
# ['reamer_tim'] ['reamer_tim'] ['hotmoille'] ['org']
# ['schlicht-carl'] ['schlicht-carl'] ['ecoin'] ['net']
# ['steve3131'] ['steve3131'] ['email'] ['tech']
# ['wagner9136'] ['wagner9136'] ['gaagle'] ['apple']
# ['davis_bowers'] ['davis_bowers'] ['belgaximus'] ['me']
# ['edward9079'] ['edward9079'] ['napster'] ['net']
# ['283141330'] ['283141330'] ['gaagle'] ['hu']
# ['tyduffman'] ['tyduffman'] ['hotmoille'] ['hu']
# ['walterhydinger'] ['walterhydinger'] ['ecoin'] ['io']
# ['ben9635'] ['ben9635'] ['odul'] ['apple']
# ['vanderpoel'] ['mark'] ['odul'] ['tech']
# ['delorenzo'] ['jack'] ['napster'] ['xyz']
# ['chapman-roger'] ['chapman-roger'] ['mail'] ['com']
# ['nathan'] ['woo'] ['proton'] ['org']
# ['victorvader'] ['victorvader'] ['belgaximus'] ['tech']
# ['bateman1522'] ['bateman1522'] ['mail'] ['net']
# ['ben'] ['irwin'] ['email'] ['net']
# ['fredhaworth'] ['fredhaworth'] ['mail'] ['io']
# ['eastman_larry'] ['eastman_larry'] ['napster'] ['apple']
# ['sweeney_alex'] ['sweeney_alex'] ['hotmoille'] ['hu']
# ['hydinger_otto'] ['hydinger_otto'] ['email'] ['apple']
# ['peter2600'] ['peter2600'] ['belgaximus'] ['apple']
# ['eastman_adam'] ['eastman_adam'] ['imail'] ['xyz']
# ['thomas'] ['thomas'] ['gaagle'] ['com']
# ['hal'] ['hal'] ['napster'] ['gov']
# ['paulresnick'] ['paulresnick'] ['gaagle'] ['me']
# ['682804922'] ['682804922'] ['ecoin'] ['hu']
# ['ziegler-alex'] ['ziegler-alex'] ['odul'] ['me']
# ['maki-frank'] ['maki-frank'] ['mail'] ['hu']
# ['myerspeter'] ['myerspeter'] ['youhoo'] ['me']
# ['fred67'] ['fred67'] ['youhoo'] ['net']
# ['edwardhoffman'] ['edwardhoffman'] ['napster'] ['apple']
# ['nuttle-monte'] ['nuttle-monte'] ['email'] ['gov']
# ['thompson_orwig'] ['thompson_orwig'] ['napster'] ['com']
# ['ike'] ['stahl'] ['hotmoille'] ['apple']
# ['markhoffman'] ['markhoffman'] ['imail'] ['org']
# ['669214282'] ['669214282'] ['imail'] ['com']
# ['hank'] ['hank'] ['proton'] ['com']
# ['pettigrew_bauer'] ['pettigrew_bauer'] ['youhoo'] ['hu']
# ['nuttle_upson'] ['nuttle_upson'] ['ecoin'] ['com']
# ['vader_ty'] ['vader_ty'] ['mail'] ['org']
# ['danziegler'] ['danziegler'] ['hotmoille'] ['tech']
# ['nugent_uddin'] ['nugent_uddin'] ['belgaximus'] ['com']
# ['alex'] ['mccormack'] ['hotmoille'] ['com']
# ['larry'] ['larry'] ['youhoo'] ['hu']
# ['aaron735'] ['aaron735'] ['mail'] ['me']
# ['deitzdan'] ['deitzdan'] ['imail'] ['apple']
# ['alexhesch'] ['alexhesch'] ['odul'] ['gov']
# ['dinkinscarl'] ['dinkinscarl'] ['napster'] ['io']
# ['aaronschwager'] ['aaronschwager'] ['mail'] ['gov']
# ['edward'] ['edward'] ['imail'] ['tech']
# ['ory-ty'] ['ory-ty'] ['ecoin'] ['com']
# ['dugelman_roger'] ['dugelman_roger'] ['mail'] ['com']
# ['43720854'] ['43720854'] ['ecoin'] ['net']
# ['larryulrich'] ['larryulrich'] ['mail'] ['apple']
# ['tiernanotto'] ['tiernanotto'] ['hotmoille'] ['xyz']
# ['christensen-ben'] ['christensen-ben'] ['odul'] ['io']
# ['220923632'] ['220923632'] ['proton'] ['xyz']
# ['stahl_larry'] ['stahl_larry'] ['mail'] ['com']
# ['vader_larry'] ['vader_larry'] ['belgaximus'] ['io']
# ['lepage'] ['lepage'] ['odul'] ['io']
# ['woofrank'] ['woofrank'] ['youhoo'] ['hu']
# ['413352781'] ['413352781'] ['imail'] ['xyz']
# ['walterschutz'] ['walterschutz'] ['imail'] ['apple']
# ['ike'] ['ike'] ['proton'] ['xyz']
# ['tislerjohn'] ['tislerjohn'] ['napster'] ['org']
# ['ebner_chapman'] ['ebner_chapman'] ['email'] ['me']
# ['jurgenson'] ['mark'] ['odul'] ['net']
# ['40053022'] ['40053022'] ['belgaximus'] ['apple']
# ['nathanhylan'] ['nathanhylan'] ['gaagle'] ['io']
# ['carl1266'] ['carl1266'] ['proton'] ['me']
# ['ortiz'] ['ortiz'] ['gaagle'] ['hu']
# ['johnsen1400'] ['johnsen1400'] ['mail'] ['tech']
# ['irwin_otto'] ['irwin_otto'] ['proton'] ['hu']
# ['ikechapman'] ['ikechapman'] ['youhoo'] ['io']
# ['walter'] ['walter'] ['mail'] ['net']
# ['nathan'] ['zeller'] ['odul'] ['me']
# ['joeuddin'] ['joeuddin'] ['ecoin'] ['me']
# ['lawicki'] ['lawicki'] ['gaagle'] ['org']
# ['casal9156'] ['casal9156'] ['belgaximus'] ['com']
# ['resnick2754'] ['resnick2754'] ['youhoo'] ['xyz']
# ['ashwoon_hank'] ['ashwoon_hank'] ['odul'] ['io']
# ['jack3740'] ['jack3740'] ['proton'] ['xyz']
# ['hal'] ['casal'] ['hotmoille'] ['com']
# ['jurgenson_dan'] ['jurgenson_dan'] ['napster'] ['hu']
# ['393543398'] ['393543398'] ['proton'] ['hu']
# ['steve5769'] ['steve5769'] ['proton'] ['apple']
# ['duffman_vanderpoel'] ['duffman_vanderpoel'] ['odul'] ['com']
# ['ramachandran1712'] ['ramachandran1712'] ['mail'] ['io']
# ['dugelman-adam'] ['dugelman-adam'] ['imail'] ['tech']
# ['735354722'] ['735354722'] ['hotmoille'] ['gov']
# ['monteschiebel'] ['monteschiebel'] ['odul'] ['tech']
# ['larry'] ['miller'] ['youhoo'] ['tech']
# ['lepage-peter'] ['lepage-peter'] ['hotmoille'] ['apple']
# ['duffmanedward'] ['duffmanedward'] ['email'] ['me']
# ['tim'] ['roberts'] ['ecoin'] ['xyz']
# ['schickowski'] ['matthew'] ['napster'] ['com']
# ['steve'] ['steve'] ['youhoo'] ['gov']
# ['duffman_weiss'] ['duffman_weiss'] ['proton'] ['gov']
# ['rogersty'] ['rogersty'] ['hotmoille'] ['hu']
# ['paulchapman'] ['paulchapman'] ['imail'] ['xyz']
# ['adam'] ['delorenzo'] ['mail'] ['hu']
# ['bongardben'] ['bongardben'] ['napster'] ['tech']
# ['knutson-walter'] ['knutson-walter'] ['belgaximus'] ['hu']
# ['ory_joe'] ['ory_joe'] ['belgaximus'] ['com']
# ['chambers-walter'] ['chambers-walter'] ['ecoin'] ['apple']
# ['cannon_ferro'] ['cannon_ferro'] ['ecoin'] ['apple']
# ['rice_soulis'] ['rice_soulis'] ['ecoin'] ['apple']
# ['579097737'] ['579097737'] ['belgaximus'] ['hu']
# ['chambers_roberts'] ['chambers_roberts'] ['mail'] ['xyz']
# ['pettigrewfred'] ['pettigrewfred'] ['odul'] ['net']
# ['victorillingsworth'] ['victorillingsworth'] ['ecoin'] ['org']
# ['wagnercarl'] ['wagnercarl'] ['proton'] ['net']
# ['illingsworth'] ['roger'] ['mail'] ['gov']
# ['fred'] ['fred'] ['imail'] ['io']
# ['tapiajohn'] ['tapiajohn'] ['mail'] ['me']
# ['christensen'] ['christensen'] ['belgaximus'] ['hu']
# ['vail'] ['vail'] ['gaagle'] ['com']
# ['nathan'] ['nathan'] ['imail'] ['hu']
# ['tandy'] ['tandy'] ['mail'] ['apple']
# ['victorjones'] ['victorjones'] ['napster'] ['tech']
# ['resnick'] ['david'] ['odul'] ['apple']
# ['roger'] ['roger'] ['proton'] ['net']
# ['resnick'] ['thomas'] ['imail'] ['apple']
# ['soukup_tim'] ['soukup_tim'] ['odul'] ['apple']
# ['hank'] ['hank'] ['hotmoille'] ['org']
# ['victorfletcher'] ['victorfletcher'] ['imail'] ['tech']
# ['schwager_pak'] ['schwager_pak'] ['odul'] ['tech']
# ['weinsteintim'] ['weinsteintim'] ['proton'] ['org']
# ['fred2414'] ['fred2414'] ['hotmoille'] ['apple']
# ['hesch1648'] ['hesch1648'] ['imail'] ['tech']
# ['weiss_walter'] ['weiss_walter'] ['gaagle'] ['com']
# ['ottoreamer'] ['ottoreamer'] ['email'] ['apple']
# ['carl'] ['carl'] ['mail'] ['gov']
# ['fietzer_kaskel'] ['fietzer_kaskel'] ['mail'] ['me']
# ['timbauer'] ['timbauer'] ['ecoin'] ['apple']
# ['ike'] ['reyes'] ['belgaximus'] ['gov']
# ['matthew'] ['matthew'] ['hotmoille'] ['com']
# ['reardon'] ['reardon'] ['gaagle'] ['hu']
# ['mccormack7946'] ['mccormack7946'] ['youhoo'] ['me']
# ['matthew6993'] ['matthew6993'] ['hotmoille'] ['org']
# ['nelson-matthew'] ['nelson-matthew'] ['imail'] ['hu']
# ['peter'] ['mccormack'] ['mail'] ['me']
# ['delorenzo-larry'] ['delorenzo-larry'] ['mail'] ['org']
# ['mcginnis'] ['walter'] ['email'] ['io']
# ['edward3639'] ['edward3639'] ['mail'] ['apple']
# ['mark2192'] ['mark2192'] ['youhoo'] ['xyz']
# ['dan'] ['dan'] ['hotmoille'] ['tech']
# ['nuttlety'] ['nuttlety'] ['gaagle'] ['gov']
# ['victortisler'] ['victortisler'] ['youhoo'] ['com']
# ['tisler_cannon'] ['tisler_cannon'] ['youhoo'] ['apple']
# ['otto'] ['jurgenson'] ['mail'] ['me']
# ['jacksolberg'] ['jacksolberg'] ['gaagle'] ['me']
# ['nathan'] ['vanderpoel'] ['belgaximus'] ['tech']
# ['fletcher_duffman'] ['fletcher_duffman'] ['ecoin'] ['com']
# ['dugan_ortiz'] ['dugan_ortiz'] ['hotmoille'] ['io']
# ['anderson_dewalt'] ['anderson_dewalt'] ['odul'] ['me']
# ['adampak'] ['adampak'] ['hotmoille'] ['net']
# ['peter'] ['norquist'] ['napster'] ['net']
# ['yang'] ['yang'] ['imail'] ['net']
# ['alex7627'] ['alex7627'] ['youhoo'] ['gov']
# ['ben'] ['ben'] ['napster'] ['xyz']
# ['ferry-walter'] ['ferry-walter'] ['imail'] ['tech']
# ['weiss9401'] ['weiss9401'] ['youhoo'] ['xyz']
# ['haworth_steve'] ['haworth_steve'] ['youhoo'] ['gov']
# ['ulrich9331'] ['ulrich9331'] ['email'] ['org']
# ['baxster'] ['mark'] ['email'] ['net']
# ['dugelman2727'] ['dugelman2727'] ['odul'] ['xyz']
# ['yates_hal'] ['yates_hal'] ['odul'] ['net']
# ['otto1543'] ['otto1543'] ['youhoo'] ['gov']
# ['bateman_joe'] ['bateman_joe'] ['odul'] ['apple']
# ['larryhoffman'] ['larryhoffman'] ['belgaximus'] ['tech']
# ['celedonmatthew'] ['celedonmatthew'] ['napster'] ['net']
# ['victorrogers'] ['victorrogers'] ['gaagle'] ['net']
# ['ashwoon_ben'] ['ashwoon_ben'] ['napster'] ['net']
# ['van'] ['zandt_deitz'] ['belgaximus'] ['xyz']
# ['711978855'] ['711978855'] ['email'] ['org']
# ['delorenzo'] ['delorenzo'] ['belgaximus'] ['xyz']
# ['zeller_john'] ['zeller_john'] ['napster'] ['hu']
# ['olson'] ['olson'] ['odul'] ['gov']
# ['aaronmiller'] ['aaronmiller'] ['mail'] ['gov']
# ['bensoukup'] ['bensoukup'] ['proton'] ['me']
# ['sweeneytim'] ['sweeneytim'] ['ecoin'] ['gov']
# ['joe'] ['joe'] ['proton'] ['hu']
# ['doran'] ['doran'] ['proton'] ['tech']
# ['otto'] ['otto'] ['hotmoille'] ['gov']
# ['frankchristensen'] ['frankchristensen'] ['odul'] ['me']
# ['524504262'] ['524504262'] ['odul'] ['me']
# ['tim3793'] ['tim3793'] ['gaagle'] ['io']
# ['otto815'] ['otto815'] ['email'] ['me']
# ['sweeney'] ['carl'] ['gaagle'] ['net']
# ['knutson_trebil'] ['knutson_trebil'] ['email'] ['me']
# ['hank'] ['nuttle'] ['mail'] ['me']
# ['kalleg-tim'] ['kalleg-tim'] ['gaagle'] ['gov']
# ['ikecast'] ['ikecast'] ['mail'] ['apple']
# ['jack'] ['weinstein'] ['email'] ['apple']
# ['myers_ramachandran'] ['myers_ramachandran'] ['mail'] ['io']
# ['victor'] ['victor'] ['proton'] ['hu']
# ['hancockcarl'] ['hancockcarl'] ['napster'] ['com']
# ['schlicht'] ['dan'] ['email'] ['tech']
# ['tisler3297'] ['tisler3297'] ['belgaximus'] ['tech']
# ['steve6502'] ['steve6502'] ['email'] ['net']
# ['frank5506'] ['frank5506'] ['imail'] ['apple']
# ['schwager_joe'] ['schwager_joe'] ['napster'] ['org']
# ['dugelman-jack'] ['dugelman-jack'] ['hotmoille'] ['net']
# ['weiss5261'] ['weiss5261'] ['email'] ['tech']
# ['dantrusela'] ['dantrusela'] ['odul'] ['org']
# ['leisinger_walter'] ['leisinger_walter'] ['hotmoille'] ['org']
# ['roger4965'] ['roger4965'] ['odul'] ['net']
# ['mccormack_ike'] ['mccormack_ike'] ['youhoo'] ['hu']
# ['jackortiz'] ['jackortiz'] ['imail'] ['com']
# ['walter'] ['walter'] ['mail'] ['xyz']
# ['ferro_peter'] ['ferro_peter'] ['ecoin'] ['apple']
# ['ikemyers'] ['ikemyers'] ['mail'] ['io']
# ['schmitt'] ['schmitt'] ['imail'] ['apple']
# ['yates'] ['thomas'] ['belgaximus'] ['org']
# ['schutzike'] ['schutzike'] ['ecoin'] ['tech']
# ['upson'] ['upson'] ['hotmoille'] ['hu']
# ['schlicht'] ['monte'] ['hotmoille'] ['com']
# ['upson'] ['upson'] ['youhoo'] ['com']
# ['525072400'] ['525072400'] ['proton'] ['tech']
# ['jurgenson_trusela'] ['jurgenson_trusela'] ['odul'] ['me']
# ['georgeturco'] ['georgeturco'] ['imail'] ['hu']
# ['hank5891'] ['hank5891'] ['mail'] ['apple']
# ['weiss-hank'] ['weiss-hank'] ['proton'] ['io']
# ['jenson9642'] ['jenson9642'] ['proton'] ['io']
# ['thomascaswell'] ['thomascaswell'] ['napster'] ['io']
# ['thomaskalleg'] ['thomaskalleg'] ['ecoin'] ['xyz']
# ['bowers'] ['steve'] ['napster'] ['io']
# ['victorresnick'] ['victorresnick'] ['proton'] ['org']
# ['walter8082'] ['walter8082'] ['mail'] ['xyz']
# ['sellon_roger'] ['sellon_roger'] ['proton'] ['hu']
# ['peter'] ['peter'] ['hotmoille'] ['com']
# ['victor2700'] ['victor2700'] ['napster'] ['xyz']
# ['deitz-edward'] ['deitz-edward'] ['belgaximus'] ['net']
# ['38460014'] ['38460014'] ['mail'] ['io']
# ['hesch_mills'] ['hesch_mills'] ['ecoin'] ['org']
# ['frankwoo'] ['frankwoo'] ['napster'] ['gov']
# ['van'] ['zandt_soloman'] ['belgaximus'] ['me']
# ['ulrich_carl'] ['ulrich_carl'] ['belgaximus'] ['hu']
# ['adam'] ['adam'] ['mail'] ['com']
# ['hoffman'] ['hoffman'] ['hotmoille'] ['hu']
# ['zellersteve'] ['zellersteve'] ['napster'] ['io']
# ['jonesthomas'] ['jonesthomas'] ['email'] ['tech']
# ['jagtap_victor'] ['jagtap_victor'] ['email'] ['gov']
# ['reyes3325'] ['reyes3325'] ['youhoo'] ['gov']
# ['schickowski7190'] ['schickowski7190'] ['odul'] ['tech']
# ['irwin'] ['irwin'] ['odul'] ['hu']
# ['moore_edward'] ['moore_edward'] ['youhoo'] ['org']
# ['tisler_fred'] ['tisler_fred'] ['imail'] ['apple']
# ['thomas'] ['thomas'] ['email'] ['xyz']
# ['alexcataldi'] ['alexcataldi'] ['napster'] ['org']
# ['tim'] ['tim'] ['mail'] ['apple']
# ['hankulrich'] ['hankulrich'] ['belgaximus'] ['hu']
# ['otto'] ['reamer'] ['mail'] ['net']
# ['rogerchambers'] ['rogerchambers'] ['mail'] ['io']
# ['alexdavidson'] ['alexdavidson'] ['mail'] ['net']
# ['peter'] ['moody'] ['proton'] ['io']
# ['ben'] ['weinstein'] ['odul'] ['apple']
# ['davidson_jack'] ['davidson_jack'] ['youhoo'] ['xyz']
# ['jacksellon'] ['jacksellon'] ['napster'] ['io']
# ['cataldiedward'] ['cataldiedward'] ['hotmoille'] ['io']
# ['sellon'] ['jack'] ['ecoin'] ['net']
# ['748522766'] ['748522766'] ['gaagle'] ['xyz']
# ['victorsweeney'] ['victorsweeney'] ['odul'] ['tech']
# ['nelson-matthew'] ['nelson-matthew'] ['belgaximus'] ['me']
# ['johnmoody'] ['johnmoody'] ['imail'] ['xyz']
# ['peter'] ['sandstrom'] ['napster'] ['xyz']
# ['montelulloff'] ['montelulloff'] ['email'] ['io']
# ['andersonhal'] ['andersonhal'] ['odul'] ['apple']
# ['napier_hank'] ['napier_hank'] ['belgaximus'] ['hu']
# ['moodygeorge'] ['moodygeorge'] ['proton'] ['net']
# ['peter4809'] ['peter4809'] ['email'] ['net']
# ['marknapier'] ['marknapier'] ['proton'] ['io']
# ['darnell_roger'] ['darnell_roger'] ['hotmoille'] ['net']
# ['george'] ['george'] ['belgaximus'] ['gov']
# ['tim'] ['weinstein'] ['odul'] ['io']
# ['pak_roger'] ['pak_roger'] ['proton'] ['com']
# ['georgecasal'] ['georgecasal'] ['hotmoille'] ['tech']
# ['trusela-jack'] ['trusela-jack'] ['email'] ['net']
# ['thomasvan'] ['zandt'] ['email'] ['tech']
# ['fred'] ['martin'] ['youhoo'] ['apple']
# ['alex'] ['alex'] ['proton'] ['apple']
# ['dan'] ['ventotla'] ['proton'] ['gov']
# ['dewalt_joe'] ['dewalt_joe'] ['email'] ['com']
# ['celedon_hesch'] ['celedon_hesch'] ['youhoo'] ['net']
# ['ty8684'] ['ty8684'] ['odul'] ['apple']
# ['nuttle_yang'] ['nuttle_yang'] ['youhoo'] ['hu']
# ['hal'] ['rice'] ['napster'] ['com']
# ['821663824'] ['821663824'] ['odul'] ['apple']
# ['mccord'] ['fred'] ['proton'] ['apple']
# ['orwig'] ['orwig'] ['ecoin'] ['xyz']
# ['857071926'] ['857071926'] ['mail'] ['net']
# ['turcolarry'] ['turcolarry'] ['gaagle'] ['hu']
# ['mcginnis_aaron'] ['mcginnis_aaron'] ['email'] ['com']
# ['johnpettigrew'] ['johnpettigrew'] ['proton'] ['hu']
# ['root-edward'] ['root-edward'] ['gaagle'] ['hu']
# ['hal'] ['yocum'] ['email'] ['apple']
# ['monteschuster'] ['monteschuster'] ['belgaximus'] ['gov']
# ['fietzer_mark'] ['fietzer_mark'] ['gaagle'] ['tech']
# ['271794997'] ['271794997'] ['imail'] ['gov']
# ['hancock'] ['hancock'] ['imail'] ['tech']
# ['wagle_doran'] ['wagle_doran'] ['hotmoille'] ['hu']
# ['558791202'] ['558791202'] ['napster'] ['io']
# ['woo-aaron'] ['woo-aaron'] ['ecoin'] ['com']
# ['quinn1097'] ['quinn1097'] ['imail'] ['org']
# ['sawyer'] ['sawyer'] ['proton'] ['hu']
# ['trebil5339'] ['trebil5339'] ['mail'] ['hu']
# ['norquist-mark'] ['norquist-mark'] ['email'] ['apple']
# ['ory7664'] ['ory7664'] ['belgaximus'] ['net']
# ['olsonjohn'] ['olsonjohn'] ['belgaximus'] ['tech']
# ['orwigfrank'] ['orwigfrank'] ['mail'] ['xyz']
# ['alexfrick'] ['alexfrick'] ['mail'] ['apple']
# ['knutson_matthew'] ['knutson_matthew'] ['odul'] ['tech']
# ['aikin7996'] ['aikin7996'] ['belgaximus'] ['tech']
# ['dewalt674'] ['dewalt674'] ['napster'] ['io']
# ['ventotla_haworth'] ['ventotla_haworth'] ['imail'] ['tech']
# ['ike'] ['ike'] ['ecoin'] ['apple']
# ['yates'] ['hal'] ['odul'] ['io']
# ['dan9881'] ['dan9881'] ['mail'] ['hu']
# ['resnick_john'] ['resnick_john'] ['napster'] ['xyz']
# ['roger'] ['deitz'] ['gaagle'] ['org']
# ['pak'] ['matthew'] ['gaagle'] ['gov']
# ['edward'] ['edward'] ['odul'] ['io']
# ['markmoore'] ['markmoore'] ['email'] ['tech']
# ['schickowski'] ['roger'] ['hotmoille'] ['net']
# ['larrysandstrom'] ['larrysandstrom'] ['odul'] ['org']
# ['nathan'] ['nathan'] ['napster'] ['gov']
# ['fredolson'] ['fredolson'] ['mail'] ['apple']
# ['nathan'] ['rogers'] ['odul'] ['gov']
# ['nelson-peter'] ['nelson-peter'] ['proton'] ['com']
# ['adameastman'] ['adameastman'] ['email'] ['me']
# ['solberg'] ['solberg'] ['mail'] ['me']
# ['carl'] ['mcginnis'] ['email'] ['apple']
# ['benwoo'] ['benwoo'] ['mail'] ['tech']
# ['trussel_moore'] ['trussel_moore'] ['mail'] ['hu']
# ['vader_thompson'] ['vader_thompson'] ['mail'] ['gov']
# ['davidashwoon'] ['davidashwoon'] ['belgaximus'] ['tech']
# ['sawyer'] ['steve'] ['imail'] ['me']
# ['rogerbateman'] ['rogerbateman'] ['mail'] ['tech']
# ['dinkins_weinstein'] ['dinkins_weinstein'] ['mail'] ['org']
# ['resnick-edward'] ['resnick-edward'] ['mail'] ['tech']
# ['rogercannon'] ['rogercannon'] ['youhoo'] ['io']
# ['ebner_walter'] ['ebner_walter'] ['mail'] ['xyz']
# ['aaron'] ['aaron'] ['hotmoille'] ['gov']
# ['halduffman'] ['halduffman'] ['mail'] ['hu']
# ['celedon_ostrander'] ['celedon_ostrander'] ['email'] ['gov']
# ['rogerhoffman'] ['rogerhoffman'] ['email'] ['apple']
# ['victor2949'] ['victor2949'] ['hotmoille'] ['org']
# ['matthew'] ['schwager'] ['imail'] ['com']
# ['dan9862'] ['dan9862'] ['ecoin'] ['com']
# ['lawicki-carl'] ['lawicki-carl'] ['gaagle'] ['net']
# ['tislertim'] ['tislertim'] ['mail'] ['com']
# ['victor3334'] ['victor3334'] ['belgaximus'] ['apple']
# ['alex'] ['alex'] ['mail'] ['tech']
# ['peter'] ['tisler'] ['mail'] ['net']
# ['trebil'] ['trebil'] ['ecoin'] ['gov']
# ['786331264'] ['786331264'] ['napster'] ['me']
# ['tyjohnson'] ['tyjohnson'] ['gaagle'] ['xyz']
# ['valente5120'] ['valente5120'] ['imail'] ['net']
# ['joesawyer'] ['joesawyer'] ['mail'] ['io']
# ['zeller-nathan'] ['zeller-nathan'] ['odul'] ['hu']
# ['187630443'] ['187630443'] ['imail'] ['net']
# ['926609635'] ['926609635'] ['odul'] ['com']
# ['john'] ['john'] ['hotmoille'] ['tech']
# ['myers6475'] ['myers6475'] ['email'] ['org']
# ['ortiz8400'] ['ortiz8400'] ['napster'] ['apple']
# ['sandstromgeorge'] ['sandstromgeorge'] ['hotmoille'] ['net']
# ['hylan_tandy'] ['hylan_tandy'] ['odul'] ['tech']
# ['adammccord'] ['adammccord'] ['napster'] ['org']
# ['jackjenson'] ['jackjenson'] ['mail'] ['org']
# ['matthew3862'] ['matthew3862'] ['odul'] ['apple']
# ['david8084'] ['david8084'] ['proton'] ['tech']
# ['johnmills'] ['johnmills'] ['ecoin'] ['tech']
# ['haljones'] ['haljones'] ['gaagle'] ['tech']
# ['lawless'] ['ty'] ['gaagle'] ['net']
# ['walter'] ['walter'] ['ecoin'] ['xyz']
# ['trusela-peter'] ['trusela-peter'] ['mail'] ['io']
# ['trebil'] ['alex'] ['email'] ['net']
# ...
# ['leisingeraaron'] ['leisingeraaron'] ['ecoin'] ['com']
# ['aaron'] ['aaron'] ['youhoo'] ['tech']
# ['linde'] ['linde'] ['imail'] ['net']
# ['yang-walter'] ['yang-walter'] ['imail'] ['org']
# ['mccormack'] ['mccormack'] ['napster'] ['org']
# ['cataldi_vogal'] ['cataldi_vogal'] ['email'] ['com']
# ['walter'] ['schuster'] ['odul'] ['apple']
# ['629679708'] ['629679708'] ['youhoo'] ['me']
# ['victor'] ['nuttle'] ['napster'] ['me']
# ['root'] ['dan'] ['odul'] ['org']
# ['ashwoon'] ['ashwoon'] ['napster'] ['xyz']
# ['kassing_joe'] ['kassing_joe'] ['odul'] ['com']
# ['schuster_root'] ['schuster_root'] ['napster'] ['net']
# ['681617279'] ['681617279'] ['gaagle'] ['me']
# ['orwig'] ['orwig'] ['imail'] ['me']
# ['rogerhaworth'] ['rogerhaworth'] ['mail'] ['me']
# ['turco_eastman'] ['turco_eastman'] ['gaagle'] ['apple']
# ['ziegler8032'] ['ziegler8032'] ['gaagle'] ['tech']
# ['soukup'] ['soukup'] ['mail'] ['apple']
# ['stevemiller'] ['stevemiller'] ['proton'] ['apple']
# ['97234842'] ['97234842'] ['imail'] ['net']
# ['reardon9212'] ['reardon9212'] ['proton'] ['gov']
# ['sagar'] ['sagar'] ['mail'] ['hu']
# ['paul'] ['myers'] ['email'] ['gov']
# ['jack7787'] ['jack7787'] ['belgaximus'] ['net']
# ['jagtap_larry'] ['jagtap_larry'] ['belgaximus'] ['org']
# ['fred'] ['aikin'] ['mail'] ['org']
# ['otto'] ['leisinger'] ['proton'] ['io']
# ['yates_thomas'] ['yates_thomas'] ['ecoin'] ['xyz']
# ['knutson_thomas'] ['knutson_thomas'] ['email'] ['com']
# ['davis'] ['monte'] ['hotmoille'] ['net']
# ['vader_alex'] ['vader_alex'] ['odul'] ['xyz']
# ['nuttle1626'] ['nuttle1626'] ['imail'] ['hu']
# ['738731613'] ['738731613'] ['email'] ['io']
# ['hesch'] ['hank'] ['email'] ['me']
# ['monte6198'] ['monte6198'] ['imail'] ['me']
# ['alexhydinger'] ['alexhydinger'] ['gaagle'] ['gov']
# ['caswell-aaron'] ['caswell-aaron'] ['odul'] ['xyz']
# ['dancasal'] ['dancasal'] ['mail'] ['me']
# ['schuster_tiernan'] ['schuster_tiernan'] ['email'] ['xyz']
# ['victorkeller'] ['victorkeller'] ['proton'] ['net']
# ['illingsworth'] ['monte'] ['belgaximus'] ['apple']
# ['jones'] ['jones'] ['mail'] ['net']
# ['peter'] ['peter'] ['belgaximus'] ['net']
# ['hoffman9254'] ['hoffman9254'] ['odul'] ['tech']
# ['sandstrom6021'] ['sandstrom6021'] ['belgaximus'] ['gov']
# ['260123181'] ['260123181'] ['mail'] ['xyz']
# ['moody_lawless'] ['moody_lawless'] ['youhoo'] ['tech']
# ['622921665'] ['622921665'] ['belgaximus'] ['org']
# ['wagner'] ['wagner'] ['ecoin'] ['me']
# ['498202212'] ['498202212'] ['odul'] ['tech']
# ['thompson2886'] ['thompson2886'] ['belgaximus'] ['org']
# ['alexfrick'] ['alexfrick'] ['email'] ['xyz']
# ['zeller'] ['matthew'] ['imail'] ['com']
# ['thomasjagtap'] ['thomasjagtap'] ['proton'] ['hu']
# ['stahl_solberg'] ['stahl_solberg'] ['proton'] ['hu']
# ['resnick'] ['resnick'] ['youhoo'] ['me']
# ['tisler-larry'] ['tisler-larry'] ['hotmoille'] ['me']
# ['881606408'] ['881606408'] ['imail'] ['io']
# ['hank4616'] ['hank4616'] ['proton'] ['gov']
# ['thomas'] ['reamer'] ['odul'] ['hu']
# ['turco'] ['turco'] ['hotmoille'] ['tech']
# ['jones-roger'] ['jones-roger'] ['gaagle'] ['org']
# ['matthew'] ['doran'] ['odul'] ['hu']
# ['frick_steve'] ['frick_steve'] ['napster'] ['gov']
# ['edwarddinkins'] ['edwarddinkins'] ['imail'] ['com']
# ['35834059'] ['35834059'] ['proton'] ['com']
# ['paul7873'] ['paul7873'] ['ecoin'] ['com']
# ['upson_quinn'] ['upson_quinn'] ['youhoo'] ['tech']
# ['sellon'] ['frank'] ['mail'] ['org']
# ['peteryocum'] ['peteryocum'] ['proton'] ['io']
# ['rice-aaron'] ['rice-aaron'] ['ecoin'] ['tech']
# ['714215742'] ['714215742'] ['mail'] ['org']
# ['200912703'] ['200912703'] ['youhoo'] ['org']
# ['537912928'] ['537912928'] ['mail'] ['xyz']
# ['hank2763'] ['hank2763'] ['imail'] ['io']
# ['roger4911'] ['roger4911'] ['hotmoille'] ['apple']
# ['nathanbaxster'] ['nathanbaxster'] ['mail'] ['hu']
# ['thompsonlarry'] ['thompsonlarry'] ['email'] ['net']
# ['franklepage'] ['franklepage'] ['mail'] ['me']
# ['ebner_casal'] ['ebner_casal'] ['hotmoille'] ['com']
# ['moodyroger'] ['moodyroger'] ['ecoin'] ['com']
# ['maki-alex'] ['maki-alex'] ['email'] ['gov']
# ['johnson-hank'] ['johnson-hank'] ['ecoin'] ['apple']
# ['delorenzo_adam'] ['delorenzo_adam'] ['hotmoille'] ['org']
# ['dan'] ['delorenzo'] ['proton'] ['xyz']
# ['knutsondavid'] ['knutsondavid'] ['napster'] ['me']
# ['hal2231'] ['hal2231'] ['hotmoille'] ['me']
# ['quinn_aikin'] ['quinn_aikin'] ['hotmoille'] ['net']
# ['trebilroger'] ['trebilroger'] ['belgaximus'] ['com']
# ['tiernanmark'] ['tiernanmark'] ['odul'] ['apple']
# ['olson'] ['george'] ['odul'] ['tech']
# ['reamer'] ['reamer'] ['imail'] ['hu']
# ['haworth9991'] ['haworth9991'] ['email'] ['gov']
# ['robertsmark'] ['robertsmark'] ['imail'] ['gov']
# ['jack'] ['jack'] ['belgaximus'] ['com']
# ['trussel'] ['trussel'] ['youhoo'] ['hu']
# ['mcginnis_orwig'] ['mcginnis_orwig'] ['mail'] ['com']
# ['jackupson'] ['jackupson'] ['proton'] ['xyz']
# ['nugent6976'] ['nugent6976'] ['napster'] ['com']
# ['martin_kaskel'] ['martin_kaskel'] ['hotmoille'] ['gov']
# ['davidturco'] ['davidturco'] ['mail'] ['net']
# ['halquinn'] ['halquinn'] ['belgaximus'] ['com']
# ['vail'] ['frank'] ['hotmoille'] ['apple']
# ['nuttlesteve'] ['nuttlesteve'] ['odul'] ['me']
# ['vail'] ['vail'] ['mail'] ['tech']
# ['nathan'] ['yocum'] ['ecoin'] ['apple']
# ['victorknutson'] ['victorknutson'] ['proton'] ['io']
# ['kaskel'] ['kaskel'] ['ecoin'] ['me']
# ['72032888'] ['72032888'] ['email'] ['me']
# ['joe'] ['nuttle'] ['youhoo'] ['io']
# ['nathan3403'] ['nathan3403'] ['napster'] ['apple']
# ['aaron'] ['aaron'] ['imail'] ['me']
# ['chapman-monte'] ['chapman-monte'] ['mail'] ['gov']
# ['aaron1573'] ['aaron1573'] ['odul'] ['net']
# ['benmoody'] ['benmoody'] ['proton'] ['io']
# ['van'] ['zandt9356'] ['youhoo'] ['gov']
# ['trebil-aaron'] ['trebil-aaron'] ['ecoin'] ['net']
# ['916085653'] ['916085653'] ['napster'] ['hu']
# ['knutson'] ['tim'] ['napster'] ['io']
# ['schickowski_tapia'] ['schickowski_tapia'] ['hotmoille'] ['tech']
# ['john5147'] ['john5147'] ['napster'] ['gov']
# ['fredlawicki'] ['fredlawicki'] ['hotmoille'] ['me']
# ['hesch'] ['hesch'] ['mail'] ['tech']
# ['nathan'] ['nathan'] ['ecoin'] ['net']
# ['reardon'] ['ben'] ['ecoin'] ['net']
# ['edwardanderson'] ['edwardanderson'] ['mail'] ['io']
# ['kellerhal'] ['kellerhal'] ['proton'] ['tech']
# ['kalleg_nathan'] ['kalleg_nathan'] ['ecoin'] ['hu']
# ['roger'] ['dinkins'] ['proton'] ['io']
# ['johnsen_cataldi'] ['johnsen_cataldi'] ['napster'] ['io']
# ['hal'] ['wagner'] ['imail'] ['com']
# ['bongard'] ['bongard'] ['hotmoille'] ['tech']
# ['mccord'] ['mccord'] ['mail'] ['apple']
# ['bowers_ulrich'] ['bowers_ulrich'] ['email'] ['me']
# ['nelsonroger'] ['nelsonroger'] ['gaagle'] ['xyz']
# ['stevevan'] ['zandt'] ['email'] ['hu']
# ['lewis_ortiz'] ['lewis_ortiz'] ['proton'] ['me']
# ['reyes_steve'] ['reyes_steve'] ['gaagle'] ['apple']
# ['martin'] ['edward'] ['odul'] ['org']
# ['roberts_walter'] ['roberts_walter'] ['mail'] ['hu']
# ['davidson-victor'] ['davidson-victor'] ['napster'] ['io']
# ['ike1526'] ['ike1526'] ['ecoin'] ['net']
# ['76134991'] ['76134991'] ['imail'] ['hu']
# ['aaron'] ['pak'] ['imail'] ['tech']
# ['819378036'] ['819378036'] ['proton'] ['com']
# ['ty9361'] ['ty9361'] ['gaagle'] ['xyz']
# ['frankwoo'] ['frankwoo'] ['belgaximus'] ['hu']
# ['stevevan'] ['zandt'] ['email'] ['apple']
# ['solberg'] ['solberg'] ['belgaximus'] ['hu']
# ['stahl-adam'] ['stahl-adam'] ['hotmoille'] ['net']
# ['turco'] ['turco'] ['odul'] ['apple']
# ['ashwoonthomas'] ['ashwoonthomas'] ['odul'] ['gov']
# ['kaskel'] ['tim'] ['youhoo'] ['org']
# ['larry8418'] ['larry8418'] ['belgaximus'] ['me']
# ['tandyty'] ['tandyty'] ['email'] ['xyz']
# ['bauer_ripka'] ['bauer_ripka'] ['odul'] ['xyz']
# ['moody-victor'] ['moody-victor'] ['ecoin'] ['com']
# ['866926931'] ['866926931'] ['ecoin'] ['org']
# ['van'] ['zandt_paul'] ['proton'] ['net']
# ['hylan_john'] ['hylan_john'] ['ecoin'] ['hu']
# ['hoffman_darnell'] ['hoffman_darnell'] ['napster'] ['org']
# ['sonderling7306'] ['sonderling7306'] ['belgaximus'] ['gov']
# ['mills_delorenzo'] ['mills_delorenzo'] ['mail'] ['org']
# ['hank'] ['hank'] ['email'] ['gov']
# ['johnson_joe'] ['johnson_joe'] ['email'] ['hu']
# ['lawicki'] ['lawicki'] ['gaagle'] ['tech']
# ['johnson_yates'] ['johnson_yates'] ['gaagle'] ['gov']
# ['zeller_ty'] ['zeller_ty'] ['gaagle'] ['me']
# ['thomascasal'] ['thomascasal'] ['imail'] ['net']
# ['wagle'] ['dan'] ['hotmoille'] ['net']
# ['reamer_jones'] ['reamer_jones'] ['mail'] ['hu']
# ['carl3060'] ['carl3060'] ['proton'] ['tech']
# ['roger6892'] ['roger6892'] ['imail'] ['hu']
# ['petervader'] ['petervader'] ['ecoin'] ['io']
# ['thompson'] ['thompson'] ['mail'] ['org']
# ['waglehal'] ['waglehal'] ['belgaximus'] ['io']
# ['paulhydinger'] ['paulhydinger'] ['proton'] ['com']
# ['tapia_john'] ['tapia_john'] ['gaagle'] ['xyz']
# ['larry'] ['larry'] ['mail'] ['net']
# ['andersonedward'] ['andersonedward'] ['ecoin'] ['xyz']
# ['timsellon'] ['timsellon'] ['hotmoille'] ['com']
# ['tim'] ['fietzer'] ['gaagle'] ['net']
# ['pakalex'] ['pakalex'] ['gaagle'] ['com']
# ['markpak'] ['markpak'] ['proton'] ['io']
# ['victordinkins'] ['victordinkins'] ['ecoin'] ['org']
# ['kaskel_duffman'] ['kaskel_duffman'] ['imail'] ['me']
# ['paul9959'] ['paul9959'] ['email'] ['gov']
# ['ike'] ['maki'] ['imail'] ['me']
# ['moorefrank'] ['moorefrank'] ['mail'] ['apple']
# ['406392428'] ['406392428'] ['belgaximus'] ['hu']
# ['ory_nugent'] ['ory_nugent'] ['email'] ['xyz']
# ['solomangeorge'] ['solomangeorge'] ['hotmoille'] ['apple']
# ['bateman_weinstein'] ['bateman_weinstein'] ['belgaximus'] ['gov']
# ['zeaser'] ['zeaser'] ['ecoin'] ['gov']
# ['ulrichty'] ['ulrichty'] ['odul'] ['hu']
# ['irwin-paul'] ['irwin-paul'] ['mail'] ['xyz']
# ['alexmcginnis'] ['alexmcginnis'] ['belgaximus'] ['org']
# ['cataldi'] ['tim'] ['mail'] ['tech']
# ['halrice'] ['halrice'] ['hotmoille'] ['hu']
# ['nelson'] ['steve'] ['imail'] ['hu']
# ['vail_chapman'] ['vail_chapman'] ['youhoo'] ['net']
# ['schiebelthomas'] ['schiebelthomas'] ['ecoin'] ['hu']
# ['ike'] ['hancock'] ['imail'] ['apple']
# ['roger'] ['roger'] ['belgaximus'] ['hu']
# ['nugent_fletcher'] ['nugent_fletcher'] ['ecoin'] ['hu']
# ['maki8692'] ['maki8692'] ['imail'] ['gov']
# ['adam'] ['adam'] ['email'] ['tech']
# ['roger'] ['maki'] ['mail'] ['apple']
# ['sellon-david'] ['sellon-david'] ['ecoin'] ['com']
# ['adam'] ['adam'] ['hotmoille'] ['io']
# ['thomasyates'] ['thomasyates'] ['odul'] ['com']
# ['celedon_walter'] ['celedon_walter'] ['napster'] ['hu']
# ['kassing4495'] ['kassing4495'] ['proton'] ['io']
# ['boyd_george'] ['boyd_george'] ['odul'] ['io']
# ['bowers_ebner'] ['bowers_ebner'] ['email'] ['xyz']
# ['jack9352'] ['jack9352'] ['odul'] ['tech']
# ['lewisdan'] ['lewisdan'] ['youhoo'] ['net']
# ['schmitt-roger'] ['schmitt-roger'] ['napster'] ['tech']
# ['mccormackmark'] ['mccormackmark'] ['hotmoille'] ['net']
# ['timbauer'] ['timbauer'] ['odul'] ['org']
# ['roger349'] ['roger349'] ['mail'] ['net']
# ['reamer_rogers'] ['reamer_rogers'] ['proton'] ['hu']
# ['soulisfred'] ['soulisfred'] ['belgaximus'] ['gov']
# ['vader'] ['tim'] ['hotmoille'] ['xyz']
# ['ory'] ['hal'] ['mail'] ['apple']
# ['wagnerthomas'] ['wagnerthomas'] ['youhoo'] ['tech']
# ['adamjagtap'] ['adamjagtap'] ['hotmoille'] ['apple']
# ['paul'] ['reamer'] ['napster'] ['com']
# ['adam'] ['adam'] ['belgaximus'] ['io']
# ['ty'] ['ty'] ['email'] ['tech']
# ['edward'] ['edward'] ['email'] ['net']
# ['doran2286'] ['doran2286'] ['imail'] ['org']
# ['irwinhal'] ['irwinhal'] ['belgaximus'] ['tech']
# ['tyschwager'] ['tyschwager'] ['odul'] ['tech']
# ['georgemills'] ['georgemills'] ['imail'] ['apple']
# ['wagle389'] ['wagle389'] ['odul'] ['com']
# ['edwardferro'] ['edwardferro'] ['hotmoille'] ['net']
# ['adamostrander'] ['adamostrander'] ['hotmoille'] ['gov']
# ['keller-ty'] ['keller-ty'] ['youhoo'] ['org']
# ['258546748'] ['258546748'] ['imail'] ['org']
# ['bencaswell'] ['bencaswell'] ['imail'] ['gov']
# ['steve1862'] ['steve1862'] ['hotmoille'] ['com']
# ['halturco'] ['halturco'] ['email'] ['hu']
# ['tiernan_casal'] ['tiernan_casal'] ['email'] ['com']
# ['solberg4139'] ['solberg4139'] ['mail'] ['tech']
# ['davidson-otto'] ['davidson-otto'] ['youhoo'] ['com']
# ['alexdoran'] ['alexdoran'] ['napster'] ['org']
# ['thomas'] ['thomas'] ['mail'] ['me']
# ['monte'] ['upson'] ['mail'] ['com']
# ['frick_cannon'] ['frick_cannon'] ['gaagle'] ['tech']
# ['otto'] ['otto'] ['email'] ['apple']
# ['schutz-steve'] ['schutz-steve'] ['mail'] ['xyz']
# ['ikenorquist'] ['ikenorquist'] ['mail'] ['org']
# ['hal'] ['hal'] ['email'] ['tech']
# ['ulrich'] ['thomas'] ['odul'] ['io']
# ['vader_casal'] ['vader_casal'] ['mail'] ['org']
# ['aaron'] ['aaron'] ['mail'] ['org']
# ['anderson_aaron'] ['anderson_aaron'] ['odul'] ['me']
# ['aikin8186'] ['aikin8186'] ['mail'] ['hu']
# ['hoffman_victor'] ['hoffman_victor'] ['imail'] ['tech']
# ['larrythompson'] ['larrythompson'] ['imail'] ['apple']
# ['ebnerjohn'] ['ebnerjohn'] ['gaagle'] ['apple']
# ['frank'] ['nelson'] ['proton'] ['net']
# ['ebner_reamer'] ['ebner_reamer'] ['email'] ['me']
# ['trusela_paul'] ['trusela_paul'] ['imail'] ['me']
# ['dinkinsalex'] ['dinkinsalex'] ['email'] ['io']
# ['jack3083'] ['jack3083'] ['belgaximus'] ['gov']
# ['casal'] ['casal'] ['youhoo'] ['gov']
# ['fred'] ['fred'] ['imail'] ['me']
# ['davisgeorge'] ['davisgeorge'] ['napster'] ['tech']
# ['jagtap'] ['jagtap'] ['odul'] ['com']
# ['joe1068'] ['joe1068'] ['mail'] ['tech']
# ['wagner'] ['roger'] ['mail'] ['apple']
# ['fredvalente'] ['fredvalente'] ['gaagle'] ['me']
# ['hylan'] ['carl'] ['hotmoille'] ['gov']
# ['270804951'] ['270804951'] ['napster'] ['org']
# ['uddin1875'] ['uddin1875'] ['napster'] ['apple']
# ['turco'] ['carl'] ['belgaximus'] ['tech']
# ['hoffman'] ['hoffman'] ['gaagle'] ['apple']
# ['joe'] ['rogers'] ['gaagle'] ['xyz']
# ['schmitt_larry'] ['schmitt_larry'] ['odul'] ['gov']
# ['879442014'] ['879442014'] ['mail'] ['tech']
# ['carlsoloman'] ['carlsoloman'] ['ecoin'] ['com']
# ['nathan6115'] ['nathan6115'] ['imail'] ['me']
# ['frank'] ['frank'] ['imail'] ['io']
# ['norquist_steve'] ['norquist_steve'] ['belgaximus'] ['com']
# ['delorenzo_peter'] ['delorenzo_peter'] ['mail'] ['xyz']
# ['paul'] ['paul'] ['hotmoille'] ['gov']
# ['orwig'] ['orwig'] ['odul'] ['me']
# ['dinkins-adam'] ['dinkins-adam'] ['imail'] ['tech']
# ['tislerdan'] ['tislerdan'] ['hotmoille'] ['tech']
# ['edward6174'] ['edward6174'] ['imail'] ['me']
# ['montepettigrew'] ['montepettigrew'] ['hotmoille'] ['hu']
# ['schutzlarry'] ['schutzlarry'] ['odul'] ['net']
# ['zeasertim'] ['zeasertim'] ['proton'] ['tech']
# ['walter'] ['kassing'] ['odul'] ['tech']
# ['ferro'] ['david'] ['gaagle'] ['tech']
# ['schmitt_schiebel'] ['schmitt_schiebel'] ['belgaximus'] ['gov']
# ['ikethompson'] ['ikethompson'] ['mail'] ['tech']
# ['martin'] ['ben'] ['imail'] ['me']
# ['benventotla'] ['benventotla'] ['youhoo'] ['org']
# ['ziegler_soloman'] ['ziegler_soloman'] ['imail'] ['io']
# ['davidson_rogers'] ['davidson_rogers'] ['belgaximus'] ['xyz']
# ['george'] ['george'] ['proton'] ['org']
# ['ramachandran431'] ['ramachandran431'] ['napster'] ['hu']
# ['paulostrander'] ['paulostrander'] ['youhoo'] ['xyz']
# ['tyseverson'] ['tyseverson'] ['hotmoille'] ['hu']
# ['edwardortiz'] ['edwardortiz'] ['hotmoille'] ['tech']
# ['hal5999'] ['hal5999'] ['email'] ['org']
# ['christensen-david'] ['christensen-david'] ['odul'] ['hu']
# ['mark'] ['mark'] ['mail'] ['me']
# ['bongard-paul'] ['bongard-paul'] ['gaagle'] ['xyz']
# ['moody3417'] ['moody3417'] ['ecoin'] ['gov']
# ['trebil_bowers'] ['trebil_bowers'] ['proton'] ['org']
# ['pak9267'] ['pak9267'] ['ecoin'] ['hu']
# ['883886499'] ['883886499'] ['youhoo'] ['io']
# ['peterknutson'] ['peterknutson'] ['gaagle'] ['hu']
# ['mark'] ['mark'] ['belgaximus'] ['gov']
# ['660694516'] ['660694516'] ['napster'] ['apple']
# ['larry'] ['larry'] ['belgaximus'] ['gov']
# ['wagner-otto'] ['wagner-otto'] ['ecoin'] ['apple']
# ['ripka1096'] ['ripka1096'] ['email'] ['apple']
# ['bowers'] ['otto'] ['proton'] ['gov']
# ['peter2859'] ['peter2859'] ['mail'] ['net']
# ['ulrich_fred'] ['ulrich_fred'] ['imail'] ['tech']
# ['dugelman_carl'] ['dugelman_carl'] ['youhoo'] ['io']
# ['801140752'] ['801140752'] ['email'] ['net']
# ['schutz_otto'] ['schutz_otto'] ['mail'] ['hu']
# ['vader-larry'] ['vader-larry'] ['hotmoille'] ['me']
# ['jurgenson'] ['aaron'] ['napster'] ['io']
# ['stahl_ty'] ['stahl_ty'] ['gaagle'] ['tech']
# ['lawickimatthew'] ['lawickimatthew'] ['gaagle'] ['tech']
# ['kassing-victor'] ['kassing-victor'] ['gaagle'] ['io']
# ['halbongard'] ['halbongard'] ['hotmoille'] ['tech']
# ['soukup'] ['roger'] ['youhoo'] ['com']
# ['733095700'] ['733095700'] ['mail'] ['io']
# ['jack'] ['sweeney'] ['hotmoille'] ['org']

# %% [markdown]
# Repeat the previous exercise with this new formula and compare the length of your lists with those of the previous exercise.
# What do you notice ?
